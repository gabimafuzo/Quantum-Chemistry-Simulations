# %% [markdown]
# ## Carregando psi4

# %%
# %%bash
# set -euo pipefail
#
# MAMBA_ROOT="$HOME/mamba"
# MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
# if [ ! -x "$MAMBA_BIN" ]; then
#   mkdir -p "$MAMBA_ROOT"
#   curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj -C "$MAMBA_ROOT" bin/micromamba >/dev/null
# fi
#
# "$MAMBA_BIN" create -y -r "$MAMBA_ROOT" -n psi4 -c conda-forge psi4 python=3.12 >/dev/null

# %% [markdown]
# ## H

# %%
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
# %%bash
set -euo pipefail
MAMBA_ROOT="$HOME/mamba"
MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
cat > psi4.in <<'EOF'
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>


# Your input file should go in this middle section
# Write this as a classic-style Psi4 input file (not a Python script)

# Specify the molecular geometry
molecule {
   H 0.0 0.0 0.0
}

set {
  basis aug-cc-pVQZ
  reference uhf
}

# Compute the energy at the CCSD(T) level
energy('CCSD(T)')


# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
EOF
"$MAMBA_BIN" run -r "$MAMBA_ROOT" -n psi4 psi4 psi4.in psi4.out
cat psi4.out
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Out:
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, D. L. Poole, T. Győri, E. C. Mitchell, J. P. Pederson,
#     and A. M. Wallace
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     https://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Tuesday, 26 May 2026 07:23PM
#
#     Process ID: 28608
#     Host:       8e3c8f7b991a
#     PSIDATADIR: /root/mamba/envs/psi4/share/psi4
#     Memory:     500.0 MiB
#     Threads:    1
#     Addons:     a̶d̶c̶c̶, a̶m̶b̶i̶t̶, b̶s̶e̶, c̶c̶t̶3̶, c̶f̶o̶u̶r̶, c̶h̶e̶m̶p̶s̶2̶, c̶p̶p̶e̶, d̶d̶x̶,
#                 d̶f̶t̶d̶3̶, d̶f̶t̶d̶4̶, dkh, ecpint, einsums, f̶o̶r̶t̶e̶, g̶a̶u̶x̶c̶, g̶c̶p̶,
#                 g̶d̶m̶a̶, g̶e̶o̶m̶e̶t̶r̶i̶c̶, g̶p̶u̶_̶d̶f̶c̶c̶, i̶n̶t̶e̶g̶r̶a̶t̶o̶r̶x̶x̶,
#                 i̶p̶i̶, l̶i̶b̶e̶f̶p̶, m̶d̶i̶, m̶p̶2̶d̶, m̶r̶c̶c̶, ooo,
#                 o̶p̶e̶n̶f̶e̶r̶m̶i̶o̶n̶p̶s̶i̶4̶, pcmsolver, p̶s̶i̶4̶f̶o̶c̶k̶c̶i̶, p̶s̶i̶x̶a̶s̶,
#                 r̶e̶s̶p̶, s̶i̶m̶i̶n̶t̶, s̶n̶s̶m̶p̶2̶, v̶2̶r̶d̶m̶_̶c̶a̶s̶s̶c̶f̶
#
#   ==> Input File <==
#
# --------------------------------------------------------------------------
# # >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
#
# # Your input file should go in this middle section
# # Write this as a classic-style Psi4 input file (not a Python script)
#
# # Specify the molecular geometry
# molecule {
#    H 0.0 0.0 0.0
# }
#
# set {
#   basis aug-cc-pVQZ
#   reference uhf
# }
#
# # Compute the energy at the CCSD(T) level
# energy('CCSD(T)')
#
#
# # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# # STUDENTS SHOULD IGNORE THESE LINES
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 8e3c8f7b991a
# *** at Tue May 26 19:23:37 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVQZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvqz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               UHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Geometry (in Angstrom), charge = 0, multiplicity = 2:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          H            0.000000000000     0.000000000000     0.000000000000     1.007825032230
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B = ************  C = ************ [cm^-1]
#   Rotational constants: A = ************  B = ************  C = ************ [MHz]
#   Nuclear repulsion =    0.000000000000000
#
#   Charge       = 0
#   Multiplicity = 2
#   Electrons    = 1
#   Nalpha       = 1
#   Nbeta        = 0
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is CORE.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVQZ
#     Blend: AUG-CC-PVQZ
#     Number of shells: 14
#     Number of basis functions: 46
#     Number of Cartesian functions: 55
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   1
#       Number of AO shells:              14
#       Number of primitives:             16
#       Number of atomic orbitals:        55
#       Number of basis functions:        46
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 1169642 doubles for integral storage.
#   We computed 5565 shell quartets total.
#   Whereas there are 5565 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.2249687389E-02.
#   Reciprocal condition number of the overlap matrix is 1.0778603251E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Core (One-Electron) Hamiltonian.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      Ag        11      11       1       0       0       1
#      B1g        3       3       0       0       0       0
#      B2g        3       3       0       0       0       0
#      B3g        3       3       0       0       0       0
#      Au         2       2       0       0       0       0
#      B1u        8       8       0       0       0       0
#      B2u        8       8       0       0       0       0
#      B3u        8       8       0       0       0       0
#    -------------------------------------------------------
#     Total      46      46       1       0       0       1
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @UHF iter   1:    -0.49994832146912   -4.99948e-01   1.61956e-16 DIIS
#    @UHF iter   2:    -0.49994832146912    2.77556e-16   7.84520e-17 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    @Spin Contamination Metric:   0.000000000E+00
#    @S^2 Expected:                7.500000000E-01
#    @S^2 Observed:                7.500000000E-01
#    @S   Expected:                5.000000000E-01
#    @S   Observed:                5.000000000E-01
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Alpha Occupied:
#
#        1Ag    -0.499948
#
#     Alpha Virtual:
#
#        2Ag     0.051183     1B3u    0.171452     1B2u    0.171452
#        1B1u    0.171452     3Ag     0.362663     4Ag     0.613318
#        5Ag     0.613318     1B3g    0.613318     1B1g    0.613318
#        1B2g    0.613318     2B3u    0.741441     2B2u    0.741441
#        2B1u    0.741441     3B2u    1.558792     3B3u    1.558792
#        1Au     1.558792     4B3u    1.558792     3B1u    1.558792
#        4B1u    1.558792     4B2u    1.558792     6Ag     1.575182
#        7Ag     2.447851     2B3g    2.447851     8Ag     2.447851
#        2B1g    2.447851     2B2g    2.447851     5B2u    2.544648
#        5B1u    2.544648     5B3u    2.544648     2Au     6.551080
#        6B1u    6.551080     6B2u    6.551080     7B1u    6.551080
#        6B3u    6.551080     7B3u    6.551080     7B2u    6.551080
#        9Ag     7.383054     8B2u    7.925356     8B3u    7.925356
#        8B1u    7.925356    10Ag     8.386670     3B3g    8.386670
#        3B1g    8.386670     3B2g    8.386670    11Ag     8.386670
#
#     Beta Occupied:
#
#
#
#     Beta Virtual:
#
#        1Ag     0.014566     2Ag     0.110187     1B2u    0.190622
#        1B1u    0.190622     1B3u    0.190622     3Ag     0.469075
#        1B3g    0.626719     1B1g    0.626719     1B2g    0.626719
#        4Ag     0.626719     5Ag     0.626719     2B2u    0.808896
#        2B3u    0.808896     2B1u    0.808896     3B3u    1.571363
#        3B1u    1.571363     1Au     1.571363     3B2u    1.571363
#        4B3u    1.571363     4B1u    1.571363     4B2u    1.571363
#        6Ag     1.690004     7Ag     2.487329     8Ag     2.487329
#        2B1g    2.487329     2B2g    2.487329     2B3g    2.487329
#        5B2u    2.619732     5B1u    2.619732     5B3u    2.619732
#        6B2u    6.579923     2Au     6.579923     6B1u    6.579923
#        6B3u    6.579923     7B1u    6.579923     7B3u    6.579923
#        7B2u    6.579923     9Ag     7.465193     8B2u    7.983373
#        8B3u    7.983373     8B1u    7.983373    10Ag     8.428908
#        3B3g    8.428908     3B2g    8.428908     3B1g    8.428908
#       11Ag     8.428908
#
#     Final Occupation by Irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     0,    0,    0,    0,    0,    0,    0,    0 ]
#     SOCC [     1,    0,    0,    0,    0,    0,    0,    0 ]
#     NA   [     1,    0,    0,    0,    0,    0,    0,    0 ]
#     NB   [     0,    0,    0,    0,    0,    0,    0,    0 ]
#
#   @UHF Final Energy:    -0.49994832146912
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.0000000000000000
#     One-Electron Energy =                  -0.4999483214691200
#     Two-Electron Energy =                   0.0000000000000001
#     Total Energy =                         -0.4999483214691200
#
#   UHF NO Occupations:
#   HONO-0 :    1 Ag 1.0000000
#   LUNO+0 :    2 Ag 0.0000000
#   LUNO+1 :    3 Ag 0.0000000
#   LUNO+2 :    4 Ag 0.0000000
#   LUNO+3 :    8B3u 0.0000000
#
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on 8e3c8f7b991a at Tue May 26 19:23:38 2026
# Module time:
# 	user time   =       0.16 seconds =       0.00 minutes
# 	system time =       0.06 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       0.16 seconds =       0.00 minutes
# 	system time =       0.06 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   1
#       Number of AO shells:              14
#       Number of SO shells:              14
#       Number of primitives:             16
#       Number of atomic orbitals:        55
#       Number of basis functions:        46
#
#       Number of irreps:                  8
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [  11    3    3    3    2    8    8    8 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 61179 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on 8e3c8f7b991a
# *** at Tue May 26 19:23:38 2026
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 8
# 	Number of MOs        = 46
# 	Number of active MOs = 46
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = UHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 Ag	   11	    0	    0	    1	    10	    0
# 	 B1g	   3	    0	    0	    0	    3	    0
# 	 B2g	   3	    0	    0	    0	    3	    0
# 	 B3g	   3	    0	    0	    0	    3	    0
# 	 Au	   2	    0	    0	    0	    2	    0
# 	 B1u	   8	    0	    0	    0	    8	    0
# 	 B2u	   8	    0	    0	    0	    8	    0
# 	 B3u	   8	    0	    0	    0	    8	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =      0.00000000000000
#
# 	Size of irrep 0 of <AB|CD> integrals:      0.019 (MW) /      0.155 (MB)
# 	Size of irrep 1 of <AB|CD> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 2 of <AB|CD> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 3 of <AB|CD> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 4 of <AB|CD> integrals:      0.008 (MW) /      0.068 (MB)
# 	Size of irrep 5 of <AB|CD> integrals:      0.018 (MW) /      0.144 (MB)
# 	Size of irrep 6 of <AB|CD> integrals:      0.018 (MW) /      0.144 (MB)
# 	Size of irrep 7 of <AB|CD> integrals:      0.018 (MW) /      0.144 (MB)
# 	Total:                                     0.124 (MW) /      0.993 (MB)
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.022 (MW) /      0.178 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.015 (MW) /      0.119 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.015 (MW) /      0.119 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.015 (MW) /      0.119 (MB)
# 	Size of irrep 4 of <ab|cd> integrals:      0.009 (MW) /      0.071 (MB)
# 	Size of irrep 5 of <ab|cd> integrals:      0.020 (MW) /      0.161 (MB)
# 	Size of irrep 6 of <ab|cd> integrals:      0.020 (MW) /      0.161 (MB)
# 	Size of irrep 7 of <ab|cd> integrals:      0.020 (MW) /      0.161 (MB)
# 	Total:                                     0.136 (MW) /      1.089 (MB)
#
# 	Size of irrep 0 of <Ab|Cd> integrals:      0.111 (MW) /      0.887 (MB)
# 	Size of irrep 1 of <Ab|Cd> integrals:      0.058 (MW) /      0.465 (MB)
# 	Size of irrep 2 of <Ab|Cd> integrals:      0.058 (MW) /      0.465 (MB)
# 	Size of irrep 3 of <Ab|Cd> integrals:      0.058 (MW) /      0.465 (MB)
# 	Size of irrep 4 of <Ab|Cd> integrals:      0.035 (MW) /      0.277 (MB)
# 	Size of irrep 5 of <Ab|Cd> integrals:      0.076 (MW) /      0.609 (MB)
# 	Size of irrep 6 of <Ab|Cd> integrals:      0.076 (MW) /      0.609 (MB)
# 	Size of irrep 7 of <Ab|Cd> integrals:      0.076 (MW) /      0.609 (MB)
# 	Total:                                     0.548 (MW) /      4.386 (MB)
#
# 	Size of irrep 0 of <IA|BC> integrals:      0.003 (MW) /      0.026 (MB)
# 	Size of irrep 1 of <IA|BC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 2 of <IA|BC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 3 of <IA|BC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 4 of <IA|BC> integrals:      0.000 (MW) /      0.003 (MB)
# 	Size of irrep 5 of <IA|BC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 6 of <IA|BC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 7 of <IA|BC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Total:                                     0.012 (MW) /      0.097 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 1 of <ia|bc> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 2 of <ia|bc> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 3 of <ia|bc> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 4 of <ia|bc> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 5 of <ia|bc> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 6 of <ia|bc> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 7 of <ia|bc> integrals:      0.000 (MW) /      0.000 (MB)
# 	Total:                                     0.000 (MW) /      0.000 (MB)
#
# 	Size of irrep 0 of <Ia|Bc> integrals:      0.004 (MW) /      0.029 (MB)
# 	Size of irrep 1 of <Ia|Bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 2 of <Ia|Bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 3 of <Ia|Bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 4 of <Ia|Bc> integrals:      0.000 (MW) /      0.003 (MB)
# 	Size of irrep 5 of <Ia|Bc> integrals:      0.002 (MW) /      0.018 (MB)
# 	Size of irrep 6 of <Ia|Bc> integrals:      0.002 (MW) /      0.018 (MB)
# 	Size of irrep 7 of <Ia|Bc> integrals:      0.002 (MW) /      0.018 (MB)
# 	Total:                                     0.013 (MW) /      0.103 (MB)
#
# 	Size of irrep 0 of <iA|bC> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 1 of <iA|bC> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 2 of <iA|bC> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 3 of <iA|bC> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 4 of <iA|bC> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 5 of <iA|bC> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 6 of <iA|bC> integrals:      0.000 (MW) /      0.000 (MB)
# 	Size of irrep 7 of <iA|bC> integrals:      0.000 (MW) /      0.000 (MB)
# 	Total:                                     0.000 (MW) /      0.000 (MB)
#
# 	Size of irrep 0 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 1 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 2 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 3 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 4 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 5 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 6 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 7 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Total:                                     0.000 (MW) /      0.000 (MB)
#
# 	Nuclear Rep. energy          =      0.00000000000000
# 	SCF energy                   =     -0.49994832146912
# 	One-electron energy          =     -0.49994832146912
# 	Two-electron (AA) energy     =      0.00000000000000
# 	Two-electron (BB) energy     =      0.00000000000000
# 	Two-electron (AB) energy     =      0.00000000000000
# 	Two-electron energy          =      0.00000000000000
# 	Reference energy             =     -0.49994832146912
#
# *** tstop() called on 8e3c8f7b991a at Tue May 26 19:23:38 2026
# Module time:
# 	user time   =       0.12 seconds =       0.00 minutes
# 	system time =       0.15 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.31 seconds =       0.01 minutes
# 	system time =       0.21 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
#             **************************
#             *                        *
#             *        CCENERGY        *
#             *                        *
#             **************************
#
#     Nuclear Rep. energy (wfn)     =    0.000000000000000
#     SCF energy          (wfn)     =   -0.499948321469120
#     Reference energy    (file100) =   -0.499948321469120
#
#     Input parameters:
#     -----------------
#     Wave function   =     CCSD_T
#     Reference wfn   =     UHF
#     Brueckner       =     No
#     Memory (Mbytes) =     524.3
#     Maxiter         =     50
#     R_Convergence   =     1.0e-07
#     E_Convergence   =     1.0e-06
#     Restart         =     Yes
#     DIIS            =     Yes
#     AO Basis        =     NONE
#     ABCD            =     NEW
#     Cache Level     =     2
#     Cache Type      =     LRU
#     Print Level     =     1
#     Num. of threads =     1
#     # Amps to Print =     10
#     Print MP2 Amps? =     No
#     Analyze T2 Amps =     No
#     Print Pair Ener =     No
#     Local CC        =     No
#     SCS-MP2         =     False
#     SCSN-MP2        =     False
#     SCS-CCSD        =     False
#
# MP2 correlation energy -0.0000000000000000
#                 Solving CC Amplitude Equations
#                 ------------------------------
#   Iter             Energy              RMS        T1Diag      D1Diag    New D1Diag    D2Diag
#   ----     ---------------------    ---------   ----------  ----------  ----------   --------
#      0        -0.000000000000000    0.000e+00    0.000000    0.000000    0.000000    0.000000
#      1        -0.000000000000000    1.992e-16    0.000000    0.000000    0.000000    0.000000
#
#     Iterations converged.
#
#
#     SCF energy       (wfn)                    =   -0.499948321469120
#     Reference energy (file100)                =   -0.499948321469120
#
#     Opposite-spin MP2 correlation energy      =    0.000000000000000
#     Same-spin MP2 correlation energy          =    0.000000000000000
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.000000000000000
#       * MP2 total energy                      =   -0.499948321469120
#
#     Opposite-spin CCSD correlation energy     =    0.000000000000000
#     Same-spin CCSD correlation energy         =    0.000000000000000
#     Singles CCSD correlation energy           =   -0.000000000000000
#     CCSD correlation energy                   =   -0.000000000000000
#       * CCSD total energy                     =   -0.499948321469120
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      UHF
#
#     Nuclear Rep. energy (wfn)                =    0.000000000000000
#     SCF energy          (wfn)                =   -0.499948321469120
#     Reference energy    (file100)            =   -0.499948321469120
#     CCSD energy         (file100)            =   -0.000000000000000
#     Total CCSD energy   (file100)            =   -0.499948321469120
#
#     Number of ijk index combinations:
#     Spin Case AAA:                                   0
#     Spin Case BBB:                                   0
#     Spin Case AAB:                                   0
#     Spin Case ABB:                                   0
#     AAA (T) energy                             =    0.000000000000000
#     BBB (T) energy                             =    0.000000000000000
#     AAB (T) energy                             =    0.000000000000000
#     ABB (T) energy                             =    0.000000000000000
#     (T) energy                                   =    0.000000000000000
#       * CCSD(T) total energy                     =   -0.499948321469120
#
#
#     Psi4 stopped on: Tuesday, 26 May 2026 07:23PM
#     Psi4 wall time for execution: 0:00:01.04
#
# *** Psi4 exiting successfully. Buy a developer a beer!

# %% [markdown]
# ## He in python

# %%
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
# %%bash
set -euo pipefail
MAMBA_ROOT="$HOME/mamba"
MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
cat > psi4.in <<'EOF'
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>


# Your input file should go in this middle section
# Write this as a classic-style Psi4 input file (not a Python script)

import psi4

# Specify the location of the output file
psi4.core.set_output_file("psi4.out", True)

# Specify the molecular geometry
molecule = psi4.geometry("""
   He 0.0 0.0 0.0
""")

# Set some calculation options
psi4.set_options({'reference': 'uhf',
                  'basis': 'aug-cc-pVQZ'})

# Compute the energy at the CCSD(T) level
psi4.energy('CCSD(T)')

# Print the contents of the output file
with open("psi4.out", "r") as f:
    print(f.read())

# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
EOF
"$MAMBA_BIN" run -r "$MAMBA_ROOT" -n psi4 psi4 psi4.in psi4.out
cat psi4.out
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Out:
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, D. L. Poole, T. Győri, E. C. Mitchell, J. P. Pederson,
#     and A. M. Wallace
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     https://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Tuesday, 26 May 2026 07:51PM
#
#     Process ID: 35317
#     Host:       8e3c8f7b991a
#     PSIDATADIR: /root/mamba/envs/psi4/share/psi4
#     Memory:     500.0 MiB
#     Threads:    1
#     Addons:     a̶d̶c̶c̶, a̶m̶b̶i̶t̶, b̶s̶e̶, c̶c̶t̶3̶, c̶f̶o̶u̶r̶, c̶h̶e̶m̶p̶s̶2̶, c̶p̶p̶e̶, d̶d̶x̶,
#                 d̶f̶t̶d̶3̶, d̶f̶t̶d̶4̶, dkh, ecpint, einsums, f̶o̶r̶t̶e̶, g̶a̶u̶x̶c̶, g̶c̶p̶,
#                 g̶d̶m̶a̶, g̶e̶o̶m̶e̶t̶r̶i̶c̶, g̶p̶u̶_̶d̶f̶c̶c̶, i̶n̶t̶e̶g̶r̶a̶t̶o̶r̶x̶x̶,
#                 i̶p̶i̶, l̶i̶b̶e̶f̶p̶, m̶d̶i̶, m̶p̶2̶d̶, m̶r̶c̶c̶, ooo,
#                 o̶p̶e̶n̶f̶e̶r̶m̶i̶o̶n̶p̶s̶i̶4̶, pcmsolver, p̶s̶i̶4̶f̶o̶c̶k̶c̶i̶, p̶s̶i̶x̶a̶s̶,
#                 r̶e̶s̶p̶, s̶i̶m̶i̶n̶t̶, s̶n̶s̶m̶p̶2̶, v̶2̶r̶d̶m̶_̶c̶a̶s̶s̶c̶f̶
#
#   ==> Input File <==
#
# --------------------------------------------------------------------------
# # >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
#
# # Your input file should go in this middle section
# # Write this as a classic-style Psi4 input file (not a Python script)
#
# import psi4
#
# # Specify the location of the output file
# psi4.core.set_output_file("psi4.out", True)
#
# # Specify the molecular geometry
# molecule = psi4.geometry("""
#    He 0.0 0.0 0.0
# """)
#
# # Set some calculation options
# psi4.set_options({'reference': 'uhf',
#                   'basis': 'aug-cc-pVQZ'})
#
# # Compute the energy at the CCSD(T) level
# psi4.energy('CCSD(T)')
#
# # Print the contents of the output file
# with open("psi4.out", "r") as f:
#     print(f.read())
#
# # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# # STUDENTS SHOULD IGNORE THESE LINES
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 8e3c8f7b991a
# *** at Tue May 26 19:51:31 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVQZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry HE         line    72 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvqz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               UHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          HE           0.000000000000     0.000000000000     0.000000000000     4.002603254130
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B = ************  C = ************ [cm^-1]
#   Rotational constants: A = ************  B = ************  C = ************ [MHz]
#   Nuclear repulsion =    0.000000000000000
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 2
#   Nalpha       = 1
#   Nbeta        = 1
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is CORE.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVQZ
#     Blend: AUG-CC-PVQZ
#     Number of shells: 14
#     Number of basis functions: 46
#     Number of Cartesian functions: 55
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   1
#       Number of AO shells:              14
#       Number of primitives:             17
#       Number of atomic orbitals:        55
#       Number of basis functions:        46
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 1169642 doubles for integral storage.
#   We computed 5565 shell quartets total.
#   Whereas there are 5565 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.1408536236E-02.
#   Reciprocal condition number of the overlap matrix is 1.0427704434E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Core (One-Electron) Hamiltonian.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      Ag        11      11       1       1       1       0
#      B1g        3       3       0       0       0       0
#      B2g        3       3       0       0       0       0
#      B3g        3       3       0       0       0       0
#      Au         2       2       0       0       0       0
#      B1u        8       8       0       0       0       0
#      B2u        8       8       0       0       0       0
#      B3u        8       8       0       0       0       0
#    -------------------------------------------------------
#     Total      46      46       1       1       1       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @UHF iter   1:    -2.75016263784500   -2.75016e+00   2.86195e-02 ADIIS/DIIS
#    @UHF iter   2:    -2.86014262105557   -1.09980e-01   2.51385e-03 ADIIS/DIIS
#    @UHF iter   3:    -2.86150171956953   -1.35910e-03   3.15698e-04 ADIIS/DIIS
#    @UHF iter   4:    -2.86152183206415   -2.01125e-05   2.38541e-05 DIIS
#    @UHF iter   5:    -2.86152199533983   -1.63276e-07   9.29420e-07 DIIS
#    @UHF iter   6:    -2.86152199562991   -2.90077e-10   8.01815e-08 DIIS
#    @UHF iter   7:    -2.86152199563247   -2.56062e-12   3.16726e-10 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    @Spin Contamination Metric:  -2.220446049E-15
#    @S^2 Expected:                0.000000000E+00
#    @S^2 Observed:               -2.220446049E-15
#    @S   Expected:                0.000000000E+00
#    @S   Observed:                0.000000000E+00
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Alpha Occupied:
#
#        1Ag    -0.917932
#
#     Alpha Virtual:
#
#        2Ag     0.098748     1B3u    0.347825     1B2u    0.347825
#        1B1u    0.347825     3Ag     0.685403     1B1g    1.148963
#        1B2g    1.148963     1B3g    1.148963     4Ag     1.148963
#        5Ag     1.148963     2B1u    1.476085     2B2u    1.476085
#        2B3u    1.476085     6Ag     2.955725     3B3u    3.003209
#        3B2u    3.003209     4B2u    3.003209     1Au     3.003209
#        4B3u    3.003209     3B1u    3.003209     4B1u    3.003209
#        2B1g    4.577315     2B2g    4.577315     2B3g    4.577315
#        7Ag     4.577315     8Ag     4.577315     5B2u    5.130345
#        5B1u    5.130345     5B3u    5.130345     6B1u   12.535762
#        6B3u   12.535762     2Au    12.535762     6B2u   12.535762
#        7B3u   12.535762     7B1u   12.535762     7B2u   12.535762
#        9Ag    13.621517    10Ag    16.643632    11Ag    16.643632
#        3B1g   16.643632     3B2g   16.643632     3B3g   16.643632
#        8B2u   18.091756     8B1u   18.091756     8B3u   18.091756
#
#     Beta Occupied:
#
#        1Ag    -0.917932
#
#     Beta Virtual:
#
#        2Ag     0.098748     1B3u    0.347825     1B2u    0.347825
#        1B1u    0.347825     3Ag     0.685403     1B1g    1.148963
#        1B2g    1.148963     1B3g    1.148963     4Ag     1.148963
#        5Ag     1.148963     2B1u    1.476085     2B2u    1.476085
#        2B3u    1.476085     6Ag     2.955725     3B3u    3.003209
#        3B2u    3.003209     4B2u    3.003209     1Au     3.003209
#        4B3u    3.003209     3B1u    3.003209     4B1u    3.003209
#        2B1g    4.577315     2B2g    4.577315     2B3g    4.577315
#        7Ag     4.577315     8Ag     4.577315     5B2u    5.130345
#        5B1u    5.130345     5B3u    5.130345     6B1u   12.535762
#        6B3u   12.535762     2Au    12.535762     6B2u   12.535762
#        7B3u   12.535762     7B1u   12.535762     7B2u   12.535762
#        9Ag    13.621517    10Ag    16.643632    11Ag    16.643632
#        3B1g   16.643632     3B2g   16.643632     3B3g   16.643632
#        8B2u   18.091756     8B1u   18.091756     8B3u   18.091756
#
#     Final Occupation by Irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     1,    0,    0,    0,    0,    0,    0,    0 ]
#     SOCC [     0,    0,    0,    0,    0,    0,    0,    0 ]
#     NA   [     1,    0,    0,    0,    0,    0,    0,    0 ]
#     NB   [     1,    0,    0,    0,    0,    0,    0,    0 ]
#
#   @UHF Final Energy:    -2.86152199563247
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.0000000000000000
#     One-Electron Energy =                  -3.8871796718649003
#     Two-Electron Energy =                   1.0256576762324334
#     Total Energy =                         -2.8615219956324669
#
#   UHF NO Occupations:
#   HONO-0 :    1 Ag 2.0000000
#   LUNO+0 :    2 Ag 0.0000000
#   LUNO+1 :    3 Ag 0.0000000
#   LUNO+2 :    4 Ag 0.0000000
#   LUNO+3 :    5 Ag 0.0000000
#
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on 8e3c8f7b991a at Tue May 26 19:51:33 2026
# Module time:
# 	user time   =       0.70 seconds =       0.01 minutes
# 	system time =       0.24 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
# Total time:
# 	user time   =       0.70 seconds =       0.01 minutes
# 	system time =       0.24 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   1
#       Number of AO shells:              14
#       Number of SO shells:              14
#       Number of primitives:             17
#       Number of atomic orbitals:        55
#       Number of basis functions:        46
#
#       Number of irreps:                  8
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [  11    3    3    3    2    8    8    8 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 61179 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on 8e3c8f7b991a
# *** at Tue May 26 19:51:33 2026
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 8
# 	Number of MOs        = 46
# 	Number of active MOs = 46
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = UHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 Ag	   11	    0	    1	    0	    10	    0
# 	 B1g	   3	    0	    0	    0	    3	    0
# 	 B2g	   3	    0	    0	    0	    3	    0
# 	 B3g	   3	    0	    0	    0	    3	    0
# 	 Au	   2	    0	    0	    0	    2	    0
# 	 B1u	   8	    0	    0	    0	    8	    0
# 	 B2u	   8	    0	    0	    0	    8	    0
# 	 B3u	   8	    0	    0	    0	    8	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =      0.00000000000000
#
# 	Size of irrep 0 of <AB|CD> integrals:      0.019 (MW) /      0.155 (MB)
# 	Size of irrep 1 of <AB|CD> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 2 of <AB|CD> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 3 of <AB|CD> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 4 of <AB|CD> integrals:      0.008 (MW) /      0.068 (MB)
# 	Size of irrep 5 of <AB|CD> integrals:      0.018 (MW) /      0.144 (MB)
# 	Size of irrep 6 of <AB|CD> integrals:      0.018 (MW) /      0.144 (MB)
# 	Size of irrep 7 of <AB|CD> integrals:      0.018 (MW) /      0.144 (MB)
# 	Total:                                     0.124 (MW) /      0.993 (MB)
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.019 (MW) /      0.155 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 4 of <ab|cd> integrals:      0.008 (MW) /      0.068 (MB)
# 	Size of irrep 5 of <ab|cd> integrals:      0.018 (MW) /      0.144 (MB)
# 	Size of irrep 6 of <ab|cd> integrals:      0.018 (MW) /      0.144 (MB)
# 	Size of irrep 7 of <ab|cd> integrals:      0.018 (MW) /      0.144 (MB)
# 	Total:                                     0.124 (MW) /      0.993 (MB)
#
# 	Size of irrep 0 of <Ab|Cd> integrals:      0.104 (MW) /      0.835 (MB)
# 	Size of irrep 1 of <Ab|Cd> integrals:      0.057 (MW) /      0.453 (MB)
# 	Size of irrep 2 of <Ab|Cd> integrals:      0.057 (MW) /      0.453 (MB)
# 	Size of irrep 3 of <Ab|Cd> integrals:      0.057 (MW) /      0.453 (MB)
# 	Size of irrep 4 of <Ab|Cd> integrals:      0.034 (MW) /      0.271 (MB)
# 	Size of irrep 5 of <Ab|Cd> integrals:      0.072 (MW) /      0.575 (MB)
# 	Size of irrep 6 of <Ab|Cd> integrals:      0.072 (MW) /      0.575 (MB)
# 	Size of irrep 7 of <Ab|Cd> integrals:      0.072 (MW) /      0.575 (MB)
# 	Total:                                     0.524 (MW) /      4.189 (MB)
#
# 	Size of irrep 0 of <IA|BC> integrals:      0.003 (MW) /      0.026 (MB)
# 	Size of irrep 1 of <IA|BC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 2 of <IA|BC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 3 of <IA|BC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 4 of <IA|BC> integrals:      0.000 (MW) /      0.003 (MB)
# 	Size of irrep 5 of <IA|BC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 6 of <IA|BC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 7 of <IA|BC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Total:                                     0.012 (MW) /      0.097 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:      0.003 (MW) /      0.026 (MB)
# 	Size of irrep 1 of <ia|bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 2 of <ia|bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 3 of <ia|bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 4 of <ia|bc> integrals:      0.000 (MW) /      0.003 (MB)
# 	Size of irrep 5 of <ia|bc> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 6 of <ia|bc> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 7 of <ia|bc> integrals:      0.002 (MW) /      0.017 (MB)
# 	Total:                                     0.012 (MW) /      0.097 (MB)
#
# 	Size of irrep 0 of <Ia|Bc> integrals:      0.003 (MW) /      0.026 (MB)
# 	Size of irrep 1 of <Ia|Bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 2 of <Ia|Bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 3 of <Ia|Bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 4 of <Ia|Bc> integrals:      0.000 (MW) /      0.003 (MB)
# 	Size of irrep 5 of <Ia|Bc> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 6 of <Ia|Bc> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 7 of <Ia|Bc> integrals:      0.002 (MW) /      0.017 (MB)
# 	Total:                                     0.012 (MW) /      0.097 (MB)
#
# 	Size of irrep 0 of <iA|bC> integrals:      0.003 (MW) /      0.026 (MB)
# 	Size of irrep 1 of <iA|bC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 2 of <iA|bC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 3 of <iA|bC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 4 of <iA|bC> integrals:      0.000 (MW) /      0.003 (MB)
# 	Size of irrep 5 of <iA|bC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 6 of <iA|bC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 7 of <iA|bC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Total:                                     0.012 (MW) /      0.097 (MB)
#
# 	Size of irrep 0 of tIjAb amplitudes:       0.000 (MW) /      0.003 (MB)
# 	Size of irrep 1 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 2 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 3 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 4 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 5 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 6 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 7 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Total:                                     0.000 (MW) /      0.003 (MB)
#
# 	Nuclear Rep. energy          =      0.00000000000000
# 	SCF energy                   =     -2.86152199563247
# 	One-electron energy          =     -3.88717967507757
# 	Two-electron (AA) energy     =      0.00000000000000
# 	Two-electron (BB) energy     =      0.00000000000000
# 	Two-electron (AB) energy     =      1.02565767944511
# 	Two-electron energy          =      1.02565767944511
# 	Reference energy             =     -2.86152199563247
#
# *** tstop() called on 8e3c8f7b991a at Tue May 26 19:51:33 2026
# Module time:
# 	user time   =       0.11 seconds =       0.00 minutes
# 	system time =       0.12 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.84 seconds =       0.01 minutes
# 	system time =       0.37 seconds =       0.01 minutes
# 	total time  =          2 seconds =       0.03 minutes
#             **************************
#             *                        *
#             *        CCENERGY        *
#             *                        *
#             **************************
#
#     Nuclear Rep. energy (wfn)     =    0.000000000000000
#     SCF energy          (wfn)     =   -2.861521995632467
#     Reference energy    (file100) =   -2.861521995632465
#
#     Input parameters:
#     -----------------
#     Wave function   =     CCSD_T
#     Reference wfn   =     UHF
#     Brueckner       =     No
#     Memory (Mbytes) =     524.3
#     Maxiter         =     50
#     R_Convergence   =     1.0e-07
#     E_Convergence   =     1.0e-06
#     Restart         =     Yes
#     DIIS            =     Yes
#     AO Basis        =     NONE
#     ABCD            =     NEW
#     Cache Level     =     2
#     Cache Type      =     LRU
#     Print Level     =     1
#     Num. of threads =     1
#     # Amps to Print =     10
#     Print MP2 Amps? =     No
#     Analyze T2 Amps =     No
#     Print Pair Ener =     No
#     Local CC        =     No
#     SCS-MP2         =     False
#     SCSN-MP2        =     False
#     SCS-CCSD        =     False
#
# MP2 correlation energy -0.0357241295134033
#                 Solving CC Amplitude Equations
#                 ------------------------------
#   Iter             Energy              RMS        T1Diag      D1Diag    New D1Diag    D2Diag
#   ----     ---------------------    ---------   ----------  ----------  ----------   --------
#      0        -0.035724129513403    0.000e+00    0.000000    0.000000    0.000000    0.000000
#      1        -0.039835587261307    1.317e-02    0.001222    0.000000    0.000000    0.000000
#      2        -0.041005194651459    3.354e-03    0.001778    0.000000    0.000000    0.000000
#      3        -0.041012499822108    5.031e-04    0.002065    0.000000    0.000000    0.000000
#      4        -0.041011931096504    5.873e-05    0.002095    0.000000    0.000000    0.000000
#      5        -0.041011586797575    1.113e-05    0.002101    0.000000    0.000000    0.000000
#      6        -0.041011591306406    1.951e-06    0.002101    0.000000    0.000000    0.000000
#      7        -0.041011604772101    2.819e-07    0.002101    0.000000    0.000000    0.000000
#      8        -0.041011603870357    2.640e-08    0.002101    0.000000    0.000000    0.000000
#
#     Iterations converged.
#
#
#     Largest TIA Amplitudes:
#               0   0        -0.0013303989
#               0   4         0.0013162298
#               0   1        -0.0007357472
#               0   7         0.0006090447
#
#     Largest Tia Amplitudes:
#               0   0        -0.0013303989
#               0   4         0.0013162298
#               0   1        -0.0007357472
#               0   7         0.0006090447
#
#     Largest TIjAb Amplitudes:
#       0   0   1   1        -0.0341283687
#       0   0   4   4        -0.0247274954
#       0   0   1   4        -0.0244027430
#       0   0   4   1        -0.0244027430
#       0   0  22  22        -0.0224260042
#       0   0  30  30        -0.0224260042
#       0   0  38  38        -0.0224260042
#       0   0   0   1        -0.0162098759
#       0   0   1   0        -0.0162098759
#       0   0  21  22         0.0126082076
#
#     SCF energy       (wfn)                    =   -2.861521995632467
#     Reference energy (file100)                =   -2.861521995632465
#
#     Opposite-spin MP2 correlation energy      =   -0.035724129513403
#     Same-spin MP2 correlation energy          =    0.000000000000000
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.035724129513403
#       * MP2 total energy                      =   -2.897246125145868
#
#     Opposite-spin CCSD correlation energy     =   -0.041011603870357
#     Same-spin CCSD correlation energy         =    0.000000000000000
#     Singles CCSD correlation energy           =   -0.000000000000000
#     CCSD correlation energy                   =   -0.041011603870357
#       * CCSD total energy                     =   -2.902533599502823
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      UHF
#
#     Nuclear Rep. energy (wfn)                =    0.000000000000000
#     SCF energy          (wfn)                =   -2.861521995632467
#     Reference energy    (file100)            =   -2.861521995632465
#     CCSD energy         (file100)            =   -0.041011603870357
#     Total CCSD energy   (file100)            =   -2.902533599502823
#
#     Number of ijk index combinations:
#     Spin Case AAA:                                   0
#     Spin Case BBB:                                   0
#     Spin Case AAB:                                   0
#     Spin Case ABB:                                   0
#     AAA (T) energy                             =    0.000000000000000
#     BBB (T) energy                             =    0.000000000000000
#     AAB (T) energy                             =    0.000000000000000
#     ABB (T) energy                             =    0.000000000000000
#     (T) energy                                   =    0.000000000000000
#       * CCSD(T) total energy                     =   -2.902533599502823
#
#
#
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, D. L. Poole, T. Győri, E. C. Mitchell, J. P. Pederson,
#     and A. M. Wallace
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     https://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Tuesday, 26 May 2026 07:51PM
#
#     Process ID: 35317
#     Host:       8e3c8f7b991a
#     PSIDATADIR: /root/mamba/envs/psi4/share/psi4
#     Memory:     500.0 MiB
#     Threads:    1
#     Addons:     a̶d̶c̶c̶, a̶m̶b̶i̶t̶, b̶s̶e̶, c̶c̶t̶3̶, c̶f̶o̶u̶r̶, c̶h̶e̶m̶p̶s̶2̶, c̶p̶p̶e̶, d̶d̶x̶,
#                 d̶f̶t̶d̶3̶, d̶f̶t̶d̶4̶, dkh, ecpint, einsums, f̶o̶r̶t̶e̶, g̶a̶u̶x̶c̶, g̶c̶p̶,
#                 g̶d̶m̶a̶, g̶e̶o̶m̶e̶t̶r̶i̶c̶, g̶p̶u̶_̶d̶f̶c̶c̶, i̶n̶t̶e̶g̶r̶a̶t̶o̶r̶x̶x̶,
#                 i̶p̶i̶, l̶i̶b̶e̶f̶p̶, m̶d̶i̶, m̶p̶2̶d̶, m̶r̶c̶c̶, ooo,
#                 o̶p̶e̶n̶f̶e̶r̶m̶i̶o̶n̶p̶s̶i̶4̶, pcmsolver, p̶s̶i̶4̶f̶o̶c̶k̶c̶i̶, p̶s̶i̶x̶a̶s̶,
#                 r̶e̶s̶p̶, s̶i̶m̶i̶n̶t̶, s̶n̶s̶m̶p̶2̶, v̶2̶r̶d̶m̶_̶c̶a̶s̶s̶c̶f̶
#
#   ==> Input File <==
#
# --------------------------------------------------------------------------
# # >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
#
# # Your input file should go in this middle section
# # Write this as a classic-style Psi4 input file (not a Python script)
#
# import psi4
#
# # Specify the location of the output file
# psi4.core.set_output_file("psi4.out", True)
#
# # Specify the molecular geometry
# molecule = psi4.geometry("""
#    He 0.0 0.0 0.0
# """)
#
# # Set some calculation options
# psi4.set_options({'reference': 'uhf',
#                   'basis': 'aug-cc-pVQZ'})
#
# # Compute the energy at the CCSD(T) level
# psi4.energy('CCSD(T)')
#
# # Print the contents of the output file
# with open("psi4.out", "r") as f:
#     print(f.read())
#
# # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# # STUDENTS SHOULD IGNORE THESE LINES
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 8e3c8f7b991a
# *** at Tue May 26 19:51:31 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVQZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry HE         line    72 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvqz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               UHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          HE           0.000000000000     0.000000000000     0.000000000000     4.002603254130
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B = ************  C = ************ [cm^-1]
#   Rotational constants: A = ************  B = ************  C = ************ [MHz]
#   Nuclear repulsion =    0.000000000000000
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 2
#   Nalpha       = 1
#   Nbeta        = 1
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is CORE.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVQZ
#     Blend: AUG-CC-PVQZ
#     Number of shells: 14
#     Number of basis functions: 46
#     Number of Cartesian functions: 55
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   1
#       Number of AO shells:              14
#       Number of primitives:             17
#       Number of atomic orbitals:        55
#       Number of basis functions:        46
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 1169642 doubles for integral storage.
#   We computed 5565 shell quartets total.
#   Whereas there are 5565 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.1408536236E-02.
#   Reciprocal condition number of the overlap matrix is 1.0427704434E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Core (One-Electron) Hamiltonian.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      Ag        11      11       1       1       1       0
#      B1g        3       3       0       0       0       0
#      B2g        3       3       0       0       0       0
#      B3g        3       3       0       0       0       0
#      Au         2       2       0       0       0       0
#      B1u        8       8       0       0       0       0
#      B2u        8       8       0       0       0       0
#      B3u        8       8       0       0       0       0
#    -------------------------------------------------------
#     Total      46      46       1       1       1       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @UHF iter   1:    -2.75016263784500   -2.75016e+00   2.86195e-02 ADIIS/DIIS
#    @UHF iter   2:    -2.86014262105557   -1.09980e-01   2.51385e-03 ADIIS/DIIS
#    @UHF iter   3:    -2.86150171956953   -1.35910e-03   3.15698e-04 ADIIS/DIIS
#    @UHF iter   4:    -2.86152183206415   -2.01125e-05   2.38541e-05 DIIS
#    @UHF iter   5:    -2.86152199533983   -1.63276e-07   9.29420e-07 DIIS
#    @UHF iter   6:    -2.86152199562991   -2.90077e-10   8.01815e-08 DIIS
#    @UHF iter   7:    -2.86152199563247   -2.56062e-12   3.16726e-10 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    @Spin Contamination Metric
F
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 Ag	   11	    0	    1	    0	    10	    0
# 	 B1g	   3	    0	    0	    0	    3	    0
# 	 B2g	   3	    0	    0	    0	    3	    0
# 	 B3g	   3	    0	    0	    0	    3	    0
# 	 Au	   2	    0	    0	    0	    2	    0
# 	 B1u	   8	    0	    0	    0	    8	    0
# 	 B2u	   8	    0	    0	    0	    8	    0
# 	 B3u	   8	    0	    0	    0	    8	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =      0.00000000000000
#
# 	Size of irrep 0 of <AB|CD> integrals:      0.019 (MW) /      0.155 (MB)
# 	Size of irrep 1 of <AB|CD> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 2 of <AB|CD> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 3 of <AB|CD> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 4 of <AB|CD> integrals:      0.008 (MW) /      0.068 (MB)
# 	Size of irrep 5 of <AB|CD> integrals:      0.018 (MW) /      0.144 (MB)
# 	Size of irrep 6 of <AB|CD> integrals:      0.018 (MW) /      0.144 (MB)
# 	Size of irrep 7 of <AB|CD> integrals:      0.018 (MW) /      0.144 (MB)
# 	Total:                                     0.124 (MW) /      0.993 (MB)
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.019 (MW) /      0.155 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.014 (MW) /      0.113 (MB)
# 	Size of irrep 4 of <ab|cd> integrals:      0.008 (MW) /      0.068 (MB)
# 	Size of irrep 5 of <ab|cd> integrals:      0.018 (MW) /      0.144 (MB)
# 	Size of irrep 6 of <ab|cd> integrals:      0.018 (MW) /      0.144 (MB)
# 	Size of irrep 7 of <ab|cd> integrals:      0.018 (MW) /      0.144 (MB)
# 	Total:                                     0.124 (MW) /      0.993 (MB)
#
# 	Size of irrep 0 of <Ab|Cd> integrals:      0.104 (MW) /      0.835 (MB)
# 	Size of irrep 1 of <Ab|Cd> integrals:      0.057 (MW) /      0.453 (MB)
# 	Size of irrep 2 of <Ab|Cd> integrals:      0.057 (MW) /      0.453 (MB)
# 	Size of irrep 3 of <Ab|Cd> integrals:      0.057 (MW) /      0.453 (MB)
# 	Size of irrep 4 of <Ab|Cd> integrals:      0.034 (MW) /      0.271 (MB)
# 	Size of irrep 5 of <Ab|Cd> integrals:      0.072 (MW) /      0.575 (MB)
# 	Size of irrep 6 of <Ab|Cd> integrals:      0.072 (MW) /      0.575 (MB)
# 	Size of irrep 7 of <Ab|Cd> integrals:      0.072 (MW) /      0.575 (MB)
# 	Total:                                     0.524 (MW) /      4.189 (MB)
#
# 	Size of irrep 0 of <IA|BC> integrals:      0.003 (MW) /      0.026 (MB)
# 	Size of irrep 1 of <IA|BC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 2 of <IA|BC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 3 of <IA|BC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 4 of <IA|BC> integrals:      0.000 (MW) /      0.003 (MB)
# 	Size of irrep 5 of <IA|BC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 6 of <IA|BC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 7 of <IA|BC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Total:                                     0.012 (MW) /      0.097 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:      0.003 (MW) /      0.026 (MB)
# 	Size of irrep 1 of <ia|bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 2 of <ia|bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 3 of <ia|bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 4 of <ia|bc> integrals:      0.000 (MW) /      0.003 (MB)
# 	Size of irrep 5 of <ia|bc> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 6 of <ia|bc> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 7 of <ia|bc> integrals:      0.002 (MW) /      0.017 (MB)
# 	Total:                                     0.012 (MW) /      0.097 (MB)
#
# 	Size of irrep 0 of <Ia|Bc> integrals:      0.003 (MW) /      0.026 (MB)
# 	Size of irrep 1 of <Ia|Bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 2 of <Ia|Bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 3 of <Ia|Bc> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 4 of <Ia|Bc> integrals:      0.000 (MW) /      0.003 (MB)
# 	Size of irrep 5 of <Ia|Bc> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 6 of <Ia|Bc> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 7 of <Ia|Bc> integrals:      0.002 (MW) /      0.017 (MB)
# 	Total:                                     0.012 (MW) /      0.097 (MB)
#
# 	Size of irrep 0 of <iA|bC> integrals:      0.003 (MW) /      0.026 (MB)
# 	Size of irrep 1 of <iA|bC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 2 of <iA|bC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 3 of <iA|bC> integrals:      0.001 (MW) /      0.006 (MB)
# 	Size of irrep 4 of <iA|bC> integrals:      0.000 (MW) /      0.003 (MB)
# 	Size of irrep 5 of <iA|bC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 6 of <iA|bC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Size of irrep 7 of <iA|bC> integrals:      0.002 (MW) /      0.017 (MB)
# 	Total:                                     0.012 (MW) /      0.097 (MB)
#
# 	Size of irrep 0 of tIjAb amplitudes:       0.000 (MW) /      0.003 (MB)
# 	Size of irrep 1 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 2 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 3 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 4 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 5 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 6 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 7 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Total:                                     0.000 (MW) /      0.003 (MB)
#
# 	Nuclear Rep. energy          =      0.00000000000000
# 	SCF energy                   =     -2.86152199563247
# 	One-electron energy          =     -3.88717967507757
# 	Two-electron (AA) energy     =      0.00000000000000
# 	Two-electron (BB) energy     =      0.00000000000000
# 	Two-electron (AB) energy     =      1.02565767944511
# 	Two-electron energy          =      1.02565767944511
# 	Reference energy             =     -2.86152199563247
#
# *** tstop() called on 8e3c8f7b991a at Tue May 26 19:51:33 2026
# Module time:
# 	user time   =       0.11 seconds =       0.00 minutes
# 	system time =       0.12 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.84 seconds =       0.01 minutes
# 	system time =       0.37 seconds =       0.01 minutes
# 	total time  =          2 seconds =       0.03 minutes
#             **************************
#             *                        *
#             *        CCENERGY        *
#             *                        *
#             **************************
#
#     Nuclear Rep. energy (wfn)     =    0.000000000000000
#     SCF energy          (wfn)     =   -2.861521995632467
#     Reference energy    (file100) =   -2.861521995632465
#
#     Input parameters:
#     -----------------
#     Wave function   =     CCSD_T
#     Reference wfn   =     UHF
#     Brueckner       =     No
#     Memory (Mbytes) =     524.3
#     Maxiter         =     50
#     R_Convergence   =     1.0e-07
#     E_Convergence   =     1.0e-06
#     Restart         =     Yes
#     DIIS            =     Yes
#     AO Basis        =     NONE
#     ABCD            =     NEW
#     Cache Level     =     2
#     Cache Type      =     LRU
#     Print Level     =     1
#     Num. of threads =     1
#     # Amps to Print =     10
#     Print MP2 Amps? =     No
#     Analyze T2 Amps =     No
#     Print Pair Ener =     No
#     Local CC        =     No
#     SCS-MP2         =     False
#     SCSN-MP2        =     False
#     SCS-CCSD        =     False
#
# MP2 correlation energy -0.0357241295134033
#                 Solving CC Amplitude Equations
#                 ------------------------------
#   Iter             Energy              RMS        T1Diag      D1Diag    New D1Diag    D2Diag
#   ----     ---------------------    ---------   ----------  ----------  ----------   --------
#      0        -0.035724129513403    0.000e+00    0.000000    0.000000    0.000000    0.000000
#      1        -0.039835587261307    1.317e-02    0.001222    0.000000    0.000000    0.000000
#      2        -0.041005194651459    3.354e-03    0.001778    0.000000    0.000000    0.000000
#      3        -0.041012499822108    5.031e-04    0.002065    0.000000    0.000000    0.000000
#      4        -0.041011931096504    5.873e-05    0.002095    0.000000    0.000000    0.000000
#      5        -0.041011586797575    1.113e-05    0.002101    0.000000    0.000000    0.000000
#      6        -0.041011591306406    1.951e-06    0.002101    0.000000    0.000000    0.000000
#      7        -0.041011604772101    2.819e-07    0.002101    0.000000    0.000000    0.000000
#      8        -0.041011603870357    2.640e-08    0.002101    0.000000    0.000000    0.000000
#
#     Iterations converged.
#
#
#     Largest TIA Amplitudes:
#               0   0        -0.0013303989
#               0   4         0.0013162298
#               0   1        -0.0007357472
#               0   7         0.0006090447
#
#     Largest Tia Amplitudes:
#               0   0        -0.0013303989
#               0   4         0.0013162298
#               0   1        -0.0007357472
#               0   7         0.0006090447
#
#     Largest TIjAb Amplitudes:
#       0   0   1   1        -0.0341283687
#       0   0   4   4        -0.0247274954
#       0   0   1   4        -0.0244027430
#       0   0   4   1        -0.0244027430
#       0   0  22  22        -0.0224260042
#       0   0  30  30        -0.0224260042
#       0   0  38  38        -0.0224260042
#       0   0   0   1        -0.0162098759
#       0   0   1   0        -0.0162098759
#       0   0  21  22         0.0126082076
#
#     SCF energy       (wfn)                    =   -2.861521995632467
#     Reference energy (file100)                =   -2.861521995632465
#
#     Opposite-spin MP2 correlation energy      =   -0.035724129513403
#     Same-spin MP2 correlation energy          =    0.000000000000000
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.035724129513403
#       * MP2 total energy                      =   -2.897246125145868
#
#     Opposite-spin CCSD correlation energy     =   -0.041011603870357
#     Same-spin CCSD correlation energy         =    0.000000000000000
#     Singles CCSD correlation energy           =   -0.000000000000000
#     CCSD correlation energy                   =   -0.041011603870357
#       * CCSD total energy                     =   -2.902533599502823
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      UHF
#
#     Nuclear Rep. energy (wfn)                =    0.000000000000000
#     SCF energy          (wfn)                =   -2.861521995632467
#     Reference energy    (file100)            =   -2.861521995632465
#     CCSD energy         (file100)            =   -0.041011603870357
#     Total CCSD energy   (file100)            =   -2.902533599502823
#
#     Number of ijk index combinations:
#     Spin Case AAA:                                   0
#     Spin Case BBB:                                   0
#     Spin Case AAB:                                   0
#     Spin Case ABB:                                   0
#     AAA (T) energy                             =    0.000000000000000
#     BBB (T) energy                             =    0.000000000000000
#     AAB (T) energy                             =    0.000000000000000
#     ABB (T) energy                             =    0.000000000000000
#     (T) energy                                   =    0.000000000000000
#       * CCSD(T) total energy                     =   -2.902533599502823
#
#
#     Psi4 stopped on: Tuesday, 26 May 2026 07:51PM
#     Psi4 wall time for execution: 0:00:02.39
#
# *** Psi4 exiting successfully. Buy a developer a beer!

# %% [markdown]
# # H2

# %%
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
# %%bash
set -euo pipefail
MAMBA_ROOT="$HOME/mamba"
MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
cat > psi4.in <<'EOF'
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>


# Your input file should go in this middle section
# Write this as a classic-style Psi4 input file (not a Python script)

# Specify the molecular geometry
molecule {
   H 0.0 0.0 0.0
   H 0.4 0.0 0.0
}

set {
  basis aug-cc-pVQZ
  reference uhf
}

# Compute the energy at the CCSD(T) level
energy('CCSD(T)')


# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
EOF
"$MAMBA_BIN" run -r "$MAMBA_ROOT" -n psi4 psi4 psi4.in psi4.out
cat psi4.out
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Out:
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, D. L. Poole, T. Győri, E. C. Mitchell, J. P. Pederson,
#     and A. M. Wallace
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     https://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Tuesday, 26 May 2026 08:13PM
#
#     Process ID: 40721
#     Host:       8e3c8f7b991a
#     PSIDATADIR: /root/mamba/envs/psi4/share/psi4
#     Memory:     500.0 MiB
#     Threads:    1
#     Addons:     a̶d̶c̶c̶, a̶m̶b̶i̶t̶, b̶s̶e̶, c̶c̶t̶3̶, c̶f̶o̶u̶r̶, c̶h̶e̶m̶p̶s̶2̶, c̶p̶p̶e̶, d̶d̶x̶,
#                 d̶f̶t̶d̶3̶, d̶f̶t̶d̶4̶, dkh, ecpint, einsums, f̶o̶r̶t̶e̶, g̶a̶u̶x̶c̶, g̶c̶p̶,
#                 g̶d̶m̶a̶, g̶e̶o̶m̶e̶t̶r̶i̶c̶, g̶p̶u̶_̶d̶f̶c̶c̶, i̶n̶t̶e̶g̶r̶a̶t̶o̶r̶x̶x̶,
#                 i̶p̶i̶, l̶i̶b̶e̶f̶p̶, m̶d̶i̶, m̶p̶2̶d̶, m̶r̶c̶c̶, ooo,
#                 o̶p̶e̶n̶f̶e̶r̶m̶i̶o̶n̶p̶s̶i̶4̶, pcmsolver, p̶s̶i̶4̶f̶o̶c̶k̶c̶i̶, p̶s̶i̶x̶a̶s̶,
#                 r̶e̶s̶p̶, s̶i̶m̶i̶n̶t̶, s̶n̶s̶m̶p̶2̶, v̶2̶r̶d̶m̶_̶c̶a̶s̶s̶c̶f̶
#
#   ==> Input File <==
#
# --------------------------------------------------------------------------
# # >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
#
# # Your input file should go in this middle section
# # Write this as a classic-style Psi4 input file (not a Python script)
#
# # Specify the molecular geometry
# molecule {
#    H 0.0 0.0 0.0
#    H 0.4 0.0 0.0
# }
#
# set {
#   basis aug-cc-pVQZ
#   reference uhf
# }
#
# # Compute the energy at the CCSD(T) level
# energy('CCSD(T)')
#
#
# # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# # STUDENTS SHOULD IGNORE THESE LINES
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 8e3c8f7b991a
# *** at Tue May 26 20:13:56 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVQZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvqz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               UHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Full point group: D_inf_h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          H           -0.200000000000    -0.000000000000     0.000000000000     1.007825032230
#          H            0.200000000000     0.000000000000     0.000000000000     1.007825032230
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B
0.0000000
#
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on 8e3c8f7b991a at Tue May 26 20:13:59 2026
# Module time:
# 	user time   =       2.22 seconds =       0.04 minutes
# 	system time =       0.56 seconds =       0.01 minutes
# 	total time  =          3 seconds =       0.05 minutes
# Total time:
# 	user time   =       2.22 seconds =       0.04 minutes
# 	system time =       0.56 seconds =       0.01 minutes
# 	total time  =          3 seconds =       0.05 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:              28
#       Number of SO shells:              14
#       Number of primitives:             32
#       Number of atomic orbitals:       110
#       Number of basis functions:        92
#
#       Number of irreps:                  8
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [  19   11   11    5    5   11   11   19 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 1170661 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on 8e3c8f7b991a
# *** at Tue May 26 20:14:00 2026
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 8
# 	Number of MOs        = 92
# 	Number of active MOs = 92
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = UHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 Ag	   19	    0	    1	    0	    18	    0
# 	 B1g	   11	    0	    0	    0	    11	    0
# 	 B2g	   11	    0	    0	    0	    11	    0
# 	 B3g	   5	    0	    0	    0	    5	    0
# 	 Au	   5	    0	    0	    0	    5	    0
# 	 B1u	   11	    0	    0	    0	    11	    0
# 	 B2u	   11	    0	    0	    0	    11	    0
# 	 B3u	   19	    0	    0	    0	    19	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =      0.00000000000000
#
# 	Size of irrep 0 of <AB|CD> integrals:      0.318 (MW) /      2.545 (MB)
# 	Size of irrep 1 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 2 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 3 of <AB|CD> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 4 of <AB|CD> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 5 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 6 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 7 of <AB|CD> integrals:      0.371 (MW) /      2.967 (MB)
# 	Total:                                     2.123 (MW) /     16.982 (MB)
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.318 (MW) /      2.545 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 4 of <ab|cd> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 5 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 6 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 7 of <ab|cd> integrals:      0.371 (MW) /      2.967 (MB)
# 	Total:                                     2.123 (MW) /     16.982 (MB)
#
# 	Size of irrep 0 of <Ab|Cd> integrals:      1.486 (MW) /     11.888 (MB)
# 	Size of irrep 1 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 2 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 3 of <Ab|Cd> integrals:      0.729 (MW) /      5.835 (MB)
# 	Size of irrep 4 of <Ab|Cd> integrals:      0.729 (MW) /      5.835 (MB)
# 	Size of irrep 5 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 6 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 7 of <Ab|Cd> integrals:      1.484 (MW) /     11.868 (MB)
# 	Total:                                     8.705 (MW) /     69.638 (MB)
#
# 	Size of irrep 0 of <IA|BC> integrals:      0.022 (MW) /      0.176 (MB)
# 	Size of irrep 1 of <IA|BC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 2 of <IA|BC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 3 of <IA|BC> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 4 of <IA|BC> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 5 of <IA|BC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 6 of <IA|BC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 7 of <IA|BC> integrals:      0.023 (MW) /      0.185 (MB)
# 	Total:                                     0.099 (MW) /      0.793 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:      0.022 (MW) /      0.176 (MB)
# 	Size of irrep 1 of <ia|bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 2 of <ia|bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 3 of <ia|bc> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 4 of <ia|bc> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 5 of <ia|bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 6 of <ia|bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 7 of <ia|bc> integrals:      0.023 (MW) /      0.185 (MB)
# 	Total:                                     0.099 (MW) /      0.793 (MB)
#
# 	Size of irrep 0 of <Ia|Bc> integrals:      0.022 (MW) /      0.176 (MB)
# 	Size of irrep 1 of <Ia|Bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 2 of <Ia|Bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 3 of <Ia|Bc> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 4 of <Ia|Bc> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 5 of <Ia|Bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 6 of <Ia|Bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 7 of <Ia|Bc> integrals:      0.023 (MW) /      0.185 (MB)
# 	Total:                                     0.099 (MW) /      0.793 (MB)
#
# 	Size of irrep 0 of <iA|bC> integrals:      0.022 (MW) /      0.176 (MB)
# 	Size of irrep 1 of <iA|bC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 2 of <iA|bC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 3 of <iA|bC> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 4 of <iA|bC> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 5 of <iA|bC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 6 of <iA|bC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 7 of <iA|bC> integrals:      0.023 (MW) /      0.185 (MB)
# 	Total:                                     0.099 (MW) /      0.793 (MB)
#
# 	Size of irrep 0 of tIjAb amplitudes:       0.001 (MW) /      0.010 (MB)
# 	Size of irrep 1 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 2 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 3 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 4 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 5 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 6 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 7 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Total:                                     0.001 (MW) /      0.010 (MB)
#
# 	Nuclear Rep. energy          =      1.32294302667500
# 	SCF energy                   =     -0.94224812453371
# 	One-electron energy          =     -3.07545613597702
# 	Two-electron (AA) energy     =      0.00000000000000
# 	Two-electron (BB) energy     =      0.00000000000000
# 	Two-electron (AB) energy     =      0.81026498476825
# 	Two-electron energy          =      0.81026498476825
# 	Reference energy             =     -0.94224812453377
#
# *** tstop() called on 8e3c8f7b991a at Tue May 26 20:14:04 2026
# Module time:
# 	user time   =       1.99 seconds =       0.03 minutes
# 	system time =       2.00 seconds =       0.03 minutes
# 	total time  =          4 seconds =       0.07 minutes
# Total time:
# 	user time   =       4.70 seconds =       0.08 minutes
# 	system time =       2.58 seconds =       0.04 minutes
# 	total time  =          8 seconds =       0.13 minutes
#             **************************
#             *                        *
#             *        CCENERGY        *
#             *                        *
#             **************************
#
#     Nuclear Rep. energy (wfn)     =    1.322943026675000
#     SCF energy          (wfn)     =   -0.942248124533713
#     Reference energy    (file100) =   -0.942248124533768
#
#     Input parameters:
#     -----------------
#     Wave function   =     CCSD_T
#     Reference wfn   =     UHF
#     Brueckner       =     No
#     Memory (Mbytes) =     524.3
#     Maxiter         =     50
#     R_Convergence   =     1.0e-07
#     E_Convergence   =     1.0e-06
#     Restart         =     Yes
#     DIIS            =     Yes
#     AO Basis        =     NONE
#     ABCD            =     NEW
#     Cache Level     =     2
#     Cache Type      =     LRU
#     Print Level     =     1
#     Num. of threads =     1
#     # Amps to Print =     10
#     Print MP2 Amps? =     No
#     Analyze T2 Amps =     No
#     Print Pair Ener =     No
#     Local CC        =     No
#     SCS-MP2         =     False
#     SCSN-MP2        =     False
#     SCS-CCSD        =     False
#
# MP2 correlation energy -0.0330992968341636
#                 Solving CC Amplitude Equations
#                 ------------------------------
#   Iter             Energy              RMS        T1Diag      D1Diag    New D1Diag    D2Diag
#   ----     ---------------------    ---------   ----------  ----------  ----------   --------
#      0        -0.033099296834164    0.000e+00    0.000000    0.000000    0.000000    0.000000
#      1        -0.037173641901064    1.680e-02    0.002149    0.000000    0.000000    0.000000
#      2        -0.038625137324134    4.584e-03    0.002470    0.000000    0.000000    0.000000
#      3        -0.038623196724522    4.059e-04    0.002323    0.000000    0.000000    0.000000
#      4        -0.038626109332617    9.577e-05    0.002292    0.000000    0.000000    0.000000
#      5        -0.038626198891535    1.670e-05    0.002287    0.000000    0.000000    0.000000
#      6        -0.038626078086797    3.069e-06    0.002287    0.000000    0.000000    0.000000
#      7        -0.038626094120254    7.300e-07    0.002287    0.000000    0.000000    0.000000
#      8        -0.038626100009247    1.259e-07    0.002287    0.000000    0.000000    0.000000
#      9        -0.038626099768717    2.349e-08    0.002287    0.000000    0.000000    0.000000
#
#     Iterations converged.
#
#
#     Largest TIA Amplitudes:
#               0   6         0.0012811476
#               0   2         0.0011097219
#               0   5         0.0010635733
#               0  11        -0.0006791795
#               0   4        -0.0005891056
#               0  12        -0.0003812422
#               0   0         0.0003622827
#               0   1         0.0002289815
#               0  10        -0.0002165437
#               0  16         0.0001560952
#
#     Largest Tia Amplitudes:
#               0   6         0.0012811476
#               0   2         0.0011097219
#               0   5         0.0010635733
#               0  11        -0.0006791795
#               0   4        -0.0005891056
#               0  12        -0.0003812422
#               0   0         0.0003622827
#               0   1         0.0002289815
#               0  10        -0.0002165437
#               0  16         0.0001560952
#
#     Largest TIjAb Amplitudes:
#       0   0  52  52        -0.0240199061
#       0   0  63  63        -0.0240199061
#       0   0   5   5        -0.0228454416
#       0   0   2   5        -0.0193877771
#       0   0   5   2        -0.0193877771
#       0   0   2   2        -0.0189512539
#       0   0  77  77        -0.0166842733
#       0   0  52  55         0.0158544254
#       0   0  55  52         0.0158544254
#       0   0  63  66         0.0158544254
#
#     SCF energy       (wfn)                    =   -0.942248124533713
#     Reference energy (file100)                =   -0.942248124533768
#
#     Opposite-spin MP2 correlation energy      =   -0.033099296834164
#     Same-spin MP2 correlation energy          =    0.000000000000000
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.033099296834164
#       * MP2 total energy                      =   -0.975347421367932
#
#     Opposite-spin CCSD correlation energy     =   -0.038626099768717
#     Same-spin CCSD correlation energy         =    0.000000000000000
#     Singles CCSD correlation energy           =    0.000000000000000
#     CCSD correlation energy                   =   -0.038626099768717
#       * CCSD total energy                     =   -0.980874224302485
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      UHF
#
#     Nuclear Rep. energy (wfn)                =    1.322943026675000
#     SCF energy          (wfn)                =   -0.942248124533713
#     Reference energy    (file100)            =   -0.942248124533768
#     CCSD energy         (file100)            =   -0.038626099768717
#     Total CCSD energy   (file100)            =   -0.980874224302485
#
#     Number of ijk index combinations:
#     Spin Case AAA:                                   0
#     Spin Case BBB:                                   0
#     Spin Case AAB:                                   0
#     Spin Case ABB:                                   0
#     AAA (T) energy                             =    0.000000000000000
#     BBB (T) energy                             =    0.000000000000000
#     AAB (T) energy                             =    0.000000000000000
#     ABB (T) energy                             =    0.000000000000000
#     (T) energy                                   =    0.000000000000000
#       * CCSD(T) total energy                     =   -0.980874224302485
#
#
#     Psi4 stopped on: Tuesday, 26 May 2026 08:14PM
#     Psi4 wall time for execution: 0:00:08.59
#
# *** Psi4 exiting successfully. Buy a developer a beer!

# %% [markdown]
# ## Mais de um cálculo de Energia por vez - Energia Potencial (variando a distância entre os átomos de H)

# %%
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
# %%bash
set -euo pipefail
MAMBA_ROOT="$HOME/mamba"
MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
cat > psi4.in <<'EOF'
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>


# Your input file should go in this middle section
# Write this as a classic-style Psi4 input file (not a Python script)

# Specify the molecular geometry
# molecula 1
molecule {
   H 0.0 0.0 0.0
   H 0.4 0.0 0.0
}

set {
  basis aug-cc-pVQZ
  reference uhf
}

# Compute the energy at the CCSD(T) level
energy('CCSD(T)')

# molecula 2
molecule {
   H 0.0 0.0 0.0
   H 0.6 0.0 0.0
}

energy('CCSD(T)')

# molecula 3
molecule {
   H 0.0 0.0 0.0
   H 0.7 0.0 0.0
}
energy('CCSD(T)')



# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
EOF
"$MAMBA_BIN" run -r "$MAMBA_ROOT" -n psi4 psi4 psi4.in psi4.out
cat psi4.out
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Out:
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, D. L. Poole, T. Győri, E. C. Mitchell, J. P. Pederson,
#     and A. M. Wallace
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     https://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Tuesday, 26 May 2026 08:17PM
#
#     Process ID: 41581
#     Host:       8e3c8f7b991a
#     PSIDATADIR: /root/mamba/envs/psi4/share/psi4
#     Memory:     500.0 MiB
#     Threads:    1
#     Addons:     a̶d̶c̶c̶, a̶m̶b̶i̶t̶, b̶s̶e̶, c̶c̶t̶3̶, c̶f̶o̶u̶r̶, c̶h̶e̶m̶p̶s̶2̶, c̶p̶p̶e̶, d̶d̶x̶,
#                 d̶f̶t̶d̶3̶, d̶f̶t̶d̶4̶, dkh, ecpint, einsums, f̶o̶r̶t̶e̶, g̶a̶u̶x̶c̶, g̶c̶p̶,
#                 g̶d̶m̶a̶, g̶e̶o̶m̶e̶t̶r̶i̶c̶, g̶p̶u̶_̶d̶f̶c̶c̶, i̶n̶t̶e̶g̶r̶a̶t̶o̶r̶x̶x̶,
#                 i̶p̶i̶, l̶i̶b̶e̶f̶p̶, m̶d̶i̶, m̶p̶2̶d̶, m̶r̶c̶c̶, ooo,
#                 o̶p̶e̶n̶f̶e̶r̶m̶i̶o̶n̶p̶s̶i̶4̶, pcmsolver, p̶s̶i̶4̶f̶o̶c̶k̶c̶i̶, p̶s̶i̶x̶a̶s̶,
#                 r̶e̶s̶p̶, s̶i̶m̶i̶n̶t̶, s̶n̶s̶m̶p̶2̶, v̶2̶r̶d̶m̶_̶c̶a̶s̶s̶c̶f̶
#
#   ==> Input File <==
#
# --------------------------------------------------------------------------
# # >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
#
# # Your input file should go in this middle section
# # Write this as a classic-style Psi4 input file (not a Python script)
#
# # Specify the molecular geometry
# # molecula 1
# molecule {
#    H 0.0 0.0 0.0
#    H 0.4 0.0 0.0
# }
#
# set {
#   basis aug-cc-pVQZ
#   reference uhf
# }
#
# # Compute the energy at the CCSD(T) level
# energy('CCSD(T)')
#
# # molecula 2
# molecule {
#    H 0.0 0.0 0.0
#    H 0.6 0.0 0.0
# }
#
# energy('CCSD(T)')
#
# # molecula 3
# molecule {
#    H 0.0 0.0 0.0
#    H 0.7 0.0 0.0
# }
# energy('CCSD(T)')
#
#
#
# # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# # STUDENTS SHOULD IGNORE THESE LINES
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 8e3c8f7b991a
# *** at Tue May 26 20:17:26 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVQZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvqz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               UHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Full point group: D_inf_h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          H           -0.200000000000    -0.000000000000     0.000000000000     1.007825032230
#          H            0.200000000000     0.000000000000     0.000000000000     1.007825032230
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B =    209.08427  C =    209.08427 [cm^-1]
#   Rotational constants: A = ************  B = 6268188.83096  C = 6268188.83096 [MHz]
#   Nuclear repulsion =    1.322943026675000
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 2
#   Nalpha       = 1
#   Nbeta        = 1
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVQZ
#     Blend: AUG-CC-PVQZ
#     Number of shells: 28
#     Number of basis functions: 92
#     Number of Cartesian functions: 110
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              28
#       Number of primitives:             32
#       Number of atomic orbitals:       110
#       Number of basis functions:        92
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 18305562 doubles for integral storage.
#   We computed 82621 shell quartets total.
#   Whereas there are 82621 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 1
F
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 Ag	   19	    0	    1	    0	    18	    0
# 	 B1g	   11	    0	    0	    0	    11	    0
# 	 B2g	   11	    0	    0	    0	    11	    0
# 	 B3g	   5	    0	    0	    0	    5	    0
# 	 Au	   5	    0	    0	    0	    5	    0
# 	 B1u	   11	    0	    0	    0	    11	    0
# 	 B2u	   11	    0	    0	    0	    11	    0
# 	 B3u	   19	    0	    0	    0	    19	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =      0.00000000000000
#
# 	Size of irrep 0 of <AB|CD> integrals:      0.318 (MW) /      2.545 (MB)
# 	Size of irrep 1 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 2 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 3 of <AB|CD> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 4 of <AB|CD> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 5 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 6 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 7 of <AB|CD> integrals:      0.371 (MW) /      2.967 (MB)
# 	Total:                                     2.123 (MW) /     16.982 (MB)
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.318 (MW) /      2.545 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 4 of <ab|cd> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 5 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 6 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 7 of <ab|cd> integrals:      0.371 (MW) /      2.967 (MB)
# 	Total:                                     2.123 (MW) /     16.982 (MB)
#
# 	Size of irrep 0 of <Ab|Cd> integrals:      1.486 (MW) /     11.888 (MB)
# 	Size of irrep 1 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 2 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 3 of <Ab|Cd> integrals:      0.729 (MW) /      5.835 (MB)
# 	Size of irrep 4 of <Ab|Cd> integrals:      0.729 (MW) /      5.835 (MB)
# 	Size of irrep 5 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 6 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 7 of <Ab|Cd> integrals:      1.484 (MW) /     11.868 (MB)
# 	Total:                                     8.705 (MW) /     69.638 (MB)
#
# 	Size of irrep 0 of <IA|BC> integrals:      0.022 (MW) /      0.176 (MB)
# 	Size of irrep 1 of <IA|BC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 2 of <IA|BC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 3 of <IA|BC> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 4 of <IA|BC> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 5 of <IA|BC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 6 of <IA|BC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 7 of <IA|BC> integrals:      0.023 (MW) /      0.185 (MB)
# 	Total:                                     0.099 (MW) /      0.793 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:      0.022 (MW) /      0.176 (MB)
# 	Size of irrep 1 of <ia|bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 2 of <ia|bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 3 of <ia|bc> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 4 of <ia|bc> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 5 of <ia|bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 6 of <ia|bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 7 of <ia|bc> integrals:      0.023 (MW) /      0.185 (MB)
# 	Total:                                     0.099 (MW) /      0.793 (MB)
#
# 	Size of irrep 0 of <Ia|Bc> integrals:      0.022 (MW) /      0.176 (MB)
# 	Size of irrep 1 of <Ia|Bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 2 of <Ia|Bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 3 of <Ia|Bc> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 4 of <Ia|Bc> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 5 of <Ia|Bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 6 of <Ia|Bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 7 of <Ia|Bc> integrals:      0.023 (MW) /      0.185 (MB)
# 	Total:                                     0.099 (MW) /      0.793 (MB)
#
# 	Size of irrep 0 of <iA|bC> integrals:      0.022 (MW) /      0.176 (MB)
# 	Size of irrep 1 of <iA|bC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 2 of <iA|bC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 3 of <iA|bC> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 4 of <iA|bC> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 5 of <iA|bC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 6 of <iA|bC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 7 of <iA|bC> integrals:      0.023 (MW) /      0.185 (MB)
# 	Total:                                     0.099 (MW) /      0.793 (MB)
#
# 	Size of irrep 0 of tIjAb amplitudes:       0.001 (MW) /      0.010 (MB)
# 	Size of irrep 1 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 2 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 3 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 4 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 5 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 6 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 7 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Total:                                     0.001 (MW) /      0.010 (MB)
#
# 	Nuclear Rep. energy          =      1.32294302667500
# 	SCF energy                   =     -0.94224812453371
# 	One-electron energy          =     -3.07545613597702
# 	Two-electron (AA) energy     =      0.00000000000000
# 	Two-electron (BB) energy     =      0.00000000000000
# 	Two-electron (AB) energy     =      0.81026498476825
# 	Two-electron energy          =      0.81026498476825
# 	Reference energy             =     -0.94224812453377
#
# *** tstop() called on 8e3c8f7b991a at Tue May 26 20:17:31 2026
# Module time:
# 	user time   =       1.43 seconds =       0.02 minutes
# 	system time =       1.11 seconds =       0.02 minutes
# 	total time  =          3 seconds =       0.05 minutes
# Total time:
# 	user time   =       4.01 seconds =       0.07 minutes
# 	system time =       1.36 seconds =       0.02 minutes
# 	total time  =          5 seconds =       0.08 minutes
#             **************************
#             *                        *
#             *        CCENERGY        *
#             *                        *
#             **************************
#
#     Nuclear Rep. energy (wfn)     =    1.322943026675000
#     SCF energy          (wfn)     =   -0.942248124533713
#     Reference energy    (file100) =   -0.942248124533768
#
#     Input parameters:
#     -----------------
#     Wave function   =     CCSD_T
#     Reference wfn   =     UHF
#     Brueckner       =     No
#     Memory (Mbytes) =     524.3
#     Maxiter         =     50
#     R_Convergence   =     1.0e-07
#     E_Convergence   =     1.0e-06
#     Restart         =     Yes
#     DIIS            =     Yes
#     AO Basis        =     NONE
#     ABCD            =     NEW
#     Cache Level     =     2
#     Cache Type      =     LRU
#     Print Level     =     1
#     Num. of threads =     1
#     # Amps to Print =     10
#     Print MP2 Amps? =     No
#     Analyze T2 Amps =     No
#     Print Pair Ener =     No
#     Local CC        =     No
#     SCS-MP2         =     False
#     SCSN-MP2        =     False
#     SCS-CCSD        =     False
#
# MP2 correlation energy -0.0330992968341636
#                 Solving CC Amplitude Equations
#                 ------------------------------
#   Iter             Energy              RMS        T1Diag      D1Diag    New D1Diag    D2Diag
#   ----     ---------------------    ---------   ----------  ----------  ----------   --------
#      0        -0.033099296834164    0.000e+00    0.000000    0.000000    0.000000    0.000000
#      1        -0.037173641901064    1.680e-02    0.002149    0.000000    0.000000    0.000000
#      2        -0.038625137324134    4.584e-03    0.002470    0.000000    0.000000    0.000000
#      3        -0.038623196724522    4.059e-04    0.002323    0.000000    0.000000    0.000000
#      4        -0.038626109332617    9.577e-05    0.002292    0.000000    0.000000    0.000000
#      5        -0.038626198891535    1.670e-05    0.002287    0.000000    0.000000    0.000000
#      6        -0.038626078086797    3.069e-06    0.002287    0.000000    0.000000    0.000000
#      7        -0.038626094120254    7.300e-07    0.002287    0.000000    0.000000    0.000000
#      8        -0.038626100009247    1.259e-07    0.002287    0.000000    0.000000    0.000000
#      9        -0.038626099768717    2.349e-08    0.002287    0.000000    0.000000    0.000000
#
#     Iterations converged.
#
#
#     Largest TIA Amplitudes:
#               0   6         0.0012811476
#               0   2         0.0011097219
#               0   5         0.0010635733
#               0  11        -0.0006791795
#               0   4        -0.0005891056
#               0  12        -0.0003812422
#               0   0         0.0003622827
#               0   1         0.0002289815
#               0  10        -0.0002165437
#               0  16         0.0001560952
#
#     Largest Tia Amplitudes:
#               0   6         0.0012811476
#               0   2         0.0011097219
#               0   5         0.0010635733
#               0  11        -0.0006791795
#               0   4        -0.0005891056
#               0  12        -0.0003812422
#               0   0         0.0003622827
#               0   1         0.0002289815
#               0  10        -0.0002165437
#               0  16         0.0001560952
#
#     Largest TIjAb Amplitudes:
#       0   0  52  52        -0.0240199061
#       0   0  63  63        -0.0240199061
#       0   0   5   5        -0.0228454416
#       0   0   2   5        -0.0193877771
#       0   0   5   2        -0.0193877771
#       0   0   2   2        -0.0189512539
#       0   0  77  77        -0.0166842733
#       0   0  52  55         0.0158544254
#       0   0  55  52         0.0158544254
#       0   0  63  66         0.0158544254
#
#     SCF energy       (wfn)                    =   -0.942248124533713
#     Reference energy (file100)                =   -0.942248124533768
#
#     Opposite-spin MP2 correlation energy      =   -0.033099296834164
#     Same-spin MP2 correlation energy          =    0.000000000000000
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.033099296834164
#       * MP2 total energy                      =   -0.975347421367932
#
#     Opposite-spin CCSD correlation energy     =   -0.038626099768717
#     Same-spin CCSD correlation energy         =    0.000000000000000
#     Singles CCSD correlation energy           =    0.000000000000000
#     CCSD correlation energy                   =   -0.038626099768717
#       * CCSD total energy                     =   -0.980874224302485
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      UHF
#
#     Nuclear Rep. energy (wfn)                =    1.322943026675000
#     SCF energy          (wfn)                =   -0.942248124533713
#     Reference energy    (file100)            =   -0.942248124533768
#     CCSD energy         (file100)            =   -0.038626099768717
#     Total CCSD energy   (file100)            =   -0.980874224302485
#
#     Number of ijk index combinations:
#     Spin Case AAA:                                   0
#     Spin Case BBB:                                   0
#     Spin Case AAB:                                   0
#     Spin Case ABB:                                   0
#     AAA (T) energy                             =    0.000000000000000
#     BBB (T) energy                             =    0.000000000000000
#     AAB (T) energy                             =    0.000000000000000
#     ABB (T) energy                             =    0.000000000000000
#     (T) energy                                   =    0.000000000000000
#       * CCSD(T) total energy                     =   -0.980874224302485
#
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 8e3c8f7b991a
# *** at Tue May 26 20:17:32 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVQZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvqz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               UHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Full point group: D_inf_h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          H           -0.300000000000    -0.000000000000     0.000000000000     1.007825032230
#          H            0.300000000000     0.000000000000     0.000000000000     1.007825032230
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B =     92.92634  C =     92.92634 [cm^-1]
#   Rotational constants: A = ************  B = 2785861.70265  C = 2785861.70265 [MHz]
#   Nuclear repulsion =    0.881962017783334
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 2
#   Nalpha       = 1
#   Nbeta        = 1
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVQZ
#     Blend: AUG-CC-PVQZ
#     Number of shells: 28
#     Number of basis functions: 92
#     Number of Cartesian functions: 110
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              28
#       Number of primitives:             32
#       Number of atomic orbitals:       110
#       Number of basis functions:        92
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 18305562 doubles for integral storage.
#   We computed 82621 shell quartets total.
#   Whereas there are 82621 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 3.3171701465E-05.
#   Reciprocal condition number of the overlap matrix is 5.5457402894E-06.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      Ag        19      19
#      B1g       11      11
#      B2g       11      11
#      B3g        5       5
#      Au         5       5
#      B1u       11      11
#      B2u       11      11
#      B3u       19      19
#    -------------------------
#     Total      92      92
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @UHF iter SAD:    -1.13382026820799   -1.13382e+00   0.00000e+00
#    @UHF iter   1:    -1.08527133116054    4.85489e-02   4.43863e-03 DIIS/ADIIS
#    @UHF iter   2:    -1.11506734063892   -2.97960e-02   7.91469e-04 DIIS/ADIIS
#    @UHF iter   3:    -1.11618507164970   -1.11773e-03   1.08397e-04 DIIS/ADIIS
#    @UHF iter   4:    -1.11620377007753   -1.86984e-05   4.12325e-06 DIIS
#    @UHF iter   5:    -1.11620378444647   -1.43689e-08   1.83345e-07 DIIS
#    @UHF iter   6:    -1.11620378450800   -6.15290e-11   9.93710e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    @Spin Contamination Metric
#        5B1g    1.899856     5B2g    1.899856     9B3u    1.950983
#       10B3u    2.365668     6B1u    2.383646     6B2u    2.383646
#       11Ag     2.418872     3B3g    2.418872    12Ag     2.795950
#        6B1g    2.973232     6B2g    2.973232    11B3u    3.545358
#        7B1u    3.785209     7B2u    3.785209    12B3u    3.855517
#        3Au     3.855517    13Ag     4.166442    13B3u    4.585432
#        7B1g    4.751383     7B2g    4.751383    14Ag     5.924712
#        8B1u    6.250967     8B2u    6.250967     4B3g    6.918842
#       15Ag     6.918842     9B2u    7.263475     9B1u    7.263475
#        8B2g    7.370947     8B1g    7.370947     9B1g    7.533860
#        9B2g    7.533860    14B3u    7.688041    15B3u    7.857109
#        4Au     7.857109    16Ag     8.003394    10B1u    8.242431
#       10B2u    8.242431    17Ag     8.350841     5B3g    8.350841
#       18Ag     9.455018    16B3u    9.462377    10B1g    9.495828
#       10B2g    9.495828    11B2u    9.933517    11B1u    9.933517
#        5Au    10.530381    17B3u   10.530381    18B3u   11.909774
#       11B1g   14.631984    11B2g   14.631984    19B3u   15.812625
#       19Ag    16.155158
#
#     Final Occupation by Irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     1,    0,    0,    0,    0,    0,    0,    0 ]
#     SOCC [     0,    0,    0,    0,    0,    0,    0,    0 ]
#     NA   [     1,    0,    0,    0,    0,    0,    0,    0 ]
#     NB   [     1,    0,    0,    0,    0,    0,    0,    0 ]
#
#   @UHF Final Energy:    -1.11620378450800
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.8819620177833336
#     One-Electron Energy =                  -2.7116125953647927
#     Two-Electron Energy =                   0.7134467930734639
#     Total Energy =                         -1.1162037845079951
#
#   UHF NO Occupations:
#   HONO-0 :    1 Ag 2.0000000
#   LUNO+0 :    2 Ag 0.0000000
#   LUNO+1 :    3 Ag 0.0000000
#   LUNO+2 :    4 Ag 0.0000000
#   LUNO+3 :    5 Ag 0.0000000
#
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000           -0.0000000           -0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on 8e3c8f7b991a at Tue May 26 20:17:34 2026
# Module time:
# 	user time   =       1.55 seconds =       0.03 minutes
# 	system time =       0.08 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
# Total time:
# 	user time   =       6.06 seconds =       0.10 minutes
# 	system time =       1.92 seconds =       0.03 minutes
# 	total time  =          8 seconds =       0.13 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:              28
#       Number of SO shells:              14
#       Number of primitives:             32
#       Number of atomic orbitals:       110
#       Number of basis functions:        92
#
#       Number of irreps:                  8
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [  19   11   11    5    5   11   11   19 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 1170661 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on 8e3c8f7b991a
# *** at Tue May 26 20:17:34 2026
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 8
# 	Number of MOs        = 92
# 	Number of active MOs = 92
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = UHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 Ag	   19	    0	    1	    0	    18	    0
# 	 B1g	   11	    0	    0	    0	    11	    0
# 	 B2g	   11	    0	    0	    0	    11	    0
# 	 B3g	   5	    0	    0	    0	    5	    0
# 	 Au	   5	    0	    0	    0	    5	    0
# 	 B1u	   11	    0	    0	    0	    11	    0
# 	 B2u	   11	    0	    0	    0	    11	    0
# 	 B3u	   19	    0	    0	    0	    19	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =      0.00000000000000
#
# 	Size of irrep 0 of <AB|CD> integrals:      0.318 (MW) /      2.545 (MB)
# 	Size of irrep 1 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 2 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 3 of <AB|CD> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 4 of <AB|CD> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 5 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 6 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 7 of <AB|CD> integrals:      0.371 (MW) /      2.967 (MB)
# 	Total:                                     2.123 (MW) /     16.982 (MB)
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.318 (MW) /      2.545 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 4 of <ab|cd> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 5 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 6 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 7 of <ab|cd> integrals:      0.371 (MW) /      2.967 (MB)
# 	Total:                                     2.123 (MW) /     16.982 (MB)
#
# 	Size of irrep 0 of <Ab|Cd> integrals:      1.486 (MW) /     11.888 (MB)
# 	Size of irrep 1 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 2 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 3 of <Ab|Cd> integrals:      0.729 (MW) /      5.835 (MB)
# 	Size of irrep 4 of <Ab|Cd> integrals:      0.729 (MW) /      5.835 (MB)
# 	Size of irrep 5 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 6 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 7 of <Ab|Cd> integrals:      1.484 (MW) /     11.868 (MB)
# 	Total:                                     8.705 (MW) /     69.638 (MB)
#
# 	Size of irrep 0 of <IA|BC> integrals:      0.022 (MW) /      0.176 (MB)
# 	Size of irrep 1 of <IA|BC> integrals:      0.011 (MW) /      0.091 (MB)
# ...
#       Number of SO shells:              14
#       Number of primitives:             32
#       Number of atomic orbitals:       110
#       Number of basis functions:        92
#
#       Number of irreps:                  8
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [  19   11   11    5    5   11   11   19 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 1170661 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on 8e3c8f7b991a
# *** at Tue May 26 20:17:41 2026
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 8
# 	Number of MOs        = 92
# 	Number of active MOs = 92
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = UHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 Ag	   19	    0	    1	    0	    18	    0
# 	 B1g	   11	    0	    0	    0	    11	    0
# 	 B2g	   11	    0	    0	    0	    11	    0
# 	 B3g	   5	    0	    0	    0	    5	    0
# 	 Au	   5	    0	    0	    0	    5	    0
# 	 B1u	   11	    0	    0	    0	    11	    0
# 	 B2u	   11	    0	    0	    0	    11	    0
# 	 B3u	   19	    0	    0	    0	    19	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting AA/AB first half-transformation.
# 	Sorting AA/AB half-transformed integrals.
# 	Starting BB first half-transformation.
# 	Sorting BB half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting AA second half-transformation.
# 	Starting AB second half-transformation.
# 	Starting BB second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =      0.00000000000000
#
# 	Size of irrep 0 of <AB|CD> integrals:      0.318 (MW) /      2.545 (MB)
# 	Size of irrep 1 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 2 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 3 of <AB|CD> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 4 of <AB|CD> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 5 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 6 of <AB|CD> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 7 of <AB|CD> integrals:      0.371 (MW) /      2.967 (MB)
# 	Total:                                     2.123 (MW) /     16.982 (MB)
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.318 (MW) /      2.545 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 4 of <ab|cd> integrals:      0.182 (MW) /      1.459 (MB)
# 	Size of irrep 5 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 6 of <ab|cd> integrals:      0.267 (MW) /      2.138 (MB)
# 	Size of irrep 7 of <ab|cd> integrals:      0.371 (MW) /      2.967 (MB)
# 	Total:                                     2.123 (MW) /     16.982 (MB)
#
# 	Size of irrep 0 of <Ab|Cd> integrals:      1.486 (MW) /     11.888 (MB)
# 	Size of irrep 1 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 2 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 3 of <Ab|Cd> integrals:      0.729 (MW) /      5.835 (MB)
# 	Size of irrep 4 of <Ab|Cd> integrals:      0.729 (MW) /      5.835 (MB)
# 	Size of irrep 5 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 6 of <Ab|Cd> integrals:      1.069 (MW) /      8.553 (MB)
# 	Size of irrep 7 of <Ab|Cd> integrals:      1.484 (MW) /     11.868 (MB)
# 	Total:                                     8.705 (MW) /     69.638 (MB)
#
# 	Size of irrep 0 of <IA|BC> integrals:      0.022 (MW) /      0.176 (MB)
# 	Size of irrep 1 of <IA|BC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 2 of <IA|BC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 3 of <IA|BC> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 4 of <IA|BC> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 5 of <IA|BC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 6 of <IA|BC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 7 of <IA|BC> integrals:      0.023 (MW) /      0.185 (MB)
# 	Total:                                     0.099 (MW) /      0.793 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:      0.022 (MW) /      0.176 (MB)
# 	Size of irrep 1 of <ia|bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 2 of <ia|bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 3 of <ia|bc> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 4 of <ia|bc> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 5 of <ia|bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 6 of <ia|bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 7 of <ia|bc> integrals:      0.023 (MW) /      0.185 (MB)
# 	Total:                                     0.099 (MW) /      0.793 (MB)
#
# 	Size of irrep 0 of <Ia|Bc> integrals:      0.022 (MW) /      0.176 (MB)
# 	Size of irrep 1 of <Ia|Bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 2 of <Ia|Bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 3 of <Ia|Bc> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 4 of <Ia|Bc> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 5 of <Ia|Bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 6 of <Ia|Bc> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 7 of <Ia|Bc> integrals:      0.023 (MW) /      0.185 (MB)
# 	Total:                                     0.099 (MW) /      0.793 (MB)
#
# 	Size of irrep 0 of <iA|bC> integrals:      0.022 (MW) /      0.176 (MB)
# 	Size of irrep 1 of <iA|bC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 2 of <iA|bC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 3 of <iA|bC> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 4 of <iA|bC> integrals:      0.004 (MW) /      0.034 (MB)
# 	Size of irrep 5 of <iA|bC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 6 of <iA|bC> integrals:      0.011 (MW) /      0.091 (MB)
# 	Size of irrep 7 of <iA|bC> integrals:      0.023 (MW) /      0.185 (MB)
# 	Total:                                     0.099 (MW) /      0.793 (MB)
#
# 	Size of irrep 0 of tIjAb amplitudes:       0.001 (MW) /      0.010 (MB)
# 	Size of irrep 1 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 2 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 3 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 4 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 5 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 6 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Size of irrep 7 of tIjAb amplitudes:       0.000 (MW) /      0.000 (MB)
# 	Total:                                     0.001 (MW) /      0.010 (MB)
#
# 	Nuclear Rep. energy          =      0.75596744381429
# 	SCF energy                   =     -1.13263362435551
# 	One-electron energy          =     -2.56207748724256
# 	Two-electron (AA) energy     =      0.00000000000000
# 	Two-electron (BB) energy     =      0.00000000000000
# 	Two-electron (AB) energy     =      0.67347641907277
# 	Two-electron energy          =      0.67347641907277
# 	Reference energy             =     -1.13263362435551
#
# *** tstop() called on 8e3c8f7b991a at Tue May 26 20:17:43 2026
# Module time:
# 	user time   =       1.26 seconds =       0.02 minutes
# 	system time =       0.90 seconds =       0.02 minutes
# 	total time  =          2 seconds =       0.03 minutes
# Total time:
# 	user time   =      12.19 seconds =       0.20 minutes
# 	system time =       4.60 seconds =       0.08 minutes
# 	total time  =         17 seconds =       0.28 minutes
#             **************************
#             *                        *
#             *        CCENERGY        *
#             *                        *
#             **************************
#
#     Nuclear Rep. energy (wfn)     =    0.755967443814286
#     SCF energy          (wfn)     =   -1.132633624355513
#     Reference energy    (file100) =   -1.132633624355509
#
#     Input parameters:
#     -----------------
#     Wave function   =     CCSD_T
#     Reference wfn   =     UHF
#     Brueckner       =     No
#     Memory (Mbytes) =     524.3
#     Maxiter         =     50
#     R_Convergence   =     1.0e-07
#     E_Convergence   =     1.0e-06
#     Restart         =     Yes
#     DIIS            =     Yes
#     AO Basis        =     NONE
#     ABCD            =     NEW
#     Cache Level     =     2
#     Cache Type      =     LRU
#     Print Level     =     1
#     Num. of threads =     1
#     # Amps to Print =     10
#     Print MP2 Amps? =     No
#     Analyze T2 Amps =     No
#     Print Pair Ener =     No
#     Local CC        =     No
#     SCS-MP2         =     False
#     SCSN-MP2        =     False
#     SCS-CCSD        =     False
#
#     Using old T1 amplitudes.
# MP2 correlation energy -0.0331172168811313
#                 Solving CC Amplitude Equations
#                 ------------------------------
#   Iter             Energy              RMS        T1Diag      D1Diag    New D1Diag    D2Diag
#   ----     ---------------------    ---------   ----------  ----------  ----------   --------
#      0        -0.033115676301417    0.000e+00    0.005106    0.000000    0.000000    0.000000
#      1        -0.037742928100453    2.346e-02    0.005667    0.000000    0.000000    0.000000
#      2        -0.039954906076982    8.154e-03    0.006821    0.000000    0.000000    0.000000
#      3        -0.039953952234303    9.472e-04    0.006958    0.000000    0.000000    0.000000
#      4        -0.039958865922834    2.460e-04    0.007025    0.000000    0.000000    0.000000
#      5        -0.039958727254266    3.522e-05    0.007038    0.000000    0.000000    0.000000
#      6        -0.039958429623792    6.704e-06    0.007042    0.000000    0.000000    0.000000
#      7        -0.039958498910505    1.575e-06    0.007043    0.000000    0.000000    0.000000
#      8        -0.039958516120804    2.469e-07    0.007043    0.000000    0.000000    0.000000
#      9        -0.039958514524222    5.977e-08    0.007043    0.000000    0.000000    0.000000
#
#     Iterations converged.
#
#
#     Largest TIA Amplitudes:
#               0   2         0.0047383536
#               0   6         0.0026971014
#               0   0         0.0026308477
#               0   4         0.0025365168
#               0   7         0.0016071550
#               0   5         0.0012540154
#               0  10        -0.0011111757
#               0  12         0.0008229130
#               0   1         0.0005601942
#               0  14         0.0003138002
#
#     Largest Tia Amplitudes:
#               0   2         0.0047383536
#               0   6         0.0026971014
#               0   0         0.0026308477
#               0   4         0.0025365168
#               0   7         0.0016071550
#               0   5         0.0012540154
#               0  10        -0.0011111757
#               0  12         0.0008229130
#               0   1         0.0005601942
#               0  14         0.0003138002
#
#     Largest TIjAb Amplitudes:
#       0   0  74  74        -0.0314768028
#       0   0  74  77        -0.0265335573
#       0   0  77  74        -0.0265335573
#       0   0  73  74        -0.0249443002
#       0   0  74  73        -0.0249443002
#       0   0  77  77        -0.0244537125
#       0   0   2   2        -0.0231724757
#       0   0  73  73        -0.0202335707
#       0   0  73  77        -0.0200953976
#       0   0  77  73        -0.0200953976
#
#     SCF energy       (wfn)                    =   -1.132633624355513
#     Reference energy (file100)                =   -1.132633624355509
#
#     Opposite-spin MP2 correlation energy      =   -0.033117216881131
#     Same-spin MP2 correlation energy          =    0.000000000000000
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.033117216881131
#       * MP2 total energy                      =   -1.165750841236641
#
#     Opposite-spin CCSD correlation energy     =   -0.039958514524222
#     Same-spin CCSD correlation energy         =    0.000000000000000
#     Singles CCSD correlation energy           =   -0.000000000000000
#     CCSD correlation energy                   =   -0.039958514524222
#       * CCSD total energy                     =   -1.172592138879731
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      UHF
#
#     Nuclear Rep. energy (wfn)                =    0.755967443814286
#     SCF energy          (wfn)                =   -1.132633624355513
#     Reference energy    (file100)            =   -1.132633624355509
#     CCSD energy         (file100)            =   -0.039958514524222
#     Total CCSD energy   (file100)            =   -1.172592138879731
#
#     Number of ijk index combinations:
#     Spin Case AAA:                                   0
#     Spin Case BBB:                                   0
#     Spin Case AAB:                                   0
#     Spin Case ABB:                                   0
#     AAA (T) energy                             =    0.000000000000000
#     BBB (T) energy                             =    0.000000000000000
#     AAB (T) energy                             =    0.000000000000000
#     ABB (T) energy                             =    0.000000000000000
#     (T) energy                                   =    0.000000000000000
#       * CCSD(T) total energy                     =   -1.172592138879731
#
#
#     Psi4 stopped on: Tuesday, 26 May 2026 08:17PM
#     Psi4 wall time for execution: 0:00:22.06
#
# *** Psi4 exiting successfully. Buy a developer a beer!

# %% [markdown]
# #Fluorine

# %%
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
# %%bash
set -euo pipefail
MAMBA_ROOT="$HOME/mamba"
MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
cat > psi4.in <<'EOF'
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# Your input file should go in this middle section
# Write this as a classic-style Psi4 input file (not a Python script)

# Specify the molecular geometry
# molecula 1
molecule {
   F 0.0 0.0 0.0
   F 1.1 0.0 0.0
}

set {
  basis aug-cc-pVQZ
  reference uhf
}

# Compute the energy at the CCSD(T) level
energy('CCSD(T)')

# molecula 2
molecule {
   F 0.0 0.0 0.0
   F 1.2 0.0 0.0
}

energy('CCSD(T)')

# molecula 3
molecule {
   F 0.0 0.0 0.0
   F 1.3 0.0 0.0
}
energy('CCSD(T)')

# molecula 4
molecule {
   F 0.0 0.0 0.0
   F 1.4 0.0 0.0
}
energy('CCSD(T)')

# molecula 5
molecule {
   F 0.0 0.0 0.0
   F 1.5 0.0 0.0
}
energy('CCSD(T)')


# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
EOF
"$MAMBA_BIN" run -r "$MAMBA_ROOT" -n psi4 psi4 psi4.in psi4.out
cat psi4.out
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Out:
# Process is terminated.
