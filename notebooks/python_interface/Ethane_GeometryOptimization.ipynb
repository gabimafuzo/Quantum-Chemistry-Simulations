# %%
# %%bash
# set -euo pipefail
#
# MAMBA_ROOT="$HOME/mamba"
# MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
# if [ ! -x "$MAMBA_BIN" ]; then
#   mkdir -p "$MAMBA_ROOT"
#   curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj -C "$MAMBA_ROOT" bin/micromamba >/dev/null
# fi
#
# "$MAMBA_BIN" create -y -r "$MAMBA_ROOT" -n psi4 -c conda-forge psi4 python=3.12 >/dev/null

# %%
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
# %%bash
set -euo pipefail
MAMBA_ROOT="$HOME/mamba"
MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
cat > psi4.in <<'EOF'
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Your input file should go in this middle section
# Write this as a classic-style Psi4 input file (not a Python script)

molecule{
  C
  C 1 CC2
  H 1 HC3 2 HCC3
  H 2 HC4 1 HCC4 3 HCCH4
  H 2 HC5 1 HCC5 3 HCCH5
  H 2 HC6 1 HCC6 3 HCCH6
  H 1 HC7 2 HCC7 4 HCCH7
  H 1 HC8 2 HCC8 4 HCCH8

  CC2 = 1.5
  HC3 = 1.0
  HCC3 = 109.5
  HC4 = 1.0
  HCC4 = 109.5
  HCCH4 = 65.0
  HC5 = 1.0
  HCC5 = 109.5
  HCCH5 = -65.0
  HC6 = 1.0
  HCC6 = 109.5
  HCCH6 = 185.0
  HC7 = 1.0
  HCC7 = 109.5
  HCCH7 = -65.0
  HC8 = 1.0
  HCC8 = 109.5
  HCCH8 = 185.0
}

set {
  basis aug-cc-pVDZ
  reference rhf
  }
optimize ('MP2')


# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
EOF
"$MAMBA_BIN" run -r "$MAMBA_ROOT" -n psi4 psi4 psi4.in psi4.out
cat psi4.out
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Out:
# Optimizer: Optimization complete!
#
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, D. L. Poole, T. Győri, E. C. Mitchell, J. P. Pederson,
#     and A. M. Wallace
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     https://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Thursday, 28 May 2026 07:32PM
#
#     Process ID: 39758
#     Host:       4b17f6c6367b
#     PSIDATADIR: /root/mamba/envs/psi4/share/psi4
#     Memory:     500.0 MiB
#     Threads:    1
#     Addons:     a̶d̶c̶c̶, a̶m̶b̶i̶t̶, b̶s̶e̶, c̶c̶t̶3̶, c̶f̶o̶u̶r̶, c̶h̶e̶m̶p̶s̶2̶, c̶p̶p̶e̶, d̶d̶x̶,
#                 d̶f̶t̶d̶3̶, d̶f̶t̶d̶4̶, dkh, ecpint, einsums, f̶o̶r̶t̶e̶, g̶a̶u̶x̶c̶, g̶c̶p̶,
#                 g̶d̶m̶a̶, g̶e̶o̶m̶e̶t̶r̶i̶c̶, g̶p̶u̶_̶d̶f̶c̶c̶, i̶n̶t̶e̶g̶r̶a̶t̶o̶r̶x̶x̶,
#                 i̶p̶i̶, l̶i̶b̶e̶f̶p̶, m̶d̶i̶, m̶p̶2̶d̶, m̶r̶c̶c̶, ooo,
#                 o̶p̶e̶n̶f̶e̶r̶m̶i̶o̶n̶p̶s̶i̶4̶, pcmsolver, p̶s̶i̶4̶f̶o̶c̶k̶c̶i̶, p̶s̶i̶x̶a̶s̶,
#                 r̶e̶s̶p̶, s̶i̶m̶i̶n̶t̶, s̶n̶s̶m̶p̶2̶, v̶2̶r̶d̶m̶_̶c̶a̶s̶s̶c̶f̶
#
#   ==> Input File <==
#
# --------------------------------------------------------------------------
# # >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# # Your input file should go in this middle section
# # Write this as a classic-style Psi4 input file (not a Python script)
#
# molecule{
#   C
#   C 1 CC2
#   H 1 HC3 2 HCC3
#   H 2 HC4 1 HCC4 3 HCCH4
#   H 2 HC5 1 HCC5 3 HCCH5
#   H 2 HC6 1 HCC6 3 HCCH6
#   H 1 HC7 2 HCC7 4 HCCH7
#   H 1 HC8 2 HCC8 4 HCCH8
#
#   CC2 = 1.5
#   HC3 = 1.0
#   HCC3 = 109.5
#   HC4 = 1.0
#   HCC4 = 109.5
#   HCCH4 = 65.0
#   HC5 = 1.0
#   HCC5 = 109.5
#   HCCH5 = -65.0
#   HC6 = 1.0
#   HCC6 = 109.5
#   HCCH6 = 185.0
#   HC7 = 1.0
#   HCC7 = 109.5
#   HCCH7 = -65.0
#   HC8 = 1.0
#   HCC8 = 109.5
#   HCCH8 = 185.0
# }
#
# set {
#   basis aug-cc-pVDZ
#   reference rhf
#   }
# optimize ('MP2')
#
#
# # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# # STUDENTS SHOULD IGNORE THESE LINES
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#     SCF Algorithm Type (re)set to DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 4b17f6c6367b
# *** at Thu May 28 19:32:27 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry C          line   182 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 3-8 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C            0.000000000000    -0.750000000000     0.011012191279    12.000000000000
#          C            0.000000000000     0.750000000000     0.011012191279    12.000000000000
#          H           -0.506480903975    -1.083806859234     0.806027961334     1.007825032230
#          H            0.506480903975     1.083806859234     0.806027961334     1.007825032230
#          H           -0.934577062461     1.083806859234    -0.112027213182     1.007825032230
#          H            0.435263401290     1.083806859234    -0.825121023123     1.007825032230
#          H            0.934577062461    -1.083806859234    -0.112027213182     1.007825032230
#          H           -0.435263401290    -1.083806859234    -0.825121023123     1.007825032230
#
#   Running in c2 symmetry.
#
#   Rotational constants: A =      3.13952  B =      0.72467  C =      0.72310 [cm^-1]
#   Rotational constants: A =  94120.32569  B =  21725.10278  C =  21677.96511 [MHz]
#   Nuclear repulsion =   44.839409235469958
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 48
#     Number of basis functions: 100
#     Number of Cartesian functions: 104
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry C          line   154 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#     atoms 3-8 entry H          line    70 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.030 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 128
#     Number of basis functions: 364
#     Number of Cartesian functions: 412
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 2.2197348597E-04.
#   Reciprocal condition number of the overlap matrix is 2.3771171885E-05.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         50      50
#      B         50      50
#    -------------------------
#     Total     100     100
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter SAD:   -80.71429864110891   -8.07143e+01   0.00000e+00
#     Occupation by irrep:
#               A     B
#     DOCC [     5,    4 ]
#     NA   [     5,    4 ]
#     NB   [     5,    4 ]
#
#    @DF-RHF iter   1:   -71.06864428264683    9.64565e+00   2.67432e-02 ADIIS/DIIS
#    @DF-RHF iter   2:   -76.95121885639445   -5.88257e+00   2.94411e-02 ADIIS/DIIS
#    @DF-RHF iter   3:   -79.06119105026148   -2.10997e+00   6.16653e-03 ADIIS/DIIS
#    @DF-RHF iter   4:   -79.18126612240955   -1.20075e-01   1.47046e-03 ADIIS/DIIS
#    @DF-RHF iter   5:   -79.19005794231212   -8.79182e-03   1.68622e-04 ADIIS/DIIS
#    @DF-RHF iter   6:   -79.19023688223432   -1.78940e-04   3.17519e-05 DIIS
#    @DF-RHF iter   7:   -79.19024404623059   -7.16400e-06   5.71148e-06 DIIS
#    @DF-RHF iter   8:   -79.19024425591614   -2.09686e-07   1.34339e-06 DIIS
#    @DF-RHF iter   9:   -79.19024426475818   -8.84204e-09   1.56583e-07 DIIS
#    @DF-RHF iter  10:   -79.19024426488494   -1.26761e-10   2.22529e-08 DIIS
#    @DF-RHF iter  11:   -79.19024426488696   -2.01794e-12   2.44325e-09 DIIS
#    @DF-RHF iter  12:   -79.19024426488697   -1.42109e-14   3.61659e-10 DIIS
#    @DF-RHF iter  13:   -79.19024426488701   -4.26326e-14   4.77522e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -11.179049     1B    -11.178382     2A     -1.051258
#        2B     -0.875156     3A     -0.631384     3B     -0.628145
#        4B     -0.505190     4A     -0.504736     5A     -0.501232
#
#     Virtual:
#
#        6A      0.038709     5B      0.051447     7A      0.052871
#        6B      0.052945     7B      0.083047     8A      0.083128
#        9A      0.125445     8B      0.140287    10A      0.142687
#        9B      0.154497    11A      0.174555    10B      0.176805
#       12A      0.177949    11B      0.206762    12B      0.299274
#       13A      0.301767    14A      0.326462    13B      0.329217
#       15A      0.385017    14B      0.386461    15B      0.395047
#       16A      0.398707    16B      0.425470    17A      0.425619
#       17B      0.441397    18A      0.477289    18B      0.480511
#       19A      0.488985    20A      0.495830    19B      0.565455
#       21A      0.569703    20B      0.585775    22A      0.597531
#       21B      0.606435    23A      0.639334    22B      0.639521
#       23B      0.645305    24A      0.647320    24B      0.671333
#       25A      0.671463    26A      0.720853    25B      0.747659
#       26B      0.764574    27A      0.767333    27B      0.768414
#       28A      0.803708    28B      0.811601    29B      0.899096
#       29A      0.902281    30A      1.087915    30B      1.089318
#       31A      1.196889    31B      1.205992    32B      1.231963
#       32A      1.240390    33A      1.280146    33B      1.408017
#       34B      1.427061    34A      1.433936    35A      1.524963
#       35B      1.530911    36A      1.769356    36B      1.782934
#       37A      1.924676    38A      1.948443    37B      1.951805
#       39A      1.958176    38B      1.966520    40A      2.147841
#       39B      2.157002    41A      2.197686    40B      2.222857
#       42A      2.255052    41B      2.273332    43A      2.369260
#       42B      2.379201    44A      2.421261    43B      2.426249
#       44B      2.535851    45A      2.563212    45B      2.761798
#       46B      2.798378    46A      2.804660    47A      2.884918
#       47B      2.922021    48B      3.187219    48A      3.198541
#       49A      3.244475    49B      3.251515    50B      3.403405
#       50A      3.432402
#
#     Final Occupation by Irrep:
#               A     B
#     DOCC [     5,    4 ]
#     NA   [     5,    4 ]
#     NB   [     5,    4 ]
#
#   @DF-RHF Final Energy:   -79.19024426488701
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             44.8394092354699580
#     One-Electron Energy =                -193.9502400841770964
#     Two-Electron Energy =                  69.9205865838201248
#     Total Energy =                        -79.1902442648870135
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.1991666           -0.2458425           -0.0466759
#  Magnitude           :                                                    0.0466759
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on 4b17f6c6367b at Thu May 28 19:32:30 2026
# Module time:
# 	user time   =       2.21 seconds =       0.04 minutes
# 	system time =       0.15 seconds =       0.00 minutes
# 	total time  =          3 seconds =       0.05 minutes
# Total time:
# 	user time   =       2.21 seconds =       0.04 minutes
# 	system time =       0.15 seconds =       0.00 minutes
# 	total time  =          3 seconds =       0.05 minutes
#
# *** tstart() called on 4b17f6c6367b
# *** at Thu May 28 19:32:30 2026
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //               DFMP2               //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_MP2
#     atoms 1-2 entry C          line   112 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#     atoms 3-8 entry H          line    30 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#
# 	 --------------------------------------------------------
# 	                          DF-MP2
# 	      2nd-Order Density-Fitted Moller-Plesset Theory
# 	              RMP2 Wavefunction,   1 Threads
#
# 	        Rob Parrish, Justin Turney, Andy Simmonett,
# 	           Ed Hohenstein, and C. David Sherrill
# 	 --------------------------------------------------------
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-RI
#     Number of shells: 98
#     Number of basis functions: 282
#     Number of Cartesian functions: 322
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	 --------------------------------------------------------
# 	                 NBF =   100, NAUX =   282
# 	 --------------------------------------------------------
# 	   CLASS    FOCC     OCC    AOCC    AVIR     VIR    FVIR
# 	   PAIRS       0       9       9      91      91       0
# 	 --------------------------------------------------------
#
#   DFHelper Memory: AOs need 0.030 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#
#          ------------------------------------------------------------
#                                      CPHF
#                                   Rob Parrish
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C            0.000000000000    -0.750000000000     0.011012191279    12.000000000000
#          C            0.000000000000     0.750000000000     0.011012191279    12.000000000000
#          H           -0.506480903975    -1.083806859234     0.806027961334     1.007825032230
#          H            0.506480903975     1.083806859234     0.806027961334     1.007825032230
#          H           -0.934577062461     1.083806859234    -0.112027213182     1.007825032230
#          H            0.435263401290     1.083806859234    -0.825121023123     1.007825032230
#          H            0.934577062461    -1.083806859234    -0.112027213182     1.007825032230
#          H           -0.435263401290    -1.083806859234    -0.825121023123     1.007825032230
#
#   Nuclear repulsion =   44.839409235469958
#   Reference energy  =  -79.190244264887014
#
#   ==> Basis Set <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 48
#     Number of basis functions: 100
#     Number of Cartesian functions: 104
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> CGRSolver (by Rob Parrish) <==
#
#    Number of roots    =         1
#    Preconditioning    =    JACOBI
#    Convergence cutoff =     1E-06
#    Maximum iterations =       100
#
#   ==> CPHFRHamiltonian (by Rob Parrish) <==
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 128
#     Number of basis functions: 364
#     Number of Cartesian functions: 412
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> CPHF Iterations <==
#
#   => Iterations <=
#
#              Iter  Converged  Remaining    Residual
#   CGR           1          0          1   4.205E-02
#   CGR           2          0          1   1.314E-02
#   CGR           3          0          1   1.526E-03
#   CGR           4          0          1   1.753E-04
#   CGR           5          0          1   3.242E-05
#   CGR           6          0          1   5.296E-06
#   CGR           7          0          1   1.168E-06
#   CGR           8          1          0   1.275E-07
#
#     CGRSolver converged.
#
#   ==> DFCorrGrad: Density-Fitted Correlated Gradients <==
#
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [GiB]:            0.366
#     Schwarz Cutoff:          0E+00
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 128
#     Number of basis functions: 364
#     Number of Cartesian functions: 412
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	-----------------------------------------------------------
# 	 ==================> DF-MP2 Energies <====================
# 	-----------------------------------------------------------
# 	 Reference Energy          =     -79.1902442648870135 [Eh]
# 	 Singles Energy            =      -0.0000000000000000 [Eh]
# 	 Same-Spin Energy          =      -0.0677682159237098 [Eh]
# 	 Opposite-Spin Energy      =      -0.2461595176969868 [Eh]
# 	 Correlation Energy        =      -0.3139277336206966 [Eh]
# 	 Total Energy              =     -79.5041719985077151 [Eh]
# 	-----------------------------------------------------------
# 	 ================> DF-SCS-MP2 Energies <==================
# 	-----------------------------------------------------------
# 	 SCS Same-Spin Scale       =       0.3333333333333333 [-]
# 	 SCS Opposite-Spin Scale   =       1.2000000000000000 [-]
# 	 SCS Same-Spin Energy      =      -0.0225894053079033 [Eh]
# 	 SCS Opposite-Spin Energy  =      -0.2953914212363841 [Eh]
# 	 SCS Correlation Energy    =      -0.3179808265442874 [Eh]
# 	 SCS Total Energy          =     -79.5082250914312993 [Eh]
# 	-----------------------------------------------------------
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.000399271109    -0.069212037846     0.005464201508
#        2       -0.000399271109     0.069212037846     0.005464201508
#        3        0.034843413936     0.037348462931    -0.070110697525
#        4       -0.034843413936    -0.037348462931    -0.070110697525
#        5        0.083895367388    -0.033872125471    -0.007626469767
#        6       -0.048717844692    -0.029125288411     0.072272965783
#        7       -0.083895367388     0.033872125471    -0.007626469767
#        8        0.048717844692     0.029125288411     0.072272965783
#
#
# *** tstop() called on 4b17f6c6367b at Thu May 28 19:32:32 2026
# Module time:
# 	user time   =       2.21 seconds =       0.04 minutes
# 	system time =       0.09 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
# Total time:
# 	user time   =       4.42 seconds =       0.07 minutes
# 	system time =       0.24 seconds =       0.00 minutes
# 	total time  =          5 seconds =       0.08 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       6.000000            12.000000          0.00000000 -1.41729459  0.02081003
# 	       6.000000            12.000000          0.00000000  1.41729459  0.02081003
# 	       1.000000             1.007825         -0.95711020 -2.04809814  1.52317210
# 	       1.000000             1.007825          0.95711020  2.04809814  1.52317210
# 	       1.000000             1.007825         -1.76609469  2.04809814 -0.21170075
# 	       1.000000             1.007825          0.82252862  2.04809814 -1.55925275
# 	       1.000000             1.007825          1.76609469 -2.04809814 -0.21170075
# 	       1.000000             1.007825         -0.82252862 -2.04809814 -1.55925275
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.834589           1.500000
# 	 R(1,3)           =         1.889726           1.000000
# 	 R(1,7)           =         1.889726           1.000000
# 	 R(1,8)           =         1.889726           1.000000
# 	 R(2,4)           =         1.889726           1.000000
# 	 R(2,5)           =         1.889726           1.000000
# 	 R(2,6)           =         1.889726           1.000000
# 	 B(1,2,4)         =         1.911136         109.500000
# 	 B(1,2,5)         =         1.911136         109.500000
# 	 B(1,2,6)         =         1.911136         109.500000
# 	 B(2,1,3)         =         1.911136         109.500000
# 	 B(2,1,7)         =         1.911136         109.500000
# 	 B(2,1,8)         =         1.911136         109.500000
# 	 B(3,1,7)         =         2.048495         117.370117
# 	 B(3,1,8)         =         1.910131         109.442426
# 	 B(4,2,5)         =         2.048495         117.370117
# 	 B(4,2,6)         =         1.910131         109.442426
# 	 B(5,2,6)         =         1.764488         101.097715
# 	 B(7,1,8)         =         1.764488         101.097715
# 	 D(3,1,2,4)       =         1.134464          65.000000
# 	 D(3,1,2,5)       =        -1.134464         -65.000000
# 	 D(3,1,2,6)       =        -3.054326        -175.000000
# 	 D(4,2,1,7)       =        -1.134464         -65.000000
# 	 D(4,2,1,8)       =        -3.054326        -175.000000
# 	 D(5,2,1,7)       =         2.879793         165.000000
# 	 D(5,2,1,8)       =         0.959931          55.000000
# 	 D(6,2,1,7)       =         0.959931          55.000000
# 	 D(6,2,1,8)       =        -0.959931         -55.000000
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.50000        0.25650        0.03978       1.53978
# 	               R(1,3)       1.00000        0.70733        0.08009       1.08009
# 	               R(1,7)       1.00000        0.73139        0.08281       1.08281
# 	               R(1,8)       1.00000        0.75267        0.08522       1.08522
# 	               R(2,4)       1.00000        0.70733        0.08009       1.08009
# 	               R(2,5)       1.00000        0.73139        0.08281       1.08281
# 	               R(2,6)       1.00000        0.75267        0.08522       1.08522
# 	             B(1,2,4)     109.50000        0.00061        1.39626     110.89626
# 	             B(1,2,5)     109.50000        0.00028        0.80974     110.30974
# 	             B(1,2,6)     109.50000       -0.00013        0.02549     109.52549
# 	             B(2,1,3)     109.50000        0.00061        1.39626     110.89626
# 	             B(2,1,7)     109.50000        0.00028        0.80974     110.30974
# 	             B(2,1,8)     109.50000       -0.00013        0.02549     109.52549
# 	             B(3,1,7)     117.37012       -0.00100       -3.76142     113.60869
# 	             B(3,1,8)     109.44243       -0.00027       -0.80032     108.64211
# 	             B(4,2,5)     117.37012       -0.00100       -3.76142     113.60869
# 	             B(4,2,6)     109.44243       -0.00027       -0.80032     108.64211
# 	             B(5,2,6)     101.09772        0.00050        2.45260     103.55032
# 	             B(7,1,8)     101.09772        0.00050        2.45260     103.55032
# 	           D(3,1,2,4)      65.00000       -0.00039       -2.04759      62.95241
# 	           D(3,1,2,5)     -65.00000        0.00024        1.19680     -63.80320
# 	           D(3,1,2,6)    -175.00000       -0.00043       -2.15160    -177.15160
# 	           D(4,2,1,7)     -65.00000        0.00024        1.19680     -63.80320
# 	           D(4,2,1,8)    -175.00000       -0.00043       -2.15160    -177.15160
# 	           D(5,2,1,7)     165.00000        0.00087        4.44118     169.44118
# 	           D(5,2,1,8)      55.00000        0.00020        1.09279      56.09279
# 	           D(6,2,1,7)      55.00000        0.00020        1.09279      56.09279
# 	           D(6,2,1,8)     -55.00000       -0.00046       -2.25561     -57.25561
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------~
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp   ~
# 	----------------------------------------------------------------------------------------------~
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o~
# 	----------------------------------------------------------------------------------------------~
# 	     1     -79.50417200   -7.95e+01      9.14e-02      4.19e-02 o    1.61e-01      8.01e-02 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	    C  -0.0001402093  -0.7698900204   0.0026329691
# 	    C   0.0001402093   0.7698900204   0.0026329691
# 	    H  -0.5270795105  -1.1550368379   0.8632073501
# 	    H   0.5270795105   1.1550368379   0.8632073501
# 	    H  -1.0109785224   1.1459135015  -0.0908054924
# 	    H   0.4902549336   1.1325105066  -0.8951429104
# 	    H   1.0109785224  -1.1459135015  -0.0908054924
# 	    H  -0.4902549336  -1.1325105066  -0.8951429104
#
#
#     Structure for next step:
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     C
#     C             1         CC2
#     H             1         HC3      2        HCC3
#     H             2         HC4      1        HCC4      3       HCCH4
#     H             2         HC5      1        HCC5      3       HCCH5
#     H             2         HC6      1        HCC6      3       HCCH6
#     H             1         HC7      2        HCC7      4       HCCH7
#     H             1         HC8      2        HCC8      4       HCCH8
#
#     CC2       =    1.5397800664
#     HC3       =    1.0800885905
#     HC4       =    1.0800885905
#     HC5       =    1.0828136931
#     HC6       =    1.0852223689
#     HC7       =    1.0828136931
#     HC8       =    1.0852223689
#     HCC3      =  110.8962598526
#     HCC4      =  110.8962598526
#     HCC5      =  110.3097414250
#     HCC6      =  109.5254898489
#     HCC7      =  110.3097414250
#     HCC8      =  109.5254898489
#     HCCH4     =   62.9524077020
#     HCCH5     =  -63.8032039143
#     HCCH6     = -177.1516029189
#     HCCH7     =  -63.8032039143
#     HCCH8     = -177.1516029189
#
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#     SCF Algorithm Type (re)set to DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 4b17f6c6367b
# *** at Thu May 28 19:32:32 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry C          line   182 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 3-8 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C            0.000000000000    -0.769890033187     0.008763766121    12.000000000000
#          C            0.000000000000     0.769890033187     0.008763766121    12.000000000000
#          H           -0.526869151116    -1.155132808297     0.869338147061     1.007825032230
#          H            0.526869151116     1.155132808297     0.869338147061     1.007825032230
#          H           -1.011187194793     1.145729367186    -0.084674695444     1.007825032230
#          H            0.490048677219     1.132599771078    -0.889012113430     1.007825032230
#          H            1.011187194793    -1.145729367186    -0.084674695444     1.007825032230
#          H           -0.490048677219    -1.132599771078    -0.889012113430     1.007825032230
#
#   Running in c2 symmetry.
#
#   Rotational constants: A =      2.70273  B =      0.66760  C =      0.66685 [cm^-1]
#   Rotational constants: A =  81025.93110  B =  20014.02827  C =  19991.78249 [MHz]
#   Nuclear repulsion =   42.352748184425529
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 48
#     Number of basis functions: 100
#     Number of Cartesian functions: 104
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry C          line   154 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#     atoms 3-8 entry H          line    70 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry C          line   182 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 3-8 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#   Reading orbitals from file /tmp/psi4.default.39758.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.030 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 128
#     Number of basis functions: 364
#     Number of Cartesian functions: 412
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 2.7609271174E-04.
#   Reciprocal condition number of the overlap matrix is 3.0729012006E-05.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A         50      50       5       5       5       0
#      B         50      50       4       4       4       0
#    -------------------------------------------------------
#     Total     100     100       9       9       9       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter   0:   -79.08651590050889   -7.90865e+01   5.68718e-03
#    @DF-RHF iter   1:   -79.23379152691952   -1.47276e-01   3.86431e-04 ADIIS/DIIS
#    @DF-RHF iter   2:   -79.23431653537362   -5.25008e-04   1.19898e-04 ADIIS/DIIS
#    @DF-RHF iter   3:   -79.23436070716227   -4.41718e-05   4.04882e-05 DIIS
#    @DF-RHF iter   4:   -79.23436652412691   -5.81696e-06   3.67004e-06 DIIS
#    @DF-RHF iter   5:   -79.23436659520362   -7.10767e-08   7.16220e-07 DIIS
#    @DF-RHF iter   6:   -79.23436659845649   -3.25286e-09   1.76033e-07 DIIS
#    @DF-RHF iter   7:   -79.23436659867573   -2.19245e-10   2.24810e-08 DIIS
#    @DF-RHF iter   8:   -79.23436659867876   -3.02691e-12   4.03397e-09 DIIS
#    @DF-RHF iter   9:   -79.23436659867897   -2.13163e-13   7.11445e-10 DIIS
#    @DF-RHF iter  10:   -79.23436659867899   -1.42109e-14   8.46707e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -11.215774     1B    -11.215209     2A     -1.018708
#        2B     -0.844030     3A     -0.600592     3B     -0.599230
#        4A     -0.500455     4B     -0.488955     5A     -0.487559
#
#     Virtual:
#
#        6A      0.038475     5B      0.051275     7A      0.053416
#        6B      0.053478     7B      0.082654     8A      0.082711
#        9A      0.124380     8B      0.141370    10A      0.142765
#        9B      0.152644    11A      0.174801    10B      0.177165
#       12A      0.177319    11B      0.206087    12B      0.292360
#       13A      0.294894    14A      0.304917    13B      0.307035
#       15A      0.378066    14B      0.378668    15B      0.379829
#       16A      0.389614    16B      0.422764    17B      0.427404
#       17A      0.427500    18A      0.466220    18B      0.481154
#       19A      0.481671    20A      0.484715    19B      0.551012
#       21A      0.552638    20B      0.579264    22A      0.583513
#       21B      0.589284    23A      0.618801    22B      0.619964
#       23B      0.631707    24A      0.633231    24B      0.656882
#       25A      0.657910    26A      0.716704    25B      0.717450
#       26B      0.737304    27A      0.738887    27B      0.747626
#       28A      0.795476    28B      0.799458    29B      0.896439
#       29A      0.899616    30A      1.037115    30B      1.037455
#       31A      1.124334    31B      1.160275    32A      1.221430
#       32B      1.221988    33A      1.278889    33B      1.368410
#       34B      1.446522    34A      1.450846    35A      1.525075
#       35B      1.528604    36A      1.774635    36B      1.780431
#       37A      1.896945    37B      1.911775    38A      1.916839
#       38B      1.940285    39A      1.941562    40A      2.055898
#       39B      2.060161    41A      2.112633    40B      2.184133
#       42A      2.207349    41B      2.210046    43A      2.250626
#       42B      2.266637    43B      2.288101    44A      2.288815
#       45A      2.452409    44B      2.478110    45B      2.642622
#       46A      2.643281    46B      2.711441    47A      2.712668
#       47B      2.844230    48A      2.922541    48B      2.924970
#       49A      2.960821    49B      2.995688    50B      3.164381
#       50A      3.173626
#
#     Final Occupation by Irrep:
#               A     B
#     DOCC [     5,    4 ]
#     NA   [     5,    4 ]
#     NB   [     5,    4 ]
#
#   @DF-RHF Final Energy:   -79.23436659867899
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             42.3527481844255291
#     One-Electron Energy =                -189.2332076384069524
#     Two-Electron Energy =                  67.6460928553024274
#     Total Energy =                        -79.2343665986789887
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.1721346           -0.1956474           -0.0235128
#  Magnitude           :                                                    0.0235128
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on 4b17f6c6367b at Thu May 28 19:32:33 2026
# Module time:
# 	user time   =       0.82 seconds =       0.01 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       5.38 seconds =       0.09 minutes
# 	system time =       0.26 seconds =       0.00 minutes
# 	total time  =          6 seconds =       0.10 minutes
#
# *** tstart() called on 4b17f6c6367b
# *** at Thu May 28 19:32:33 2026
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //               DFMP2               //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_MP2
#     atoms 1-2 entry C          line   112 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#     atoms 3-8 entry H          line    30 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#
# 	 --------------------------------------------------------
# 	                          DF-MP2
# 	      2nd-Order Density-Fitted Moller-Plesset Theory
# 	              RMP2 Wavefunction,   1 Threads
#
# 	        Rob Parrish, Justin Turney, Andy Simmonett,
# 	           Ed Hohenstein, and C. David Sherrill
# 	 --------------------------------------------------------
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-RI
#     Number of shells: 98
#     Number of basis functions: 282
#     Number of Cartesian functions: 322
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	 --------------------------------------------------------
# 	                 NBF =   100, NAUX =   282
# 	 --------------------------------------------------------
# 	   CLASS    FOCC     OCC    AOCC    AVIR     VIR    FVIR
# 	   PAIRS       0       9       9      91      91       0
# 	 --------------------------------------------------------
#
#   DFHelper Memory: AOs need 0.030 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#
#          ------------------------------------------------------------
#                                      CPHF
#                                   Rob Parrish
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C            0.000000000000    -0.769890033187     0.008763766121    12.000000000000
#          C            0.000000000000     0.769890033187     0.008763766121    12.000000000000
#          H           -0.526869151116    -1.155132808297     0.869338147061     1.007825032230
#          H            0.526869151116     1.155132808297     0.869338147061     1.007825032230
#          H           -1.011187194793     1.145729367186    -0.084674695444     1.007825032230
#          H            0.490048677219     1.132599771078    -0.889012113430     1.007825032230
#          H            1.011187194793    -1.145729367186    -0.084674695444     1.007825032230
#          H           -0.490048677219    -1.132599771078    -0.889012113430     1.007825032230
#
#   Nuclear repulsion =   42.352748184425522
#   Reference energy  =  -79.234366598678989
#
#   ==> Basis Set <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 48
#     Number of basis functions: 100
#     Number of Cartesian functions: 104
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> CGRSolver (by Rob Parrish) <==
#
#    Number of roots    =         1
#    Preconditioning    =    JACOBI
#    Convergence cutoff =     1E-06
#    Maximum iterations =       100
#
#   ==> CPHFRHamiltonian (by Rob Parrish) <==
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 128
#     Number of basis functions: 364
#     Number of Cartesian functions: 412
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> CPHF Iterations <==
#
#   => Iterations <=
#
#              Iter  Converged  Remaining    Residual
#   CGR           1          0          1   6.639E-02
#   CGR           2          0          1   1.415E-02
#   CGR           3          0          1   1.567E-03
#   CGR           4          0          1   2.081E-04
#   CGR           5          0          1   3.131E-05
#   CGR           6          0          1   5.902E-06
#   CGR           7          0          1   1.418E-06
#   CGR           8          1          0   1.470E-07
#
#     CGRSolver converged.
#
#   ==> DFCorrGrad: Density-Fitted Correlated Gradients <==
#
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [GiB]:            0.366
#     Schwarz Cutoff:          0E+00
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 128
#     Number of basis functions: 364
#     Number of Cartesian functions: 412
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	-----------------------------------------------------------
# 	 ==================> DF-MP2 Energies <====================
# 	-----------------------------------------------------------
# 	 Reference Energy          =     -79.2343665986789887 [Eh]
# 	 Singles Energy            =      -0.0000000000000000 [Eh]
# 	 Same-Spin Energy          =      -0.0673791323488742 [Eh]
# 	 Opposite-Spin Energy      =      -0.2518158458992278 [Eh]
# 	 Correlation Energy        =      -0.3191949782481020 [Eh]
# 	 Total Energy              =     -79.5535615769270947 [Eh]
# 	-----------------------------------------------------------
# 	 ================> DF-SCS-MP2 Energies <==================
# 	-----------------------------------------------------------
# 	 SCS Same-Spin Scale       =       0.3333333333333333 [-]
# 	 SCS Opposite-Spin Scale   =       1.2000000000000000 [-]
# 	 SCS Same-Spin Energy      =      -0.0224597107829581 [Eh]
# 	 SCS Opposite-Spin Energy  =      -0.3021790150790734 [Eh]
# 	 SCS Correlation Energy    =      -0.3246387258620314 [Eh]
# 	 SCS Total Energy          =     -79.5590053245410189 [Eh]
# 	-----------------------------------------------------------
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.000497207427    -0.017900440318     0.012309785870
#        2       -0.000497207427     0.017900440318     0.012309785870
#        3        0.001240660819     0.008145143255    -0.010805014358
#        4       -0.001240660819    -0.008145143255    -0.010805014358
#        5        0.011304202457    -0.005978373853    -0.008987722677
#        6       -0.009856671510    -0.003636088891     0.007482951164
#        7       -0.011304202457     0.005978373853    -0.008987722677
#        8        0.009856671510     0.003636088891     0.007482951164
#
#
# *** tstop() called on 4b17f6c6367b at Thu May 28 19:32:36 2026
# Module time:
# 	user time   =       2.32 seconds =       0.04 minutes
# 	system time =       0.07 seconds =       0.00 minutes
# 	total time  =          3 seconds =       0.05 minutes
# Total time:
# 	user time   =       7.71 seconds =       0.13 minutes
# 	system time =       0.33 seconds =       0.01 minutes
# 	total time  =          9 seconds =       0.15 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       6.000000            12.000000          0.00000000 -1.45488131  0.01656112
# 	       6.000000            12.000000          0.00000000  1.45488131  0.01656112
# 	       1.000000             1.007825         -0.99563840 -2.18288465  1.64281101
# 	       1.000000             1.007825          0.99563840  2.18288465  1.64281101
# 	       1.000000             1.007825         -1.91086686  2.16511472 -0.16001198
# 	       1.000000             1.007825          0.92605779  2.14030338 -1.67998942
# ...
# Module time:
# 	user time   =       0.80 seconds =       0.01 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      19.79 seconds =       0.33 minutes
# 	system time =       0.63 seconds =       0.01 minutes
# 	total time  =         21 seconds =       0.35 minutes
#
# *** tstart() called on 4b17f6c6367b
# *** at Thu May 28 19:32:48 2026
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //               DFMP2               //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_MP2
#     atoms 1-2 entry C          line   112 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#     atoms 3-8 entry H          line    30 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#
# 	 --------------------------------------------------------
# 	                          DF-MP2
# 	      2nd-Order Density-Fitted Moller-Plesset Theory
# 	              RMP2 Wavefunction,   1 Threads
#
# 	        Rob Parrish, Justin Turney, Andy Simmonett,
# 	           Ed Hohenstein, and C. David Sherrill
# 	 --------------------------------------------------------
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-RI
#     Number of shells: 98
#     Number of basis functions: 282
#     Number of Cartesian functions: 322
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	 --------------------------------------------------------
# 	                 NBF =   100, NAUX =   282
# 	 --------------------------------------------------------
# 	   CLASS    FOCC     OCC    AOCC    AVIR     VIR    FVIR
# 	   PAIRS       0       9       9      91      91       0
# 	 --------------------------------------------------------
#
#   DFHelper Memory: AOs need 0.030 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#
#          ------------------------------------------------------------
#                                      CPHF
#                                   Rob Parrish
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C            0.000000000000    -0.766145410262     0.000012388529    12.000000000000
#          C            0.000000000000     0.766145410262     0.000012388529    12.000000000000
#          H           -0.511974093665    -1.163624882026     0.888857796373     1.007825032230
#          H            0.511974093665     1.163624882026     0.888857796373     1.007825032230
#          H           -1.025824349686     1.163541510953    -0.001089748949     1.007825032230
#          H            0.513766961840     1.163467826856    -0.887915555519     1.007825032230
#          H            1.025824349686    -1.163541510953    -0.001089748949     1.007825032230
#          H           -0.513766961840    -1.163467826856    -0.887915555519     1.007825032230
#
#   Nuclear repulsion =   42.013932445683821
#   Reference energy  =  -79.236932629977787
#
#   ==> Basis Set <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 48
#     Number of basis functions: 100
#     Number of Cartesian functions: 104
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> CGRSolver (by Rob Parrish) <==
#
#    Number of roots    =         1
#    Preconditioning    =    JACOBI
#    Convergence cutoff =     1E-06
#    Maximum iterations =       100
#
#   ==> CPHFRHamiltonian (by Rob Parrish) <==
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 128
#     Number of basis functions: 364
#     Number of Cartesian functions: 412
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> CPHF Iterations <==
#
#   => Iterations <=
#
#              Iter  Converged  Remaining    Residual
#   CGR           1          0          1   7.160E-02
#   CGR           2          0          1   1.422E-02
#   CGR           3          0          1   1.522E-03
#   CGR           4          0          1   1.921E-04
#   CGR           5          0          1   2.531E-05
#   CGR           6          0          1   3.564E-06
#   CGR           7          1          0   4.370E-07
#
#     CGRSolver converged.
#
#   ==> DFCorrGrad: Density-Fitted Correlated Gradients <==
#
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [GiB]:            0.366
#     Schwarz Cutoff:          0E+00
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 128
#     Number of basis functions: 364
#     Number of Cartesian functions: 412
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	-----------------------------------------------------------
# 	 ==================> DF-MP2 Energies <====================
# 	-----------------------------------------------------------
# 	 Reference Energy          =     -79.2369326299777867 [Eh]
# 	 Singles Energy            =      -0.0000000000000000 [Eh]
# 	 Same-Spin Energy          =      -0.0673137742002977 [Eh]
# 	 Opposite-Spin Energy      =      -0.2527656950366056 [Eh]
# 	 Correlation Energy        =      -0.3200794692369033 [Eh]
# 	 Total Energy              =     -79.5570120992146883 [Eh]
# 	-----------------------------------------------------------
# 	 ================> DF-SCS-MP2 Energies <==================
# 	-----------------------------------------------------------
# 	 SCS Same-Spin Scale       =       0.3333333333333333 [-]
# 	 SCS Opposite-Spin Scale   =       1.2000000000000000 [-]
# 	 SCS Same-Spin Energy      =      -0.0224379247334326 [Eh]
# 	 SCS Opposite-Spin Energy  =      -0.3033188340439267 [Eh]
# 	 SCS Correlation Energy    =      -0.3257567587773593 [Eh]
# 	 SCS Total Energy          =     -79.5626893887551461 [Eh]
# 	-----------------------------------------------------------
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.000017754941    -0.000102127915     0.000025319628
#        2        0.000017754941     0.000102127915     0.000025319628
#        3        0.000035464590     0.000027203845    -0.000041574077
#        4       -0.000035464590    -0.000027203845    -0.000041574077
#        5        0.000031481157    -0.000020997785    -0.000010737614
#        6       -0.000012744588    -0.000026228254     0.000026992062
#        7       -0.000031481157     0.000020997785    -0.000010737614
#        8        0.000012744588     0.000026228254     0.000026992062
#
#
# *** tstop() called on 4b17f6c6367b at Thu May 28 19:32:51 2026
# Module time:
# 	user time   =       2.25 seconds =       0.04 minutes
# 	system time =       0.07 seconds =       0.00 minutes
# 	total time  =          3 seconds =       0.05 minutes
# Total time:
# 	user time   =      22.04 seconds =       0.37 minutes
# 	system time =       0.70 seconds =       0.01 minutes
# 	total time  =         24 seconds =       0.40 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       6.000000            12.000000          0.00000000 -1.44780500  0.00002341
# 	       6.000000            12.000000          0.00000000  1.44780500  0.00002341
# 	       1.000000             1.007825         -0.96749082 -2.19893234  1.67969780
# 	       1.000000             1.007825          0.96749082  2.19893234  1.67969780
# 	       1.000000             1.007825         -1.93852707  2.19877479 -0.00205933
# 	       1.000000             1.007825          0.97087885  2.19863555 -1.67791722
# 	       1.000000             1.007825          1.93852707 -2.19877479 -0.00205933
# 	       1.000000             1.007825         -0.97087885 -2.19863555 -1.67791722
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.895610           1.532291
# 	 R(1,3)           =         2.078831           1.100070
# 	 R(1,7)           =         2.078905           1.100109
# 	 R(1,8)           =         2.078903           1.100108
# 	 R(2,4)           =         2.078831           1.100070
# 	 R(2,5)           =         2.078905           1.100109
# 	 R(2,6)           =         2.078903           1.100108
# 	 B(1,2,4)         =         1.940482         111.181410
# 	 B(1,2,5)         =         1.940386         111.175956
# 	 B(1,2,6)         =         1.940315         111.171866
# 	 B(2,1,3)         =         1.940482         111.181410
# 	 B(2,1,7)         =         1.940386         111.175956
# 	 B(2,1,8)         =         1.940315         111.171866
# 	 B(3,1,7)         =         1.879961         107.713837
# 	 B(3,1,8)         =         1.880004         107.716317
# 	 B(4,2,5)         =         1.879961         107.713837
# 	 B(4,2,6)         =         1.880004         107.716317
# 	 B(5,2,6)         =         1.879901         107.710386
# 	 B(7,1,8)         =         1.879901         107.710386
# 	 D(3,1,2,4)       =         1.045170          59.883802
# 	 D(3,1,2,5)       =        -1.049286         -60.119657
# 	 D(3,1,2,6)       =        -3.143553        -180.112346
# 	 D(4,2,1,7)       =        -1.049286         -60.119657
# 	 D(4,2,1,8)       =        -3.143553        -180.112346
# 	 D(5,2,1,7)       =         3.139444         179.876884
# 	 D(5,2,1,8)       =         1.045176          59.884195
# 	 D(6,2,1,7)       =         1.045176          59.884195
# 	 D(6,2,1,8)       =        -1.049091         -60.108494
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.53229       -0.00023       -0.00008       1.53221
# 	               R(1,3)       1.10007        0.00049        0.00010       1.10017
# 	               R(1,7)       1.10011        0.00030        0.00006       1.10017
# 	               R(1,8)       1.10011        0.00031        0.00004       1.10015
# 	               R(2,4)       1.10007        0.00049        0.00010       1.10017
# 	               R(2,5)       1.10011        0.00030        0.00006       1.10017
# 	               R(2,6)       1.10011        0.00031        0.00004       1.10015
# 	             B(1,2,4)     111.18141        0.00000       -0.00018     111.18123
# 	             B(1,2,5)     111.17596        0.00000        0.00567     111.18163
# 	             B(1,2,6)     111.17187        0.00000        0.01043     111.18229
# 	             B(2,1,3)     111.18141        0.00000       -0.00018     111.18123
# 	             B(2,1,7)     111.17596        0.00000        0.00567     111.18163
# 	             B(2,1,8)     111.17187        0.00000        0.01043     111.18229
# 	             B(3,1,7)     107.71384       -0.00000       -0.00597     107.70787
# 	             B(3,1,8)     107.71632       -0.00000       -0.00855     107.70777
# 	             B(4,2,5)     107.71384       -0.00000       -0.00597     107.70787
# 	             B(4,2,6)     107.71632       -0.00000       -0.00855     107.70777
# 	             B(5,2,6)     107.71039       -0.00000       -0.00238     107.70801
# 	             B(7,1,8)     107.71039       -0.00000       -0.00238     107.70801
# 	           D(3,1,2,4)      59.88380        0.00000        0.07503      59.95883
# 	           D(3,1,2,5)     -60.11966        0.00000        0.07889     -60.04076
# 	           D(3,1,2,6)    -180.11235        0.00000        0.07110    -180.04125
# 	           D(4,2,1,7)     -60.11966        0.00000        0.07889     -60.04076
# 	           D(4,2,1,8)    -180.11235        0.00000        0.07110    -180.04125
# 	           D(5,2,1,7)     179.87688        0.00000        0.08276     179.95964
# 	           D(5,2,1,8)      59.88419        0.00000        0.07496      59.95916
# 	           D(6,2,1,7)      59.88419        0.00000        0.07496      59.95916
# 	           D(6,2,1,8)     -60.10849       -0.00000        0.06717     -60.04133
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp
# 	----------------------------------------------------------------------------------------------
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
# 	----------------------------------------------------------------------------------------------
# 	     6     -79.55701210   -8.77e-07 *    5.99e-05 *    2.32e-05 o    1.44e-03      7.50e-04 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	    C   0.0000118546  -0.7661030378  -0.0000409440
# 	    C  -0.0000118546   0.7661030378  -0.0000409440
# 	    H  -0.5125855578  -1.1636237181   0.8885515560
# 	    H   0.5125855578   1.1636237181   0.8885515560
# 	    H  -1.0258568358   1.1636055277  -0.0004022334
# 	    H   0.5132131567   1.1636363175  -0.8882434982
# 	    H   1.0258568358  -1.1636055277  -0.0004022334
# 	    H  -0.5132131567  -1.1636363175  -0.8882434982
#
#
#     Final optimized geometry and variables:
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     C
#     C             1         CC2
#     H             1         HC3      2        HCC3
#     H             2         HC4      1        HCC4      3       HCCH4
#     H             2         HC5      1        HCC5      3       HCCH5
#     H             2         HC6      1        HCC6      3       HCCH6
#     H             1         HC7      2        HCC7      4       HCCH7
#     H             1         HC8      2        HCC8      4       HCCH8
#
#     CC2       =    1.5322908205
#     HC3       =    1.1000697987
#     HC4       =    1.1000697987
#     HC5       =    1.1001093000
#     HC6       =    1.1001080073
#     HC7       =    1.1001093000
#     HC8       =    1.1001080073
#     HCC3      =  111.1814096852
#     HCC4      =  111.1814096852
#     HCC5      =  111.1759558521
#     HCC6      =  111.1718664814
#     HCC7      =  111.1759558521
#     HCC8      =  111.1718664814
#     HCCH4     =   59.8838016874
#     HCCH5     =  -60.1196572600
#     HCCH6     =  179.8876536502
#     HCCH7     =  -60.1196572600
#     HCCH8     =  179.8876536502
#
#
#     Psi4 stopped on: Thursday, 28 May 2026 07:32PM
#     Psi4 wall time for execution: 0:00:25.17
#
# *** Psi4 exiting successfully. Buy a developer a beer!
