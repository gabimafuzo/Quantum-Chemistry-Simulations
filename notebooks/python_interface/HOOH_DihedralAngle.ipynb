# %%
# %%bash
# set -euo pipefail
#
# MAMBA_ROOT="$HOME/mamba"
# MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
# if [ ! -x "$MAMBA_BIN" ]; then
#   mkdir -p "$MAMBA_ROOT"
#   curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj -C "$MAMBA_ROOT" bin/micromamba >/dev/null
# fi
#
# "$MAMBA_BIN" create -y -r "$MAMBA_ROOT" -n psi4 -c conda-forge psi4 python=3.12 >/dev/null

# %%
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
# %%bash
set -euo pipefail
MAMBA_ROOT="$HOME/mamba"
MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
cat > psi4.in <<'EOF'
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>


# Your input file should go in this middle section
# Write this as a classic-style Psi4 input file (not a Python script)

molecule{
 O
  O 1 OO2
  H 1 HO3 2 HOO3
  H 2 HO4 1 HOO4 3 HOOH

  OO2 = 1.5
  HO3 = 1.0
  HOO3 = 109.5
  HO4 = 1.0
  HOO4 = 109.5
  HOOH = 175
}

set {
  basis aug-cc-pVDZ
  reference rhf
  }
optimize ('MP2')

# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
EOF
"$MAMBA_BIN" run -r "$MAMBA_ROOT" -n psi4 psi4 psi4.in psi4.out
cat psi4.out
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Out:
# Optimizer: Optimization complete!
#
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, D. L. Poole, T. Győri, E. C. Mitchell, J. P. Pederson,
#     and A. M. Wallace
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     https://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Thursday, 28 May 2026 06:47PM
#
#     Process ID: 29044
#     Host:       4b17f6c6367b
#     PSIDATADIR: /root/mamba/envs/psi4/share/psi4
#     Memory:     500.0 MiB
#     Threads:    1
#     Addons:     a̶d̶c̶c̶, a̶m̶b̶i̶t̶, b̶s̶e̶, c̶c̶t̶3̶, c̶f̶o̶u̶r̶, c̶h̶e̶m̶p̶s̶2̶, c̶p̶p̶e̶, d̶d̶x̶,
#                 d̶f̶t̶d̶3̶, d̶f̶t̶d̶4̶, dkh, ecpint, einsums, f̶o̶r̶t̶e̶, g̶a̶u̶x̶c̶, g̶c̶p̶,
#                 g̶d̶m̶a̶, g̶e̶o̶m̶e̶t̶r̶i̶c̶, g̶p̶u̶_̶d̶f̶c̶c̶, i̶n̶t̶e̶g̶r̶a̶t̶o̶r̶x̶x̶,
#                 i̶p̶i̶, l̶i̶b̶e̶f̶p̶, m̶d̶i̶, m̶p̶2̶d̶, m̶r̶c̶c̶, ooo,
#                 o̶p̶e̶n̶f̶e̶r̶m̶i̶o̶n̶p̶s̶i̶4̶, pcmsolver, p̶s̶i̶4̶f̶o̶c̶k̶c̶i̶, p̶s̶i̶x̶a̶s̶,
#                 r̶e̶s̶p̶, s̶i̶m̶i̶n̶t̶, s̶n̶s̶m̶p̶2̶, v̶2̶r̶d̶m̶_̶c̶a̶s̶s̶c̶f̶
#
#   ==> Input File <==
#
# --------------------------------------------------------------------------
# # >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
#
# # Your input file should go in this middle section
# # Write this as a classic-style Psi4 input file (not a Python script)
#
# molecule{
#  O
#   O 1 OO2
#   H 1 HO3 2 HOO3
#   H 2 HO4 1 HOO4 3 HOOH
#
#   OO2 = 1.5
#   HO3 = 1.0
#   HOO3 = 109.5
#   HO4 = 1.0
#   HOO4 = 109.5
#   HOOH = 175
# }
#
# set {
#   basis aug-cc-pVDZ
#   reference rhf
#   }
# optimize ('MP2')
# # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# # STUDENTS SHOULD IGNORE THESE LINES
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#     SCF Algorithm Type (re)set to DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 4b17f6c6367b
# *** at Thu May 28 18:47:58 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry O          line   254 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 3-4 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.750000000000     0.002437206622    15.994914619570
#          O            0.000000000000    -0.750000000000     0.002437206622    15.994914619570
#          H           -0.941744305265     1.083806859234    -0.038680237724     1.007825032230
#          H            0.941744305265    -1.083806859234    -0.038680237724     1.007825032230
#
#   Running in c2 symmetry.
#
#   Rotational constants: A =     10.76677  B =      0.81872  C =      0.76108 [cm^-1]
#   Rotational constants: A = 322779.68989  B =  24544.53823  C =  22816.63953 [MHz]
#   Nuclear repulsion =   35.335674880932388
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 64
#     Number of Cartesian functions: 68
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry O          line   270 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#     atoms 3-4 entry H          line    70 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.008 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 2.4215874360E-03.
#   Reciprocal condition number of the overlap matrix is 4.8846141455E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         32      32
#      B         32      32
#    -------------------------
#     Total      64      64
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter SAD:  -151.17980799409466   -1.51180e+02   0.00000e+00
#    @DF-RHF iter   1:  -148.73078337973675    2.44902e+00   3.20812e-02 ADIIS/DIIS
#    @DF-RHF iter   2:  -150.10519172737435   -1.37441e+00   2.91950e-02 ADIIS/DIIS
#    @DF-RHF iter   3:  -150.76840850105901   -6.63217e-01   3.34481e-03 ADIIS/DIIS
#    @DF-RHF iter   4:  -150.78045569500310   -1.20472e-02   7.50552e-04 ADIIS/DIIS
#    @DF-RHF iter   5:  -150.78139602714782   -9.40332e-04   1.41801e-04 ADIIS/DIIS
#    @DF-RHF iter   6:  -150.78144686410747   -5.08370e-05   2.60552e-05 DIIS
#    @DF-RHF iter   7:  -150.78144892832159   -2.06421e-06   5.82570e-06 DIIS
#    @DF-RHF iter   8:  -150.78144905211633   -1.23795e-07   1.57764e-06 DIIS
#    @DF-RHF iter   9:  -150.78144906298022   -1.08639e-08   6.18356e-07 DIIS
#    @DF-RHF iter  10:  -150.78144906512392   -2.14371e-09   2.74527e-07 DIIS
#    @DF-RHF iter  11:  -150.78144906568514   -5.61215e-10   9.29134e-08 DIIS
#    @DF-RHF iter  12:  -150.78144906574025   -5.51097e-11   2.05362e-08 DIIS
#    @DF-RHF iter  13:  -150.78144906574164   -1.39266e-12   4.65038e-09 DIIS
#    @DF-RHF iter  14:  -150.78144906574175   -1.13687e-13   8.86991e-10 DIIS
#    @DF-RHF iter  15:  -150.78144906574178   -2.84217e-14   1.23544e-10 DIIS
#    @DF-RHF iter  16:  -150.78144906574175    2.84217e-14   1.71935e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.643075     1B    -20.642828     2A     -1.441009
#        2B     -1.219268     3B     -0.695952     3A     -0.685095
#        4A     -0.613337     5A     -0.522088     4B     -0.464508
#
#     Virtual:
#
#        6A      0.041355     5B      0.045065     6B      0.123975
#        7B      0.178155     7A      0.198366     8A      0.202872
#        9A      0.222795    10A      0.241025     8B      0.242272
#        9B      0.279343    10B      0.330156    11A      0.339399
#       11B      0.372593    12B      0.415836    12A      0.450304
#       13B      0.471076    13A      0.527441    14B      0.635016
#       14A      0.640274    15B      0.836500    15A      0.902485
#       16A      1.001169    16B      1.052839    17A      1.088615
#       17B      1.107452    18A      1.203026    19A      1.223189
#       18B      1.272795    19B      1.281903    20A      1.389122
#       21A      1.445612    20B      1.517679    21B      1.596421
#       22B      1.696646    22A      1.713042    23B      2.000385
#       24B      2.091036    23A      2.120309    24A      2.143130
#       25B      2.360141    25A      2.458976    26A      2.513877
#       26B      2.790345    27A      2.810858    28A      3.424480
#       27B      3.461875    29A      3.509814    28B      3.618938
#       29B      3.654153    30A      3.671152    31A      3.722756
#       30B      3.743581    32A      4.056002    31B      4.104451
#       32B      4.217178
#
#     Final Occupation by Irrep:
#               A     B
#     DOCC [     5,    4 ]
#     NA   [     5,    4 ]
#     NB   [     5,    4 ]
#
#   @DF-RHF Final Energy:  -150.78144906574175
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             35.3356748809323875
#     One-Electron Energy =                -278.3799294761793703
#     Two-Electron Energy =                  92.2628055295051865
#     Total Energy =                       -150.7814490657417821
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0127818           -0.0724997           -0.0597178
#  Magnitude           :                                                    0.0597178
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on 4b17f6c6367b at Thu May 28 18:47:59 2026
# Module time:
# 	user time   =       1.02 seconds =       0.02 minutes
# 	system time =       0.11 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       1.02 seconds =       0.02 minutes
# 	system time =       0.11 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
#
# *** tstart() called on 4b17f6c6367b
# *** at Thu May 28 18:47:59 2026
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //               DFMP2               //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_MP2
#     atoms 1-2 entry O          line   204 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#     atoms 3-4 entry H          line    30 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#
# 	 --------------------------------------------------------
# 	                          DF-MP2
# 	      2nd-Order Density-Fitted Moller-Plesset Theory
# 	              RMP2 Wavefunction,   1 Threads
#
# 	        Rob Parrish, Justin Turney, Andy Simmonett,
# 	           Ed Hohenstein, and C. David Sherrill
# 	 --------------------------------------------------------
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-RI
#     Number of shells: 62
#     Number of basis functions: 190
#     Number of Cartesian functions: 222
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	 --------------------------------------------------------
# 	                 NBF =    64, NAUX =   190
# 	 --------------------------------------------------------
# 	   CLASS    FOCC     OCC    AOCC    AVIR     VIR    FVIR
# 	   PAIRS       0       9       9      55      55       0
# 	 --------------------------------------------------------
#
#   DFHelper Memory: AOs need 0.008 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#
#          ------------------------------------------------------------
#                                      CPHF
#                                   Rob Parrish
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.750000000000     0.002437206622    15.994914619570
#          O            0.000000000000    -0.750000000000     0.002437206622    15.994914619570
#          H           -0.941744305265     1.083806859234    -0.038680237724     1.007825032230
#          H            0.941744305265    -1.083806859234    -0.038680237724     1.007825032230
#
#   Nuclear repulsion =   35.335674880932388
#   Reference energy  = -150.781449065741754
#
#   ==> Basis Set <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 64
#     Number of Cartesian functions: 68
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> CGRSolver (by Rob Parrish) <==
#
#    Number of roots    =         1
#    Preconditioning    =    JACOBI
#    Convergence cutoff =     1E-06
#    Maximum iterations =       100
#
#   ==> CPHFRHamiltonian (by Rob Parrish) <==
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> CPHF Iterations <==
#
#   => Iterations <=
#
#              Iter  Converged  Remaining    Residual
#   CGR           1          0          1   8.449E-02
#   CGR           2          0          1   2.195E-02
#   CGR           3          0          1   3.913E-03
#   CGR           4          0          1   7.966E-04
#   CGR           5          0          1   1.700E-04
#   CGR           6          0          1   9.782E-05
#   CGR           7          0          1   4.149E-05
#   CGR           8          0          1   1.143E-05
#   CGR           9          0          1   2.202E-06
#   CGR          10          1          0   4.920E-07
#
#     CGRSolver converged.
#
#   ==> DFCorrGrad: Density-Fitted Correlated Gradients <==
#
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [GiB]:            0.366
#     Schwarz Cutoff:          0E+00
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	-----------------------------------------------------------
# 	 ==================> DF-MP2 Energies <====================
# 	-----------------------------------------------------------
# 	 Reference Energy          =    -150.7814490657417537 [Eh]
# 	 Singles Energy            =      -0.0000000000000000 [Eh]
# 	 Same-Spin Energy          =      -0.1100782820943278 [Eh]
# 	 Opposite-Spin Energy      =      -0.3162330078301939 [Eh]
# 	 Correlation Energy        =      -0.4263112899245217 [Eh]
# 	 Total Energy              =    -151.2077603556662666 [Eh]
# 	-----------------------------------------------------------
# 	 ================> DF-SCS-MP2 Energies <==================
# 	-----------------------------------------------------------
# 	 SCS Same-Spin Scale       =       0.3333333333333333 [-]
# 	 SCS Opposite-Spin Scale   =       1.2000000000000000 [-]
# 	 SCS Same-Spin Energy      =      -0.0366927606981093 [Eh]
# 	 SCS Opposite-Spin Energy  =      -0.3794796093962327 [Eh]
# 	 SCS Correlation Energy    =      -0.4161723700943419 [Eh]
# 	 SCS Total Energy          =    -151.1976214358360835 [Eh]
# 	-----------------------------------------------------------
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.020407002612    -0.007022992016     0.000132638343
#        2        0.020407002612     0.007022992016     0.000132638343
#        3       -0.015754310947     0.034382892665    -0.000132638343
#        4        0.015754310947    -0.034382892665    -0.000132638343
#
#
# *** tstop() called on 4b17f6c6367b at Thu May 28 18:48:00 2026
# Module time:
# 	user time   =       0.70 seconds =       0.01 minutes
# 	system time =       0.04 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       1.72 seconds =       0.03 minutes
# 	system time =       0.15 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       8.000000            15.994915          0.00000000  1.41729459  0.00460565
# 	       8.000000            15.994915          0.00000000 -1.41729459  0.00460565
# 	       1.000000             1.007825         -1.77963882  2.04809814 -0.07309506
# 	       1.000000             1.007825          1.77963882 -2.04809814 -0.07309506
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.834589           1.500000
# 	 R(1,3)           =         1.889726           1.000000
# 	 R(2,4)           =         1.889726           1.000000
# 	 B(1,2,4)         =         1.911136         109.500000
# 	 B(2,1,3)         =         1.911136         109.500000
# 	 D(3,1,2,4)       =         3.054326         175.000000
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.50000       -0.22541       -0.04067       1.45933
# 	               R(1,3)       1.00000       -0.21684       -0.02736       0.97264
# 	               R(2,4)       1.00000       -0.21684       -0.02736       0.97264
# 	             B(1,2,4)     109.50000       -0.00390      -15.29365      94.20635
# 	             B(2,1,3)     109.50000       -0.00390      -15.29365      94.20635
# 	           D(3,1,2,4)     175.00000       -0.00008       -1.63872     173.36128
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------~
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp   ~
# 	----------------------------------------------------------------------------------------------~
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o~
# 	----------------------------------------------------------------------------------------------~
# 	     1    -151.20776036   -1.51e+02      5.13e-02      3.51e-02 o    2.67e-01      1.61e-01 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	    O   0.0918563706   0.7238616267   0.0099613732
# 	    O  -0.0918563706  -0.7238616267   0.0099613732
# 	    H  -0.8598554194   0.9165459846  -0.0462044043
# 	    H   0.8598554194  -0.9165459846  -0.0462044043
#
#
#     Structure for next step:
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     O
#     O             1         OO2
#     H             1         HO3      2        HOO3
#     H             2         HO4      1        HOO4      3        HOOH
#
#     HO3       =    0.9726444302
#     HO4       =    0.9726444302
#     HOO3      =   94.2063486526
#     HOO4      =   94.2063486526
#     HOOH      =  173.3612750038
#     OO2       =    1.4593330634
#
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#     SCF Algorithm Type (re)set to DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 4b17f6c6367b
# *** at Thu May 28 18:48:00 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry O          line   254 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 3-4 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.729666531715     0.003329185633    15.994914619570
#          O            0.000000000000    -0.729666531715     0.003329185633    15.994914619570
#          H           -0.968397068541     0.801008740125    -0.052836591914     1.007825032230
#          H            0.968397068541    -0.801008740125    -0.052836591914     1.007825032230
#
#   Running in c2 symmetry.
#
#   Rotational constants: A =      9.63943  B =      0.91228  C =      0.83390 [cm^-1]
#   Rotational constants: A = 288982.88687  B =  27349.58970  C =  24999.77477 [MHz]
#   Nuclear repulsion =   36.795150722641544
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 64
#     Number of Cartesian functions: 68
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry O          line   270 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#     atoms 3-4 entry H          line    70 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry O          line   254 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 3-4 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#   Reading orbitals from file /tmp/psi4.default.29044.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.008 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 2.1660775527E-03.
#   Reciprocal condition number of the overlap matrix is 4.1851075065E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A         32      32       5       5       5       0
#      B         32      32       4       4       4       0
#    -------------------------------------------------------
#     Total      64      64       9       9       9       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter   0:  -150.82166990337575   -1.50822e+02   4.95717e-03
#    @DF-RHF iter   1:  -150.79530120212416    2.63687e-02   9.50193e-04 ADIIS/DIIS
#    @DF-RHF iter   2:  -150.79619921297078   -8.98011e-04   2.61865e-04 ADIIS/DIIS
#    @DF-RHF iter   3:  -150.79628268448840   -8.34715e-05   1.06096e-04 ADIIS/DIIS
#    @DF-RHF iter   4:  -150.79629711189853   -1.44274e-05   2.49172e-05 DIIS
#    @DF-RHF iter   5:  -150.79629848431279   -1.37241e-06   8.72854e-06 DIIS
#    @DF-RHF iter   6:  -150.79629882552933   -3.41217e-07   3.77751e-06 DIIS
#    @DF-RHF iter   7:  -150.79629892145329   -9.59240e-08   1.15092e-06 DIIS
#    @DF-RHF iter   8:  -150.79629892991895   -8.46566e-09   2.07961e-07 DIIS
#    @DF-RHF iter   9:  -150.79629893011614   -1.97190e-10   4.58007e-08 DIIS
#    @DF-RHF iter  10:  -150.79629893012370   -7.56017e-12   9.36329e-09 DIIS
#    @DF-RHF iter  11:  -150.79629893012410   -3.97904e-13   1.85818e-09 DIIS
#    @DF-RHF iter  12:  -150.79629893012404    5.68434e-14   5.21195e-10 DIIS
#    @DF-RHF iter  13:  -150.79629893012398    5.68434e-14   9.12626e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.641857     1B    -20.641579     2A     -1.481514
#        2B     -1.215791     3B     -0.739854     3A     -0.655413
#        4A     -0.628744     5A     -0.558277     4B     -0.461923
#
#     Virtual:
#
#        6A      0.041474     5B      0.049771     6B      0.127535
#        7B      0.193672     7A      0.194087     8A      0.204220
#        9A      0.205881    10A      0.239176     8B      0.244154
#        9B      0.294472    11A      0.326862    10B      0.348325
#       11B      0.367317    12B      0.440556    13B      0.458838
#       12A      0.472156    13A      0.549363    14B      0.636768
#       14A      0.640680    15A      0.885247    15B      0.908820
#       16A      1.000781    16B      1.063651    17B      1.084403
#       17A      1.119312    18A      1.185852    18B      1.267265
#       19B      1.284045    19A      1.297286    20A      1.390938
#       21A      1.411379    20B      1.477617    21B      1.535373
#       22B      1.695675    22A      1.800878    23A      2.042020
#       23B      2.107502    24A      2.159436    24B      2.160918
#       25A      2.325769    25B      2.408648    26A      2.552385
#       26B      2.733283    27A      2.870840    28A      3.437592
#       29A      3.467506    27B      3.536064    28B      3.603243
#       30A      3.661169    29B      3.662194    30B      3.769730
#       31A      3.807333    32A      4.056613    31B      4.125312
#       32B      4.349839
#
#     Final Occupation by Irrep:
#               A     B
#     DOCC [     5,    4 ]
#     NA   [     5,    4 ]
#     NB   [     5,    4 ]
#
#   @DF-RHF Final Energy:  -150.79629893012398
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             36.7951507226415444
#     One-Electron Energy =                -281.1329983612652086
#     Two-Electron Energy =                  93.5415487084996755
#     Total Energy =                       -150.7962989301239816
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0202608           -0.0990334           -0.0787726
#  Magnitude           :                                                    0.0787726
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on 4b17f6c6367b at Thu May 28 18:48:00 2026
# Module time:
# 	user time   =       0.43 seconds =       0.01 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       2.22 seconds =       0.04 minutes
# 	system time =       0.16 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
#
# *** tstart() called on 4b17f6c6367b
# *** at Thu May 28 18:48:00 2026
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //               DFMP2               //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_MP2
#     atoms 1-2 entry O          line   204 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#     atoms 3-4 entry H          line    30 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#
# 	 --------------------------------------------------------
# 	                          DF-MP2
# 	      2nd-Order Density-Fitted Moller-Plesset Theory
# 	              RMP2 Wavefunction,   1 Threads
#
# 	        Rob Parrish, Justin Turney, Andy Simmonett,
# 	           Ed Hohenstein, and C. David Sherrill
# 	 --------------------------------------------------------
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-RI
#     Number of shells: 62
#     Number of basis functions: 190
#     Number of Cartesian functions: 222
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	 --------------------------------------------------------
# 	                 NBF =    64, NAUX =   190
# 	 --------------------------------------------------------
# 	   CLASS    FOCC     OCC    AOCC    AVIR     VIR    FVIR
# 	   PAIRS       0       9       9      55      55       0
# 	 --------------------------------------------------------
#
#   DFHelper Memory: AOs need 0.008 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#
#          ------------------------------------------------------------
#                                      CPHF
#                                   Rob Parrish
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.729666531715     0.003329185633    15.994914619570
#          O            0.000000000000    -0.729666531715     0.003329185633    15.994914619570
#          H           -0.968397068541     0.801008740125    -0.052836591914     1.007825032230
#          H            0.968397068541    -0.801008740125    -0.052836591914     1.007825032230
#
#   Nuclear repulsion =   36.795150722641552
#   Reference energy  = -150.796298930123982
#
#   ==> Basis Set <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 64
#     Number of Cartesian functions: 68
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> CGRSolver (by Rob Parrish) <==
#
#    Number of roots    =         1
#    Preconditioning    =    JACOBI
#    Convergence cutoff =     1E-06
#    Maximum iterations =       100
#
#   ==> CPHFRHamiltonian (by Rob Parrish) <==
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> CPHF Iterations <==
#
#   => Iterations <=
#
#              Iter  Converged  Remaining    Residual
#   CGR           1          0          1   7.369E-02
#   CGR           2          0          1   1.769E-02
#   CGR           3          0          1   2.971E-03
#   CGR           4          0          1   5.565E-04
#   CGR           5          0          1   1.981E-04
#   CGR           6          0          1   1.241E-04
#   CGR           7          0          1   2.902E-05
#   CGR           8          0          1   5.717E-06
#   CGR           9          1          0   8.250E-07
#
#     CGRSolver converged.
#
#   ==> DFCorrGrad: Density-Fitted Correlated Gradients <==
#
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [GiB]:            0.366
#     Schwarz Cutoff:          0E+00
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	-----------------------------------------------------------
# 	 ==================> DF-MP2 Energies <====================
# 	-----------------------------------------------------------
# 	 Reference Energy          =    -150.7962989301239816 [Eh]
# 	 Singles Energy            =      -0.0000000000000000 [Eh]
# 	 Same-Spin Energy          =      -0.1099585517039170 [Eh]
# 	 Opposite-Spin Energy      =      -0.3130574621937026 [Eh]
# 	 Correlation Energy        =      -0.4230160138976196 [Eh]
# 	 Total Energy              =    -151.2193149440215905 [Eh]
# 	-----------------------------------------------------------
# 	 ================> DF-SCS-MP2 Energies <==================
# 	-----------------------------------------------------------
# 	 SCS Same-Spin Scale       =       0.3333333333333333 [-]
# 	 SCS Opposite-Spin Scale   =       1.2000000000000000 [-]
# 	 SCS Same-Spin Energy      =      -0.0366528505679723 [Eh]
# 	 SCS Opposite-Spin Energy  =      -0.3756689546324430 [Eh]
# 	 SCS Correlation Energy    =      -0.4123218052004154 [Eh]
# 	 SCS Total Energy          =    -151.2086207353243879 [Eh]
# 	-----------------------------------------------------------
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.017030408031    -0.011466194042    -0.000148867149
#        2       -0.017030408031     0.011466194042    -0.000148867149
#        3       -0.002939995914    -0.010400229829     0.000148867149
#        4        0.002939995914     0.010400229829     0.000148867149
#
#
# *** tstop() called on 4b17f6c6367b at Thu May 28 18:48:01 2026
# Module time:
# 	user time   =       0.69 seconds =       0.01 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       2.91 seconds =       0.05 minutes
# 	system time =       0.18 seconds =       0.00 minutes
# 	total time  =          3 seconds =       0.05 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       8.000000            15.994915          0.00000000  1.37886991  0.00629125
# 	       8.000000            15.994915          0.00000000 -1.37886991  0.00629125
# 	       1.000000             1.007825         -1.83000524  1.51368714 -0.09984669
# 	       1.000000             1.007825          1.83000524 -1.51368714 -0.09984669
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.757740           1.459333
# 	 R(1,3)           =         1.838032           0.972644
# 	 R(2,4)           =         1.838032           0.972644
# 	 B(1,2,4)         =         1.644211          94.206349
# 	 B(2,1,3)         =         1.644211          94.206349
# 	 D(3,1,2,4)       =         3.025725         173.361275
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.45933        0.18015        0.02419       1.48352
# 	               R(1,3)       0.97264       -0.01776       -0.00271       0.96994
# 	               R(2,4)       0.97264       -0.01776       -0.00271       0.96994
# 	             B(1,2,4)      94.20635        0.00148        3.94011      98.14646
# 	             B(2,1,3)      94.20635        0.00148        3.94011      98.14646
# 	           D(3,1,2,4)     173.36128       -0.00004       -6.38119     166.98008
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp
# 	----------------------------------------------------------------------------------------------
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
# 	----------------------------------------------------------------------------------------------
# 	     2    -151.21931494   -1.16e-02      2.19e-02      1.44e-02 o    1.11e-01      6.33e-02 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	    O  -0.0298276496   0.7411598713   0.0296751225
# 	    O   0.0298276496  -0.7411598713   0.0296751225
# 	    H  -0.9885401558   0.8401318850  -0.0791825288
# 	    H   0.9885401558  -0.8401318850  -0.0791825288
#
#
#     Structure for next step:
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     O
#     O             1         OO2
#     H             1         HO3      2        HOO3
#     H             2         HO4      1        HOO4      3        HOOH
#
#     HO3       =    0.9699356254
#     HO4       =    0.9699356254
#     HOO3      =   98.1464587656
#     HOO4      =   98.1464587656
#     HOOH      =  166.9800836053
#     OO2       =    1.4835196574
#
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#     SCF Algorithm Type (re)set to DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 4b17f6c6367b
# *** at Thu May 28 18:48:01 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry O          line   254 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 3-4 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.741759828724     0.006452458148    15.994914619570
#          O            0.000000000000    -0.741759828724     0.006452458148    15.994914619570
#          H           -0.953957207964     0.879203542501    -0.102405193219     1.007825032230
#          H            0.953957207964    -0.879203542501    -0.102405193219     1.007825032230
#
#   Running in c2 symmetry.
#
#   Rotational constants: A =      9.95517  B =      0.87142  C =      0.80299 [cm^-1]
#   Rotational constants: A = 298448.39685  B =  26124.47593  C =  24073.17037 [MHz]
#   Nuclear repulsion =   36.256379353816648
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 64
#     Number of Cartesian functions: 68
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry O          line   270 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#     atoms 3-4 entry H          line    70 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry O          line   254 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 3-4 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#   Reading orbitals from file /tmp/psi4.default.29044.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.008 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 2.1922009756E-03.
#   Reciprocal condition number of the overlap matrix is 4.2796654097E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A         32      32       5       5       5       0
#      B         32      32       4       4       4       0
#    -------------------------------------------------------
#     Total      64      64       9       9       9       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
# ...
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A         32      32       5       5       5       0
#      B         32      32       4       4       4       0
#    -------------------------------------------------------
#     Total      64      64       9       9       9       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter   0:  -150.79925226352373   -1.50799e+02   4.56425e-05
#    @DF-RHF iter   1:  -150.79941463458567   -1.62371e-04   8.82183e-06 DIIS
#    @DF-RHF iter   2:  -150.79941474535437   -1.10769e-07   2.99888e-06 DIIS
#    @DF-RHF iter   3:  -150.79941476561501   -2.02606e-08   1.35952e-06 DIIS
#    @DF-RHF iter   4:  -150.79941477023996   -4.62495e-09   4.57929e-07 DIIS
#    @DF-RHF iter   5:  -150.79941477085930   -6.19337e-10   1.23153e-07 DIIS
#    @DF-RHF iter   6:  -150.79941477090819   -4.88853e-11   2.56836e-08 DIIS
#    @DF-RHF iter   7:  -150.79941477091097   -2.78533e-12   1.17691e-08 DIIS
#    @DF-RHF iter   8:  -150.79941477091197   -9.94760e-13   3.50518e-09 DIIS
#    @DF-RHF iter   9:  -150.79941477091208   -1.13687e-13   4.65015e-10 DIIS
#    @DF-RHF iter  10:  -150.79941477091194    1.42109e-13   1.26495e-10 DIIS
#    @DF-RHF iter  11:  -150.79941477091191    2.84217e-14   3.42588e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.644840     1B    -20.644569     2A     -1.473376
#        2B     -1.221725     3B     -0.711009     3A     -0.709965
#        4A     -0.606609     5A     -0.522462     4B     -0.490797
#
#     Virtual:
#
#        6A      0.039055     5B      0.049625     6B      0.132350
#        7A      0.168559     7B      0.197978     8A      0.213819
#        9A      0.230553     8B      0.234017    10A      0.242359
#        9B      0.277858    10B      0.304685    11A      0.352255
#       11B      0.419717    12A      0.426992    12B      0.455049
#       13B      0.479223    13A      0.499214    14A      0.630818
#       14B      0.652850    15B      0.843045    15A      0.884743
#       16A      1.052353    17A      1.065599    16B      1.072384
#       17B      1.141243    18A      1.183998    18B      1.233005
#       19A      1.284757    19B      1.308611    20B      1.432064
#       20A      1.437181    21A      1.510741    21B      1.541575
#       22B      1.691619    22A      1.768244    23A      2.047591
#       23B      2.069506    24A      2.110169    24B      2.186868
#       25B      2.281602    25A      2.378148    26A      2.540681
#       26B      2.705369    27A      2.851470    28A      3.410436
#       27B      3.547324    29A      3.551718    28B      3.638084
#       30A      3.666375    29B      3.669829    30B      3.765883
#       31A      3.774971    31B      4.045548    32A      4.117228
#       32B      4.302994
#
#     Final Occupation by Irrep:
#               A     B
#     DOCC [     5,    4 ]
#     NA   [     5,    4 ]
#     NB   [     5,    4 ]
#
#   @DF-RHF Final Energy:  -150.79941477091191
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             36.4671283869804341
#     One-Electron Energy =                -280.4823823154442834
#     Two-Electron Energy =                  93.2158391575519261
#     Total Energy =                       -150.7994147709119090
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.1885493           -0.9341662           -0.7456169
#  Magnitude           :                                                    0.7456169
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on 4b17f6c6367b at Thu May 28 18:48:14 2026
# Module time:
# 	user time   =       0.39 seconds =       0.01 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      15.69 seconds =       0.26 minutes
# 	system time =       0.46 seconds =       0.01 minutes
# 	total time  =         16 seconds =       0.27 minutes
#
# *** tstart() called on 4b17f6c6367b
# *** at Thu May 28 18:48:14 2026
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //               DFMP2               //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_MP2
#     atoms 1-2 entry O          line   204 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#     atoms 3-4 entry H          line    30 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#
# 	 --------------------------------------------------------
# 	                          DF-MP2
# 	      2nd-Order Density-Fitted Moller-Plesset Theory
# 	              RMP2 Wavefunction,   1 Threads
#
# 	        Rob Parrish, Justin Turney, Andy Simmonett,
# 	           Ed Hohenstein, and C. David Sherrill
# 	 --------------------------------------------------------
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-RI
#     Number of shells: 62
#     Number of basis functions: 190
#     Number of Cartesian functions: 222
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	 --------------------------------------------------------
# 	                 NBF =    64, NAUX =   190
# 	 --------------------------------------------------------
# 	   CLASS    FOCC     OCC    AOCC    AVIR     VIR    FVIR
# 	   PAIRS       0       9       9      55      55       0
# 	 --------------------------------------------------------
#
#   DFHelper Memory: AOs need 0.008 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#
#          ------------------------------------------------------------
#                                      CPHF
#                                   Rob Parrish
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.735014201210     0.031403678288    15.994914619570
#          O            0.000000000000    -0.735014201210     0.031403678288    15.994914619570
#          H           -0.799116264516     0.889358284449    -0.498399163433     1.007825032230
#          H            0.799116264516    -0.889358284449    -0.498399163433     1.007825032230
#
#   Nuclear repulsion =   36.467128386980448
#   Reference energy  = -150.799414770911909
#
#   ==> Basis Set <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 64
#     Number of Cartesian functions: 68
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> CGRSolver (by Rob Parrish) <==
#
#    Number of roots    =         1
#    Preconditioning    =    JACOBI
#    Convergence cutoff =     1E-06
#    Maximum iterations =       100
#
#   ==> CPHFRHamiltonian (by Rob Parrish) <==
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> CPHF Iterations <==
#
#   => Iterations <=
#
#              Iter  Converged  Remaining    Residual
#   CGR           1          0          1   8.046E-02
#   CGR           2          0          1   2.063E-02
#   CGR           3          0          1   4.558E-03
#   CGR           4          0          1   1.770E-03
#   CGR           5          0          1   6.436E-04
#   CGR           6          0          1   2.032E-04
#   CGR           7          0          1   3.235E-05
#   CGR           8          0          1   6.878E-06
#   CGR           9          0          1   1.438E-06
#   CGR          10          1          0   3.440E-07
#
#     CGRSolver converged.
#
#   ==> DFCorrGrad: Density-Fitted Correlated Gradients <==
#
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [GiB]:            0.366
#     Schwarz Cutoff:          0E+00
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	-----------------------------------------------------------
# 	 ==================> DF-MP2 Energies <====================
# 	-----------------------------------------------------------
# 	 Reference Energy          =    -150.7994147709119090 [Eh]
# 	 Singles Energy            =      -0.0000000000000000 [Eh]
# 	 Same-Spin Energy          =      -0.1098186163443574 [Eh]
# 	 Opposite-Spin Energy      =      -0.3134620092628431 [Eh]
# 	 Correlation Energy        =      -0.4232806256072005 [Eh]
# 	 Total Energy              =    -151.2226953965191001 [Eh]
# 	-----------------------------------------------------------
# 	 ================> DF-SCS-MP2 Energies <==================
# 	-----------------------------------------------------------
# 	 SCS Same-Spin Scale       =       0.3333333333333333 [-]
# 	 SCS Opposite-Spin Scale   =       1.2000000000000000 [-]
# 	 SCS Same-Spin Energy      =      -0.0366062054481191 [Eh]
# 	 SCS Opposite-Spin Energy  =      -0.3761544111154118 [Eh]
# 	 SCS Correlation Energy    =      -0.4127606165635309 [Eh]
# 	 SCS Total Energy          =    -151.2121753874754404 [Eh]
# 	-----------------------------------------------------------
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.000006413383    -0.000028203383    -0.000000211525
#        2        0.000006413383     0.000028203383    -0.000000211525
#        3        0.000010202958    -0.000005448879     0.000000211525
#        4       -0.000010202958     0.000005448879     0.000000211525
#
#
# *** tstop() called on 4b17f6c6367b at Thu May 28 18:48:15 2026
# Module time:
# 	user time   =       0.71 seconds =       0.01 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =      16.40 seconds =       0.27 minutes
# 	system time =       0.48 seconds =       0.01 minutes
# 	total time  =         17 seconds =       0.28 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       8.000000            15.994915          0.00000000  1.38897554  0.05934435
# 	       8.000000            15.994915          0.00000000 -1.38897554  0.05934435
# 	       1.000000             1.007825         -1.51011088  1.68064359 -0.94183792
# 	       1.000000             1.007825          1.51011088 -1.68064359 -0.94183792
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.777951           1.470028
# 	 R(1,3)           =         1.835176           0.971133
# 	 R(2,4)           =         1.835176           0.971133
# 	 B(1,2,4)         =         1.730405          99.144906
# 	 B(2,1,3)         =         1.730405          99.144906
# 	 D(3,1,2,4)       =         1.970693         112.912363
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.47003        0.00028        0.00007       1.47010
# 	               R(1,3)       0.97113        0.00008        0.00001       0.97114
# 	               R(2,4)       0.97113        0.00008        0.00001       0.97114
# 	             B(1,2,4)      99.14491        0.00000       -0.00247      99.14244
# 	             B(2,1,3)      99.14491        0.00000       -0.00247      99.14244
# 	           D(3,1,2,4)     112.91236        0.00000        0.05251     112.96488
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp
# 	----------------------------------------------------------------------------------------------
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
# 	----------------------------------------------------------------------------------------------
# 	    12    -151.22269540   -2.54e-07 *    3.37e-05 *    1.59e-05 o    9.17e-04 *    3.79e-04 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	    O   0.0000860473   0.7350498589   0.0312248013
# 	    O  -0.0000860473  -0.7350498589   0.0312248013
# 	    H  -0.7992676789   0.8894476527  -0.4982202865
# 	    H   0.7992676789  -0.8894476527  -0.4982202865
#
#
#     Final optimized geometry and variables:
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     O
#     O             1         OO2
#     H             1         HO3      2        HOO3
#     H             2         HO4      1        HOO4      3        HOOH
#
#     HO3       =    0.9711333335
#     HO4       =    0.9711333335
#     HOO3      =   99.1449063649
#     HOO4      =   99.1449063649
#     HOOH      =  112.9123634958
#     OO2       =    1.4700284024
#
#
#     Psi4 stopped on: Thursday, 28 May 2026 06:48PM
#     Psi4 wall time for execution: 0:00:18.22
#
# *** Psi4 exiting successfully. Buy a developer a beer!
