# %%
# %%bash
# set -euo pipefail
#
# MAMBA_ROOT="$HOME/mamba"
# MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
# if [ ! -x "$MAMBA_BIN" ]; then
#   mkdir -p "$MAMBA_ROOT"
#   curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj -C "$MAMBA_ROOT" bin/micromamba >/dev/null
# fi
#
# "$MAMBA_BIN" create -y -r "$MAMBA_ROOT" -n psi4 -c conda-forge psi4 python=3.12 >/dev/null

# %%
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
# %%bash
set -euo pipefail
MAMBA_ROOT="$HOME/mamba"
MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
cat > psi4.in <<'EOF'
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>


# Your input file should go in this middle section
# Write this as a classic-style Psi4 input file (not a Python script)
molecule {
   Cl 0.0 0.0 0.0
   Cl 1.0 0.0 0.0
}

set {
  basis aug-cc-pVDZ
  reference uhf
}

# Compute the energy at the CCSD(T) level
optimize('MP2')


# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
EOF
"$MAMBA_BIN" run -r "$MAMBA_ROOT" -n psi4 psi4 psi4.in psi4.out
cat psi4.out
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Out:
# Optimizer: Optimization complete!
#
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, D. L. Poole, T. Győri, E. C. Mitchell, J. P. Pederson,
#     and A. M. Wallace
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     https://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Wednesday, 27 May 2026 08:18PM
#
#     Process ID: 35304
#     Host:       f205bb064bf1
#     PSIDATADIR: /root/mamba/envs/psi4/share/psi4
#     Memory:     500.0 MiB
#     Threads:    1
#     Addons:     a̶d̶c̶c̶, a̶m̶b̶i̶t̶, b̶s̶e̶, c̶c̶t̶3̶, c̶f̶o̶u̶r̶, c̶h̶e̶m̶p̶s̶2̶, c̶p̶p̶e̶, d̶d̶x̶,
#                 d̶f̶t̶d̶3̶, d̶f̶t̶d̶4̶, dkh, ecpint, einsums, f̶o̶r̶t̶e̶, g̶a̶u̶x̶c̶, g̶c̶p̶,
#                 g̶d̶m̶a̶, g̶e̶o̶m̶e̶t̶r̶i̶c̶, g̶p̶u̶_̶d̶f̶c̶c̶, i̶n̶t̶e̶g̶r̶a̶t̶o̶r̶x̶x̶,
#                 i̶p̶i̶, l̶i̶b̶e̶f̶p̶, m̶d̶i̶, m̶p̶2̶d̶, m̶r̶c̶c̶, ooo,
#                 o̶p̶e̶n̶f̶e̶r̶m̶i̶o̶n̶p̶s̶i̶4̶, pcmsolver, p̶s̶i̶4̶f̶o̶c̶k̶c̶i̶, p̶s̶i̶x̶a̶s̶,
#                 r̶e̶s̶p̶, s̶i̶m̶i̶n̶t̶, s̶n̶s̶m̶p̶2̶, v̶2̶r̶d̶m̶_̶c̶a̶s̶s̶c̶f̶
#
#   ==> Input File <==
#
# --------------------------------------------------------------------------
# # >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
#
# # Your input file should go in this middle section
# # Write this as a classic-style Psi4 input file (not a Python script)
# molecule {
#    Cl 0.0 0.0 0.0
#    Cl 1.0 0.0 0.0
# }
#
# set {
#   basis aug-cc-pVDZ
#   reference uhf
# }
#
# # Compute the energy at the CCSD(T) level
# optimize('MP2')
#
#
# # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# # STUDENTS SHOULD IGNORE THESE LINES
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#     For method 'MP2', SCF Algorithm Type (re)set to DISK_DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on f205bb064bf1
# *** at Wed May 27 20:18:27 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry CL         line   768 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               UHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Full point group: D_inf_h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          CL          -0.500000000000    -0.000000000000     0.000000000000    34.968852682000
#          CL           0.500000000000     0.000000000000     0.000000000000    34.968852682000
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B =      0.96415  C =      0.96415 [cm^-1]
#   Rotational constants: A = ************  B =  28904.52332  C =  28904.52332 [MHz]
#   Nuclear repulsion =  152.932213883629970
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 34
#   Nalpha       = 17
#   Nbeta        = 17
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DISK_DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 22
#     Number of basis functions: 54
#     Number of Cartesian functions: 58
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry CL         line   772 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   ==> DiskDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [MiB]:              375
#     Algorithm:                Core
#     Integral Cache:           SAVE
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 256
#     Number of Cartesian functions: 300
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 5.4436449542E-04.
#   Reciprocal condition number of the overlap matrix is 1.2216728684E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      Ag        13      13
#      B1g        6       6
#      B2g        6       6
#      B3g        2       2
#      Au         2       2
#      B1u        6       6
#      B2u        6       6
#      B3u       13      13
#    -------------------------
#     Total      54      54
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-UHF iter SAD:  -924.14783663717901   -9.24148e+02   0.00000e+00
#    @DF-UHF iter   1:  -915.48323302613198    8.66460e+00   2.27467e-02 ADIIS/DIIS
#    @DF-UHF iter   2:  -915.61211088169148   -1.28878e-01   9.71065e-03 ADIIS/DIIS
#    @DF-UHF iter   3:  -915.63295388388599   -2.08430e-02   9.36555e-04 ADIIS/DIIS
#    @DF-UHF iter   4:  -915.63337151260373   -4.17629e-04   1.11857e-04 ADIIS/DIIS
#    @DF-UHF iter   5:  -915.63337928664362   -7.77404e-06   1.52603e-05 DIIS
#    @DF-UHF iter   6:  -915.63337946707497   -1.80431e-07   3.24467e-06 DIIS
#    @DF-UHF iter   7:  -915.63337947448713   -7.41215e-09   3.94390e-07 DIIS
#    @DF-UHF iter   8:  -915.63337947455966   -7.25322e-11   4.07536e-08 DIIS
#    @DF-UHF iter   9:  -915.63337947455886    7.95808e-13   3.76987e-09 DIIS
#    @DF-UHF iter  10:  -915.63337947455966   -7.95808e-13   5.70716e-10 DIIS
#    @DF-UHF iter  11:  -915.63337947455977   -1.13687e-13   6.71091e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    @Spin Contamination Metric:   1.421085472E-14
#    @S^2 Expected:                0.000000000E+00
#    @S^2 Observed:                1.421085472E-14
#    @S   Expected:                0.000000000E+00
#    @S   Observed:                0.000000000E+00
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Alpha Occupied:
#
#        1Ag  -104.951037     1B3u -104.951006     2Ag   -10.893805
#        2B3u  -10.793106     3Ag    -8.412226     1B1u   -8.264617
#        1B2u   -8.264617     3B3u   -8.241096     1B2g   -8.237724
#        1B1g   -8.237724     4Ag    -1.778326     2B1u   -1.014854
#        2B2u   -1.014854     4B3u   -0.892582     5Ag    -0.653584
#        2B2g   -0.278156     2B1g   -0.278156
#
#     Alpha Virtual:
#
#        5B3u    0.083689     3B2u    0.094845     3B1u    0.094845
#        6Ag     0.123482     7Ag     0.143461     3B2g    0.172521
#        3B1g    0.172521     6B3u    0.282663     8Ag     0.286142
#        1B3g    0.286142     4B1u    0.428881     4B2u    0.428881
#        9Ag     0.472235     7B3u    0.516033     1Au     0.633594
#        8B3u    0.633594     5B2u    0.750986     5B1u    0.750986
#        9B3u    0.789536    10Ag     0.798643     4B2g    0.823065
#        4B1g    0.823065     2B3g    1.046040    11Ag     1.046040
#        5B1g    1.059266     5B2g    1.059266     6B1u    1.166413
#        6B2u    1.166413    10B3u    1.203469    12Ag     1.288446
#       11B3u    1.512688     2Au     1.512688    13Ag     1.741121
#       12B3u    2.187172     6B2g    2.208522     6B1g    2.208522
#       13B3u    4.371222
#
#     Beta Occupied:
#
#        1Ag  -104.951037     1B3u -104.951006     2Ag   -10.893805
#        2B3u  -10.793106     3Ag    -8.412226     1B1u   -8.264617
#        1B2u   -8.264617     3B3u   -8.241096     1B2g   -8.237724
#        1B1g   -8.237724     4Ag    -1.778326     2B1u   -1.014854
#        2B2u   -1.014854     4B3u   -0.892582     5Ag    -0.653584
#        2B2g   -0.278156     2B1g   -0.278156
#
#     Beta Virtual:
#
#        5B3u    0.083689     3B2u    0.094845     3B1u    0.094845
#        6Ag     0.123482     7Ag     0.143461     3B2g    0.172521
#        3B1g    0.172521     6B3u    0.282663     8Ag     0.286142
#        1B3g    0.286142     4B1u    0.428881     4B2u    0.428881
#        9Ag     0.472235     7B3u    0.516033     1Au     0.633594
#        8B3u    0.633594     5B2u    0.750986     5B1u    0.750986
#        9B3u    0.789536    10Ag     0.798643     4B2g    0.823065
#        4B1g    0.823065     2B3g    1.046040    11Ag     1.046040
#        5B1g    1.059266     5B2g    1.059266     6B1u    1.166413
#        6B2u    1.166413    10B3u    1.203469    12Ag     1.288446
#       11B3u    1.512688     2Au     1.512688    13Ag     1.741121
#       12B3u    2.187172     6B2g    2.208522     6B1g    2.208522
#       13B3u    4.371222
#
#     Final Occupation by Irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     5,    2,    2,    0,    0,    2,    2,    4 ]
#     SOCC [     0,    0,    0,    0,    0,    0,    0,    0 ]
#     NA   [     5,    2,    2,    0,    0,    2,    2,    4 ]
#     NB   [     5,    2,    2,    0,    0,    2,    2,    4 ]
#
#   @DF-UHF Final Energy:  -915.63337947455977
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =            152.9322138836299700
#     One-Electron Energy =               -1562.8162449597521118
#     Two-Electron Energy =                 494.2506516015622537
#     Total Energy =                       -915.6333794745597743
#
#   UHF NO Occupations:
#   HONO-2 :    3B3u 2.0000000
#   HONO-1 :    2B2u 2.0000000
#   HONO-0 :    4B3u 2.0000000
#   LUNO+0 :    5B3u 0.0000000
#   LUNO+1 :    3B2u 0.0000000
#   LUNO+2 :    6B3u 0.0000000
#   LUNO+3 :    6 Ag 0.0000000
#
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on f205bb064bf1 at Wed May 27 20:18:30 2026
# Module time:
# 	user time   =       2.12 seconds =       0.04 minutes
# 	system time =       0.22 seconds =       0.00 minutes
# 	total time  =          3 seconds =       0.05 minutes
# Total time:
# 	user time   =       2.12 seconds =       0.04 minutes
# 	system time =       0.22 seconds =       0.00 minutes
# 	total time  =          3 seconds =       0.05 minutes
#
#   A requested method does not make use of molecular symmetry: further calculations in C1 point group.
#
#   Constructing Basis Sets for DFOCC...
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry CL         line   772 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_CC
#     atoms 1-2 entry CL         line   574 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#
#
# *** tstart() called on f205bb064bf1
# *** at Wed May 27 20:18:30 2026
#
#
#
#   Module DFOCC Options:
#   ----------------------------------------------------------------------------
#   ACTIVE                        => (empty)
#   BASIS_RELATIVISTIC            => (empty)
#   BENCH                         => (empty)
#   CC_DIIS_MAX_VECS              => (empty)
#   CC_DIIS_MIN_VECS              => (empty)
#   CC_LAMBDA                     => (empty)
#   CC_MAXITER                    => (empty)
#   CC_TYPE                       => (empty)
#   CHOLESKY                      => (empty)
#   CHOLESKY_TOLERANCE            => (empty)
#   CI_TYPE                       => (empty)
#   COMPUT_S2                     => (empty)
#   CUBEPROP_BASIS_FUNCTIONS      => (empty)
#   CUBEPROP_FILEPATH             => (empty)
#   CUBEPROP_ISOCONTOUR_THRESHOLD => (empty)
#   CUBEPROP_ORBITALS             => (empty)
#   CUBEPROP_TASKS                => (empty)
#   CUBIC_BASIS_TOLERANCE         => (empty)
#   CUBIC_BLOCK_MAX_POINTS        => (empty)
#   CUBIC_GRID_OVERAGE            => (empty)
#   CUBIC_GRID_SPACING            => (empty)
#   CUTOFF                        => (empty)
#   DDX                           => (empty)
#   DEBUG                         => (empty)
#   DERTYPE                       => FIRST           !
#   DF_BASIS_CC                   => (empty)
#   DIE_IF_NOT_CONVERGED          => (empty)
#   DKH_ORDER                     => (empty)
#   DOCC                          => (empty)
#   DO_DIIS                       => (empty)
#   DO_LEVEL_SHIFT                => (empty)
#   DO_SCS                        => FALSE           !
#   DO_SOS                        => FALSE           !
#   E3_SCALE                      => (empty)
#   EKT_IP                        => (empty)
#   EXTERNAL_POTENTIAL_SYMMETRY   => (empty)
#   E_CONVERGENCE                 => 1e-08           !
#   FREEZE_CORE                   => (empty)
#   FREEZE_CORE_POLICY            => (empty)
#   FROZEN_DOCC                   => (empty)
#   FROZEN_UOCC                   => (empty)
#   HESS_TYPE                     => (empty)
#   INTEGRAL_CUTOFF               => (empty)
#   INTEGRAL_PACKAGE              => (empty)
#   LEVEL_SHIFT                   => (empty)
#   LINEQ_SOLVER                  => (empty)
#   LITERAL_CFOUR                 => (empty)
#   LS_THC_BASIS_TOLERANCE        => (empty)
#   LS_THC_DF                     => (empty)
#   LS_THC_PRUNING_SCHEME         => (empty)
#   LS_THC_RADIAL_POINTS          => (empty)
#   LS_THC_SPHERICAL_POINTS       => (empty)
#   LS_THC_S_EPSILON              => (empty)
#   LS_THC_WEIGHTS_TOLERANCE      => (empty)
#   MAT_NUM_COLUMN_PRINT          => (empty)
#   MAX_MOGRAD_CONVERGENCE        => (empty)
#   MAX_RADIAL_MOMENT             => (empty)
#   MBIS_D_CONVERGENCE            => (empty)
#   MBIS_MAXITER                  => (empty)
#   MBIS_PRUNING_SCHEME           => (empty)
#   MBIS_RADIAL_POINTS            => (empty)
#   MBIS_SPHERICAL_POINTS         => (empty)
#   MOLDEN_WITH_VIRTUAL           => (empty)
#   MOLDEN_WRITE                  => (empty)
#   MO_DIIS_NUM_VECS              => (empty)
#   MO_MAXITER                    => (empty)
#   MO_STEP_MAX                   => (empty)
#   MP2_AMP_TYPE                  => (empty)
#   MP2_OS_SCALE                  => (empty)
#   MP2_SOS_SCALE                 => (empty)
#   MP2_SOS_SCALE2                => (empty)
#   MP2_SS_SCALE                  => (empty)
#   MP2_TYPE                      => (empty)
#   MP_TYPE                       => (empty)
#   NAT_ORBS                      => FALSE           !
#   NUM_FROZEN_DOCC               => (empty)
#   NUM_FROZEN_UOCC               => (empty)
#   NUM_GPUS                      => (empty)
#   OCC_ORBS_PRINT                => (empty)
#   OEPROP                        => (empty)
#   OO_SCALE                      => (empty)
#   OPT_METHOD                    => (empty)
#   ORBITAL_OPTIMIZER_PACKAGE     => (empty)
#   ORB_OPT                       => FALSE           !
#   ORB_RESP_SOLVER               => (empty)
#   ORTH_TYPE                     => (empty)
#   PARENT_SYMMETRY               => (empty)
#   PCG_BETA_TYPE                 => (empty)
#   PCG_CONVERGENCE               => (empty)
#   PCG_MAXITER                   => (empty)
#   PCM                           => (empty)
#   PE                            => (empty)
#   PPL_TYPE                      => (empty)
#   PRINT                         => (empty)
#   PRINT_NOONS                   => (empty)
#   PROPERTIES                    => (empty)
#   PROPERTIES_ORIGIN             => (empty)
#   PUREAM                        => (empty)
#   QCHF                          => (empty)
#   QC_MODULE                     => (empty)
#   RAS1                          => (empty)
#   RAS2                          => (empty)
#   RAS3                          => (empty)
#   RAS4                          => (empty)
#   READ_SCF_3INDEX               => (empty)
#   REGULARIZATION                => (empty)
#   REG_PARAM                     => (empty)
#   RELATIVISTIC                  => (empty)
#   REMP_A                        => (empty)
#   RESTRICTED_DOCC               => (empty)
#   RESTRICTED_UOCC               => (empty)
#   RMS_MOGRAD_CONVERGENCE        => (empty)
#   R_CONVERGENCE                 => (empty)
#   SCF_TYPE                      => DISK_DF         !
#   SCREENING                     => (empty)
#   SCS_TYPE                      => (empty)
#   SOCC                          => (empty)
#   SOS_TYPE                      => (empty)
#   TRIPLES_IABC_TYPE             => (empty)
#   WFN                           => (empty)
#   WFN_TYPE                      => DF-OMP2         !
#   WRITER_FILE_LABEL             => (empty)
#
# 	Warning: cc_lambda option is changed to TRUE
# 	For this residual convergence, default PCG convergence is:     1.00e-07
# 	For this energy convergence, default residual convergence is:     3.16e-07
#
#  ==============================================================================
#  ==============================================================================
#  ==============================================================================
#
#                        DF-MP2
#               Program Written by Ugur Bozkaya
#               Latest Revision September 9, 2017
#
#  ==============================================================================
#  ==============================================================================
#  ==============================================================================
#
# 	MO spaces...
#
# 	 FC   AOCC   BOCC  AVIR   BVIR   FV
# 	------------------------------------------
# 	  0    17    17    37     37     0
# 	Reading DF integrals from disk ...
# 	Number of basis functions in the DF-HF basis: 256
# 	Number of basis functions in the DF-CC basis: 184
#
# 	Available memory                      :    500.00 MB
# 	Minimum required memory for amplitudes:      9.06 MB
#
# 	Computing DF-MP2 energy using SCF MOs (Canonical DF-MP2)...
# 	=======================================================================
# 	Nuclear Repulsion Energy (a.u.)    :   152.93221388362997
# 	DF-HF Energy (a.u.)                :  -915.63337947455977
# 	REF Energy (a.u.)                  :  -915.63337947455977
# 	Alpha-Alpha Contribution (a.u.)    :    -0.04535017205564
# 	Alpha-Beta Contribution (a.u.)     :    -0.21415315574667
# 	Beta-Beta Contribution (a.u.)      :    -0.04535017205564
# 	Scaled_SS Correlation Energy (a.u.):    -0.03023344803709
# 	Scaled_OS Correlation Energy (a.u.):    -0.25698378689601
# 	DF-SCS-MP2 Total Energy (a.u.)     :  -915.92059670949288
# 	DF-SOS-MP2 Total Energy (a.u.)     :  -915.91177857703042
# 	DF-SCS(N)-MP2 Total Energy (a.u.)  :  -915.79301208019558
# 	DF-MP2 Correlation Energy (a.u.)   :    -0.30485349985795
# 	DF-MP2 Total Energy (a.u.)         :  -915.93823297441770
# 	=======================================================================
#
# 	Computing unrelaxed response density matrices...
#
# 	Forming independent-pairs...
# 	Number of alpha independent-pairs:629
# 	Number of beta independent-pairs :629
# 	Computing the generalized Fock matrix (GFM)...
# 	Computing the orbital gradient...
# 	Forming effective orbital gradient...
# 	Solving orbital Z-vector equations...
#
# 	            PCG Solver
# 	   ------------------------------
# 	Iter     RMS Z Vector        RMS Residual
# 	----    ---------------    ---------------
# 	  1         1.77e-04         1.45e-04
# 	  2         5.87e-05         1.78e-05
# 	  3         9.23e-06         1.93e-06
# 	  4         8.13e-07         2.69e-07
# 	  5         7.41e-08         3.61e-08
#
# 	Computing the relaxed PDMs and GFM...
#
# *** tstop() called on f205bb064bf1 at Wed May 27 20:18:31 2026
# Module time:
# 	user time   =       1.12 seconds =       0.02 minutes
# 	system time =       0.17 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       3.39 seconds =       0.06 minutes
# 	system time =       0.39 seconds =       0.01 minutes
# 	total time  =          4 seconds =       0.07 minutes
#
# *** tstart() called on f205bb064bf1
# *** at Wed May 27 20:18:31 2026
#
# 	Forming Gamma^tilde...
# 	Backtransforming OPDM, TPDM, and GFM to the AO basis...
#
# *** tstop() called on f205bb064bf1 at Wed May 27 20:18:31 2026
# Module time:
# 	user time   =       0.16 seconds =       0.00 minutes
# 	system time =       0.04 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       3.55 seconds =       0.06 minutes
# 	system time =       0.43 seconds =       0.01 minutes
# 	total time  =          4 seconds =       0.07 minutes
#     Molecular point group: c1
#     Full point group: D_inf_h
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z
#     ------------   -----------------  -----------------  -----------------
#          CL          -0.944863062729    -0.000000000000     0.000000000000
#          CL           0.944863062729     0.000000000000     0.000000000000
#
#
#   -Total gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        7.990293882518    -0.000000000000    -0.000000000000
#        2       -7.990293882518     0.000000000000     0.000000000000
#
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	      17.000000            34.968853         -0.94486306 -0.00000000  0.00000000
# 	      17.000000            34.968853          0.94486306  0.00000000  0.00000000
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         1.889726           1.000000
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.00000       65.82982        0.26459       1.26459
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------~
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp   ~
# 	----------------------------------------------------------------------------------------------~
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o~
# 	----------------------------------------------------------------------------------------------~
# 	     1    -915.93823297   -9.16e+02      7.99e+00      7.99e+00 o    5.00e-01      5.00e-01 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	   Cl  -0.6322946465  -0.0000000000   0.0000000000
# 	   Cl   0.6322946465   0.0000000000   0.0000000000
#
#
#     Structure for next step:
#     Molecular point group: d2h
#     Full point group: D_inf_h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     CL          -0.632294646526    -0.000000000000     0.000000000000
#     CL           0.632294646526     0.000000000000     0.000000000000
#
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#     For method 'MP2', SCF Algorithm Type (re)set to DISK_DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on f205bb064bf1
# *** at Wed May 27 20:18:32 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry CL         line   768 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               UHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Full point group: D_inf_h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          CL          -0.632294646526    -0.000000000000     0.000000000000    34.968852682000
#          CL           0.632294646526     0.000000000000     0.000000000000    34.968852682000
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B =      0.60290  C =      0.60290 [cm^-1]
#   Rotational constants: A = ************  B =  18074.52158  C =  18074.52158 [MHz]
#   Nuclear repulsion =  120.934294417889333
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 34
#   Nalpha       = 17
#   Nbeta        = 17
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DISK_DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 22
#     Number of basis functions: 54
#     Number of Cartesian functions: 58
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry CL         line   772 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry CL         line   768 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#   Reading orbitals from file /tmp/psi4.default.35304.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   ==> DiskDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [MiB]:              375
#     Algorithm:                Core
#     Integral Cache:           SAVE
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 256
#     Number of Cartesian functions: 300
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 7.4633535411E-04.
#   Reciprocal condition number of the overlap matrix is 1.7404042514E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      Ag        13      13       5       5       5       0
#      B1g        6       6       2       2       2       0
#      B2g        6       6       2       2       2       0
#      B3g        2       2       0       0       0       0
#      Au         2       2       0       0       0       0
#      B1u        6       6       2       2       2       0
#      B2u        6       6       2       2       2       0
#      B3u       13      13       4       4       4       0
#    -------------------------------------------------------
#     Total      54      54      17      17      17       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-UHF iter   0:  -918.83134614536300   -9.18831e+02   2.12064e-01
#    @DF-UHF iter   1:  -917.84837507772909    9.82971e-01   2.37225e-02 ADIIS/DIIS
#    @DF-UHF iter   2:  -917.99994367395379   -1.51569e-01   9.78711e-03 ADIIS/DIIS
#    @DF-UHF iter   3:  -918.02174272836328   -2.17991e-02   7.70731e-04 ADIIS/DIIS
#    @DF-UHF iter   4:  -918.02202507633945   -2.82348e-04   1.85698e-04 ADIIS/DIIS
#    @DF-UHF iter   5:  -918.02204992192242   -2.48456e-05   2.68654e-05 DIIS
#    @DF-UHF iter   6:  -918.02205059371522   -6.71793e-07   4.60468e-06 DIIS
#    @DF-UHF iter   7:  -918.02205060545600   -1.17408e-08   5.83564e-07 DIIS
#    @DF-UHF iter   8:  -918.02205060566905   -2.13049e-10   7.19417e-08 DIIS
#    @DF-UHF iter   9:  -918.02205060567144   -2.38742e-12   8.68673e-09 DIIS
#    @DF-UHF iter  10:  -918.02205060567144    0.00000e+00   8.55564e-10 DIIS
#    @DF-UHF iter  11:  -918.02205060567189   -4.54747e-13   7.30237e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    @Spin Contamination Metric:   2.486899575E-14
#    @S^2 Expected:                0.000000000E+00
#    @S^2 Observed:                2.486899575E-14
#    @S   Expected:                0.000000000E+00
#    @S   Observed:                0.000000000E+00
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Alpha Occupied:
#
#        1Ag  -104.856428     1B3u -104.856414     2Ag   -10.649305
#        2B3u  -10.638356     3Ag    -8.135694     3B3u   -8.107528
#        1B1u   -8.096481     1B2u   -8.096481     1B2g   -8.093344
#        1B1g   -8.093344     4Ag    -1.646023     4B3u   -0.913693
#        2B2u   -0.808456     2B1u   -0.808456     5Ag    -0.686900
#        2B2g   -0.325810     2B1g   -0.325810
#
#     Alpha Virtual:
#
#        5B3u    0.081794     3B2u    0.109770     3B1u    0.109770
#        6Ag     0.127083     7Ag     0.141743     3B1g    0.170011
#        3B2g    0.170011     6B3u    0.279968     8Ag     0.333524
#        1B3g    0.333524     7B3u    0.417022     4B1u    0.438234
#        4B2u    0.438234     9Ag     0.458286     8B3u    0.606367
#        1Au     0.606367     9B3u    0.788385     5B2u    0.800617
#        5B1u    0.800617     4B2g    0.881663     4B1g    0.881663
#       10Ag     0.923865     5B2g    0.943385     5B1g    0.943385
#       10B3u    1.078028     6B1u    1.155270     6B2u    1.155270
#       11Ag     1.194811    12Ag     1.199317     2B3g    1.199317
#       11B3u    1.458847     2Au     1.458847    13Ag     1.510041
#        6B2g    1.865268     6B1g    1.865268    12B3u    2.224371
#       13B3u    2.691961
#
#     Beta Occupied:
#
#        1Ag  -104.856428     1B3u -104.856414     2Ag   -10.649305
#        2B3u  -10.638356     3Ag    -8.135694     3B3u   -8.107528
#        1B1u   -8.096481     1B2u   -8.096481     1B2g   -8.093344
#        1B1g   -8.093344     4Ag    -1.646023     4B3u   -0.913693
#        2B2u   -0.808456     2B1u   -0.808456     5Ag    -0.686900
#        2B2g   -0.325810     2B1g   -0.325810
#
#     Beta Virtual:
#
#        5B3u    0.081794     3B2u    0.109770     3B1u    0.109770
#        6Ag     0.127083     7Ag     0.141743     3B1g    0.170011
#        3B2g    0.170011     6B3u    0.279968     8Ag     0.333524
#        1B3g    0.333524     7B3u    0.417022     4B1u    0.438234
#        4B2u    0.438234     9Ag     0.458286     8B3u    0.606367
#        1Au     0.606367     9B3u    0.788385     5B2u    0.800617
#        5B1u    0.800617     4B2g    0.881663     4B1g    0.881663
#       10Ag     0.923865     5B2g    0.943385     5B1g    0.943385
#       10B3u    1.078028     6B1u    1.155270     6B2u    1.155270
#       11Ag     1.194811    12Ag     1.199317     2B3g    1.199317
#       11B3u    1.458847     2Au     1.458847    13Ag     1.510041
#        6B2g    1.865268     6B1g    1.865268    12B3u    2.224371
#       13B3u    2.691961
#
#     Final Occupation by Irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     5,    2,    2,    0,    0,    2,    2,    4 ]
#     SOCC [     0,    0,    0,    0,    0,    0,    0,    0 ]
#     NA   [     5,    2,    2,    0,    0,    2,    2,    4 ]
#     NB   [     5,    2,    2,    0,    0,    2,    2,    4 ]
#
#   @DF-UHF Final Energy:  -918.02205060567189
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =            120.9342944178893333
#     One-Electron Energy =               -1507.6356421591165144
#     Two-Electron Energy =                 468.6792971355553163
#     Total Energy =                       -918.0220506056718932
#
#   UHF NO Occupations:
#   HONO-2 :    3B3u 2.0000000
#   HONO-1 :    5 Ag 2.0000000
#   HONO-0 :    4B3u 2.0000000
#   LUNO+0 :    6 Ag 0.0000000
#   LUNO+1 :    7 Ag 0.0000000
#   LUNO+2 :    8 Ag 0.0000000
#   LUNO+3 :    3B2g 0.0000000
#
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on f205bb064bf1 at Wed May 27 20:18:33 2026
# Module time:
# 	user time   =       0.79 seconds =       0.01 minutes
# 	system time =       0.03 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       5.08 seconds =       0.08 minutes
# 	system time =       0.81 seconds =       0.01 minutes
# 	total time  =          6 seconds =       0.10 minutes
#
#   A requested method does not make use of molecular symmetry: further calculations in C1 point group.
#
#   Constructing Basis Sets for DFOCC...
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry CL         line   772 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_CC
#     atoms 1-2 entry CL         line   574 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#
#
# *** tstart() called on f205bb064bf1
# *** at Wed May 27 20:18:33 2026
#
#
#
#   Module DFOCC Options:
#   ----------------------------------------------------------------------------
#   ACTIVE                        => (empty)
#   BASIS_RELATIVISTIC            => (empty)
#   BENCH                         => (empty)
#   CC_DIIS_MAX_VECS              => (empty)
#   CC_DIIS_MIN_VECS              => (empty)
#   CC_LAMBDA                     => (empty)
#   CC_MAXITER                    => (empty)
#   CC_TYPE                       => (empty)
#   CHOLESKY                      => (empty)
#   CHOLESKY_TOLERANCE            => (empty)
#   CI_TYPE                       => (empty)
#   COMPUT_S2                     => (empty)
#   CUBEPROP_BASIS_FUNCTIONS      => (empty)
#   CUBEPROP_FILEPATH             => (empty)
#   CUBEPROP_ISOCONTOUR_THRESHOLD => (empty)
#   CUBEPROP_ORBITALS             => (empty)
#   CUBEPROP_TASKS                => (empty)
#   CUBIC_BASIS_TOLERANCE         => (empty)
#   CUBIC_BLOCK_MAX_POINTS        => (empty)
#   CUBIC_GRID_OVERAGE            => (empty)
#   CUBIC_GRID_SPACING            => (empty)
#   CUTOFF                        => (empty)
#   DDX                           => (empty)
#   DEBUG                         => (empty)
#   DERTYPE                       => FIRST           !
#   DF_BASIS_CC                   => (empty)
#   DIE_IF_NOT_CONVERGED          => (empty)
#   DKH_ORDER                     => (empty)
#   DOCC                          => (empty)
#   DO_DIIS                       => (empty)
#   DO_LEVEL_SHIFT                => (empty)
#   DO_SCS                        => FALSE           !
#   DO_SOS                        => FALSE           !
#   E3_SCALE                      => (empty)
#   EKT_IP                        => (empty)
#   EXTERNAL_POTENTIAL_SYMMETRY   => (empty)
#   E_CONVERGENCE                 => 1e-08           !
#   FREEZE_CORE                   => (empty)
#   FREEZE_CORE_POLICY            => (empty)
#   FROZEN_DOCC                   => (empty)
#   FROZEN_UOCC                   => (empty)
#   HESS_TYPE                     => (empty)
#   INTEGRAL_CUTOFF               => (empty)
#   INTEGRAL_PACKAGE              => (empty)
#   LEVEL_SHIFT                   => (empty)
#   LINEQ_SOLVER                  => (empty)
#   LITERAL_CFOUR                 => (empty)
#   LS_THC_BASIS_TOLERANCE        => (empty)
#   LS_THC_DF                     => (empty)
#   LS_THC_PRUNING_SCHEME         => (empty)
#   LS_THC_RADIAL_POINTS          => (empty)
#   LS_THC_SPHERICAL_POINTS       => (empty)
#   LS_THC_S_EPSILON              => (empty)
#   LS_THC_WEIGHTS_TOLERANCE      => (empty)
#   MAT_NUM_COLUMN_PRINT          => (empty)
#   MAX_MOGRAD_CONVERGENCE        => (empty)
#   MAX_RADIAL_MOMENT             => (empty)
#   MBIS_D_CONVERGENCE            => (empty)
#   MBIS_MAXITER                  => (empty)
#   MBIS_PRUNING_SCHEME           => (empty)
#   MBIS_RADIAL_POINTS            => (empty)
#   MBIS_SPHERICAL_POINTS         => (empty)
#   MOLDEN_WITH_VIRTUAL           => (empty)
#   MOLDEN_WRITE                  => (empty)
#   MO_DIIS_NUM_VECS              => (empty)
#   MO_MAXITER                    => (empty)
#   MO_STEP_MAX                   => (empty)
#   MP2_AMP_TYPE                  => (empty)
#   MP2_OS_SCALE                  => (empty)
#   MP2_SOS_SCALE                 => (empty)
#   MP2_SOS_SCALE2                => (empty)
#   MP2_SS_SCALE                  => (empty)
#   MP2_TYPE                      => (empty)
#   MP_TYPE                       => (empty)
#   NAT_ORBS                      => FALSE           !
#   NUM_FROZEN_DOCC               => (empty)
#   NUM_FROZEN_UOCC               => (empty)
#   NUM_GPUS                      => (empty)
#   OCC_ORBS_PRINT                => (empty)
#   OEPROP                        => (empty)
#   OO_SCALE                      => (empty)
#   OPT_METHOD                    => (empty)
#   ORBITAL_OPTIMIZER_PACKAGE     => (empty)
#   ORB_OPT                       => FALSE           !
#   ORB_RESP_SOLVER               => (empty)
#   ORTH_TYPE                     => (empty)
#   PARENT_SYMMETRY               => (empty)
#   PCG_BETA_TYPE                 => (empty)
#   PCG_CONVERGENCE               => (empty)
#   PCG_MAXITER                   => (empty)
#   PCM                           => (empty)
#   PE                            => (empty)
#   PPL_TYPE                      => (empty)
#   PRINT                         => (empty)
#   PRINT_NOONS                   => (empty)
#   PROPERTIES                    => (empty)
#   PROPERTIES_ORIGIN             => (empty)
#   PUREAM                        => (empty)
#   QCHF                          => (empty)
#   QC_MODULE                     => (empty)
#   RAS1                          => (empty)
#   RAS2                          => (empty)
#   RAS3                          => (empty)
#   RAS4                          => (empty)
#   READ_SCF_3INDEX               => (empty)
#   REGULARIZATION                => (empty)
#   REG_PARAM                     => (empty)
#   RELATIVISTIC                  => (empty)
#   REMP_A                        => (empty)
#   RESTRICTED_DOCC               => (empty)
#   RESTRICTED_UOCC               => (empty)
#   RMS_MOGRAD_CONVERGENCE        => (empty)
#   R_CONVERGENCE                 => (empty)
#   SCF_TYPE                      => DISK_DF         !
#   SCREENING                     => (empty)
#   SCS_TYPE                      => (empty)
#   SOCC                          => (empty)
#   SOS_TYPE                      => (empty)
#   TRIPLES_IABC_TYPE             => (empty)
#   WFN                           => (empty)
#   WFN_TYPE                      => DF-OMP2         !
#   WRITER_FILE_LABEL             => (empty)
#
# 	Warning: cc_lambda option is changed to TRUE
# 	For this residual convergence, default PCG convergence is:     1.00e-07
# 	For this energy convergence, default residual convergence is:     3.16e-07
#
#  ==============================================================================
#  ==============================================================================
#  ==============================================================================
#
#                        DF-MP2
#               Program Written by Ugur Bozkaya
#               Latest Revision September 9, 2017
#
#  ==============================================================================
#  ==============================================================================
#  ==============================================================================
#
# 	MO spaces...
#
# 	 FC   AOCC   BOCC  AVIR   BVIR   FV
# 	------------------------------------------
# 	  0    17    17    37     37     0
# 	Reading DF integrals from disk ...
# 	Number of basis functions in the DF-HF basis: 256
# 	Number of basis functions in the DF-CC basis: 184
#
# 	Available memory                      :    500.00 MB
# 	Minimum required memory for amplitudes:      9.06 MB
#
# 	Computing DF-MP2 energy using SCF MOs (Canonical DF-MP2)...
# 	=======================================================================
# 	Nuclear Repulsion Energy (a.u.)    :   120.93429441788933
# 	DF-HF Energy (a.u.)                :  -918.02205060567189
# 	REF Energy (a.u.)                  :  -918.02205060567189
# 	Alpha-Alpha Contribution (a.u.)    :    -0.04387702185814
# 	Alpha-Beta Contribution (a.u.)     :    -0.21503104468183
# 	Beta-Beta Contribution (a.u.)      :    -0.04387702185814
# 	Scaled_SS Correlation Energy (a.u.):    -0.02925134790543
# 	Scaled_OS Correlation Energy (a.u.):    -0.25803725361819
# 	DF-SCS-MP2 Total Energy (a.u.)     :  -918.30933920719565
# 	DF-SOS-MP2 Total Energy (a.u.)     :  -918.30159096375826
# 	DF-SCS(N)-MP2 Total Energy (a.u.)  :  -918.17649772261257
# 	DF-MP2 Correlation Energy (a.u.)   :    -0.30278508839812
# 	DF-MP2 Total Energy (a.u.)         :  -918.32483569406998
# 	=======================================================================
#
# 	Computing unrelaxed response density matrices...
#
# 	Forming independent-pairs...
# 	Number of alpha independent-pairs:629
# ...
#   LUNO+0 :    6 Ag 0.0000000
#   LUNO+1 :    5B3u 0.0000000
#   LUNO+2 :    3B1g 0.0000000
#   LUNO+3 :    3B2g 0.0000000
#
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on f205bb064bf1 at Wed May 27 20:19:22 2026
# Module time:
# 	user time   =       0.66 seconds =       0.01 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      47.36 seconds =       0.79 minutes
# 	system time =       6.92 seconds =       0.12 minutes
# 	total time  =         55 seconds =       0.92 minutes
#
#   A requested method does not make use of molecular symmetry: further calculations in C1 point group.
#
#   Constructing Basis Sets for DFOCC...
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry CL         line   772 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_CC
#     atoms 1-2 entry CL         line   574 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#
#
# *** tstart() called on f205bb064bf1
# *** at Wed May 27 20:19:22 2026
#
#
#
#   Module DFOCC Options:
#   ----------------------------------------------------------------------------
#   ACTIVE                        => (empty)
#   BASIS_RELATIVISTIC            => (empty)
#   BENCH                         => (empty)
#   CC_DIIS_MAX_VECS              => (empty)
#   CC_DIIS_MIN_VECS              => (empty)
#   CC_LAMBDA                     => (empty)
#   CC_MAXITER                    => (empty)
#   CC_TYPE                       => (empty)
#   CHOLESKY                      => (empty)
#   CHOLESKY_TOLERANCE            => (empty)
#   CI_TYPE                       => (empty)
#   COMPUT_S2                     => (empty)
#   CUBEPROP_BASIS_FUNCTIONS      => (empty)
#   CUBEPROP_FILEPATH             => (empty)
#   CUBEPROP_ISOCONTOUR_THRESHOLD => (empty)
#   CUBEPROP_ORBITALS             => (empty)
#   CUBEPROP_TASKS                => (empty)
#   CUBIC_BASIS_TOLERANCE         => (empty)
#   CUBIC_BLOCK_MAX_POINTS        => (empty)
#   CUBIC_GRID_OVERAGE            => (empty)
#   CUBIC_GRID_SPACING            => (empty)
#   CUTOFF                        => (empty)
#   DDX                           => (empty)
#   DEBUG                         => (empty)
#   DERTYPE                       => FIRST           !
#   DF_BASIS_CC                   => (empty)
#   DIE_IF_NOT_CONVERGED          => (empty)
#   DKH_ORDER                     => (empty)
#   DOCC                          => (empty)
#   DO_DIIS                       => (empty)
#   DO_LEVEL_SHIFT                => (empty)
#   DO_SCS                        => FALSE           !
#   DO_SOS                        => FALSE           !
#   E3_SCALE                      => (empty)
#   EKT_IP                        => (empty)
#   EXTERNAL_POTENTIAL_SYMMETRY   => (empty)
#   E_CONVERGENCE                 => 1e-08           !
#   FREEZE_CORE                   => (empty)
#   FREEZE_CORE_POLICY            => (empty)
#   FROZEN_DOCC                   => (empty)
#   FROZEN_UOCC                   => (empty)
#   HESS_TYPE                     => (empty)
#   INTEGRAL_CUTOFF               => (empty)
#   INTEGRAL_PACKAGE              => (empty)
#   LEVEL_SHIFT                   => (empty)
#   LINEQ_SOLVER                  => (empty)
#   LITERAL_CFOUR                 => (empty)
#   LS_THC_BASIS_TOLERANCE        => (empty)
#   LS_THC_DF                     => (empty)
#   LS_THC_PRUNING_SCHEME         => (empty)
#   LS_THC_RADIAL_POINTS          => (empty)
#   LS_THC_SPHERICAL_POINTS       => (empty)
#   LS_THC_S_EPSILON              => (empty)
#   LS_THC_WEIGHTS_TOLERANCE      => (empty)
#   MAT_NUM_COLUMN_PRINT          => (empty)
#   MAX_MOGRAD_CONVERGENCE        => (empty)
#   MAX_RADIAL_MOMENT             => (empty)
#   MBIS_D_CONVERGENCE            => (empty)
#   MBIS_MAXITER                  => (empty)
#   MBIS_PRUNING_SCHEME           => (empty)
#   MBIS_RADIAL_POINTS            => (empty)
#   MBIS_SPHERICAL_POINTS         => (empty)
#   MOLDEN_WITH_VIRTUAL           => (empty)
#   MOLDEN_WRITE                  => (empty)
#   MO_DIIS_NUM_VECS              => (empty)
#   MO_MAXITER                    => (empty)
#   MO_STEP_MAX                   => (empty)
#   MP2_AMP_TYPE                  => (empty)
#   MP2_OS_SCALE                  => (empty)
#   MP2_SOS_SCALE                 => (empty)
#   MP2_SOS_SCALE2                => (empty)
#   MP2_SS_SCALE                  => (empty)
#   MP2_TYPE                      => (empty)
#   MP_TYPE                       => (empty)
#   NAT_ORBS                      => FALSE           !
#   NUM_FROZEN_DOCC               => (empty)
#   NUM_FROZEN_UOCC               => (empty)
#   NUM_GPUS                      => (empty)
#   OCC_ORBS_PRINT                => (empty)
#   OEPROP                        => (empty)
#   OO_SCALE                      => (empty)
#   OPT_METHOD                    => (empty)
#   ORBITAL_OPTIMIZER_PACKAGE     => (empty)
#   ORB_OPT                       => FALSE           !
#   ORB_RESP_SOLVER               => (empty)
#   ORTH_TYPE                     => (empty)
#   PARENT_SYMMETRY               => (empty)
#   PCG_BETA_TYPE                 => (empty)
#   PCG_CONVERGENCE               => (empty)
#   PCG_MAXITER                   => (empty)
#   PCM                           => (empty)
#   PE                            => (empty)
#   PPL_TYPE                      => (empty)
#   PRINT                         => (empty)
#   PRINT_NOONS                   => (empty)
#   PROPERTIES                    => (empty)
#   PROPERTIES_ORIGIN             => (empty)
#   PUREAM                        => (empty)
#   QCHF                          => (empty)
#   QC_MODULE                     => (empty)
#   RAS1                          => (empty)
#   RAS2                          => (empty)
#   RAS3                          => (empty)
#   RAS4                          => (empty)
#   READ_SCF_3INDEX               => (empty)
#   REGULARIZATION                => (empty)
#   REG_PARAM                     => (empty)
#   RELATIVISTIC                  => (empty)
#   REMP_A                        => (empty)
#   RESTRICTED_DOCC               => (empty)
#   RESTRICTED_UOCC               => (empty)
#   RMS_MOGRAD_CONVERGENCE        => (empty)
#   R_CONVERGENCE                 => (empty)
#   SCF_TYPE                      => DISK_DF         !
#   SCREENING                     => (empty)
#   SCS_TYPE                      => (empty)
#   SOCC                          => (empty)
#   SOS_TYPE                      => (empty)
#   TRIPLES_IABC_TYPE             => (empty)
#   WFN                           => (empty)
#   WFN_TYPE                      => DF-OMP2         !
#   WRITER_FILE_LABEL             => (empty)
#
# 	Warning: cc_lambda option is changed to TRUE
# 	For this residual convergence, default PCG convergence is:     1.00e-07
# 	For this energy convergence, default residual convergence is:     3.16e-07
#
#  ==============================================================================
#  ==============================================================================
#  ==============================================================================
#
#                        DF-MP2
#               Program Written by Ugur Bozkaya
#               Latest Revision September 9, 2017
#
#  ==============================================================================
#  ==============================================================================
#  ==============================================================================
#
# 	MO spaces...
#
# 	 FC   AOCC   BOCC  AVIR   BVIR   FV
# 	------------------------------------------
# 	  0    17    17    37     37     0
# 	Reading DF integrals from disk ...
# 	Number of basis functions in the DF-HF basis: 256
# 	Number of basis functions in the DF-CC basis: 184
#
# 	Available memory                      :    500.00 MB
# 	Minimum required memory for amplitudes:      9.06 MB
#
# 	Computing DF-MP2 energy using SCF MOs (Canonical DF-MP2)...
# 	=======================================================================
# 	Nuclear Repulsion Energy (a.u.)    :    74.96915265447190
# 	DF-HF Energy (a.u.)                :  -918.96544194951139
# 	REF Energy (a.u.)                  :  -918.96544194951139
# 	Alpha-Alpha Contribution (a.u.)    :    -0.04106618981858
# 	Alpha-Beta Contribution (a.u.)     :    -0.22579605081085
# 	Beta-Beta Contribution (a.u.)      :    -0.04106618981858
# 	Scaled_SS Correlation Energy (a.u.):    -0.02737745987905
# 	Scaled_OS Correlation Energy (a.u.):    -0.27095526097302
# 	DF-SCS-MP2 Total Energy (a.u.)     :  -919.26377467036343
# 	DF-SOS-MP2 Total Energy (a.u.)     :  -919.25897681556546
# 	DF-SCS(N)-MP2 Total Energy (a.u.)  :  -919.10999493767281
# 	DF-MP2 Correlation Energy (a.u.)   :    -0.30792843044800
# 	DF-MP2 Total Energy (a.u.)         :  -919.27337037995937
# 	=======================================================================
#
# 	Computing unrelaxed response density matrices...
#
# 	Forming independent-pairs...
# 	Number of alpha independent-pairs:629
# 	Number of beta independent-pairs :629
# 	Computing the generalized Fock matrix (GFM)...
# 	Computing the orbital gradient...
# 	Forming effective orbital gradient...
# 	Solving orbital Z-vector equations...
#
# 	            PCG Solver
# 	   ------------------------------
# 	Iter     RMS Z Vector        RMS Residual
# 	----    ---------------    ---------------
# 	  1         4.78e-04         8.57e-05
# 	  2         3.51e-05         2.42e-05
# 	  3         1.04e-05         3.90e-06
# 	  4         1.61e-06         9.44e-07
# 	  5         3.61e-07         1.21e-07
# 	  6         4.43e-08         2.20e-08
#
# 	Computing the relaxed PDMs and GFM...
#
# *** tstop() called on f205bb064bf1 at Wed May 27 20:19:24 2026
# Module time:
# 	user time   =       1.02 seconds =       0.02 minutes
# 	system time =       0.16 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
# Total time:
# 	user time   =      48.50 seconds =       0.81 minutes
# 	system time =       7.08 seconds =       0.12 minutes
# 	total time  =         57 seconds =       0.95 minutes
#
# *** tstart() called on f205bb064bf1
# *** at Wed May 27 20:19:24 2026
#
# 	Forming Gamma^tilde...
# 	Backtransforming OPDM, TPDM, and GFM to the AO basis...
#
# *** tstop() called on f205bb064bf1 at Wed May 27 20:19:24 2026
# Module time:
# 	user time   =       0.21 seconds =       0.00 minutes
# 	system time =       0.04 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      48.71 seconds =       0.81 minutes
# 	system time =       7.12 seconds =       0.12 minutes
# 	total time  =         57 seconds =       0.95 minutes
#     Molecular point group: c1
#     Full point group: D_inf_h
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z
#     ------------   -----------------  -----------------  -----------------
#          CL          -1.927459426759    -0.000000000000     0.000000000000
#          CL           1.927459426759     0.000000000000     0.000000000000
#
#
#   -Total gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.000038570790    -0.000000000000     0.000000000000
#        2       -0.000038570790     0.000000000000    -0.000000000000
#
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	      17.000000            34.968853         -1.92745943 -0.00000000  0.00000000
# 	      17.000000            34.968853          1.92745943  0.00000000  0.00000000
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         3.854919           2.039935
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       2.03994        0.00032        0.00010       2.04004
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp
# 	----------------------------------------------------------------------------------------------
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
# 	----------------------------------------------------------------------------------------------
# 	    17    -919.27337038   -3.03e-07 *    3.86e-05 *    3.86e-05 o    1.91e-04 *    1.91e-04 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	   Cl  -1.0200181326  -0.0000000000   0.0000000000
# 	   Cl   1.0200181326   0.0000000000   0.0000000000
#
#
#     Final optimized geometry and variables:
#     Molecular point group: d2h
#     Full point group: D_inf_h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     CL          -1.019967603132    -0.000000000000     0.000000000000
#     CL           1.019967603132     0.000000000000     0.000000000000
#
#
#     Psi4 stopped on: Wednesday, 27 May 2026 08:19PM
#     Psi4 wall time for execution: 0:00:59.40
#
# *** Psi4 exiting successfully. Buy a developer a beer!
